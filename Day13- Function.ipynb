# %%
print("Hello,Everyone")

# %% [markdown]
# # Standard Function in python

# %% [raw]
# def functionname(parameter-optional):
#     main body
#     optional return

# %%
def addition(x:int,y:int)->int:
    """Takes two input and return there addition as output.
    Example:
        addition(12,35)==>> 47,
        addition([1,2],[3,4])==>> [1,2,3,4]"""
    return x+y

# %%
print?
# Out:
# Signature: print(*args, sep=' ', end='\n', file=None, flush=False)
# Docstring:
# Prints the values to a stream, or to sys.stdout by default.
#
# sep
#   string inserted between values, default a space.
# end
#   string appended after the last value, default a newline.
# file
#   a file-like object (stream); defaults to the current sys.stdout.
# flush
#   whether to forcibly flush the stream.
# Type:      builtin_function_or_method

# %%
addition?
# Out:
# Signature: addition(x: int, y: int) -> int
# Docstring:
# Takes two input and return there addition as output.
# Example:
#     addition(12,35)==>> 47,
#     addition([1,2],[3,4])==>> [1,2,3,4]
# File:      c:\users\shubham\appdata\local\temp\ipykernel_25992\3115523434.py
# Type:      function

# %%
addition(123.25,586.12)
# Out:
# 709.37

# %%
addition([3,4],[1,2])
# Out:
# [3, 4, 1, 2]

# %%
addition('shubham ','waghmare')
# Out:
# 'shubham waghmare'

# %%
addition(12,25)
# Out:
# 37

# %%
def addition(x,y):
    print("Hello,User.\nThis is the result of your calculation:")
    print(x),print(y)
    print(x+y)
   # return
    print("Hello")

# %%
print(10,23)

# %%
a = addition(10,20)

# %%
a

# %%
print(a)

# %%
type(a)

# %%
b

# %%
c

# %%
addition("Shubham ","Waghmare")

# %%
z = addition("Shubham"," dfff")

# %%
z

# %%
def addition(x,y):
    print(x+y)

# %%
addition(10,51)
# Out:
# 61

# %%
y = addition(10,51)
# Out:
# 61

# %%
y

# %%
print(y)
# Out:
# None

# %%
def greet():
    print("Hello,User!")

# %%
greet()
# Out:
# Hello,User!

# %%
greet("Shubham")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 greet("Shubham")
#
# TypeError: greet() takes 0 positional arguments but 1 was given

# %%
addition(10,20,30)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 addition(10,20,30)
#
# TypeError: addition() takes 2 positional arguments but 3 were given

# %% [markdown]
# ## default argument

# %%
print?

# %%
def greet(name = "User"):
    print(f"Hello,{name}!")

# %%
greet("Shubham")
# Out:
# Hello,Shubham!

# %%
greet()
# Out:
# Hello,User!

# %%
greet?
# Out:
# Signature: greet(name='User')
# Docstring: <no docstring>
# File:      c:\users\shubham\appdata\local\temp\ipykernel_25992\2419799973.py
# Type:      function

# %%
#positional,keyward

# %%
greet(name = "Shubham")
# Out:
# Hello,Shubham!

# %%
greet(x = "shubham")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 greet(x = "shubham")
#
# TypeError: greet() got an unexpected keyword argument 'x'

# %%
def sub(x:int = 1,y:int = 1)->int:
    """
    takes two arguments x and y and return there subtraction
    """
    return x - y

# %%
sub(x = 5,y = 10)
# Out:
# -5

# %%
sub(y = 5,x = 10)
# Out:
# 5

# %%
sub?
# Out:
# Signature: sub(x: int = 1, y: int = 1) -> int
# Docstring: takes two arguments x and y and return there subtraction
# File:      c:\users\shubham\appdata\local\temp\ipykernel_25992\88617922.py
# Type:      function

# %%
sub(5,10)
# Out:
# -5

# %%
sub(10,5)
# Out:
# 5

# %%
sub(10)
# Out:
# 9

# %%
sub(y=5)
# Out:
# -4

# %% [markdown]
# ## order of arguments

# %%
sub(y = 10,5)
# Out:
#   Cell In[32], line 1
#     sub(y = 10,5)
#                 ^
# SyntaxError: positional argument follows keyword argument

# %% [markdown]
# ## first -positional,then -keyward

# %%
sub(x=10,5)
# Out:
#   Cell In[33], line 1
#     sub(x=10,5)
#               ^
# SyntaxError: positional argument follows keyword argument

# %%
sub(5,y = 5)
# Out:
# 0

# %%
sub(5,x = 5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 sub(5,x = 5)
#
# TypeError: sub() got multiple values for argument 'x'

# %%
sub?
# Out:
# Signature: sub(x: int = 1, y: int = 1) -> int
# Docstring: takes two arguments x and y and return there subtraction
# File:      c:\users\shubham\appdata\local\temp\ipykernel_25992\88617922.py
# Type:      function

# %%
sub()
# Out:
# 0

# %%
def sub(x:int = 1,*,y:int = 1)->int:
    """
    takes two arguments x and y and return there subtraction
    """
    return x - y

# %%
sub(10,20)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 sub(10,20)
#
# TypeError: sub() takes from 0 to 1 positional arguments but 2 were given

# %%
sub(10,y=20)
# Out:
# -10

# %%
sub(x=20,y=30)
# Out:
# -10

# %%
print?

# %% [markdown]
# ### variable length argument

# %%
#*args,**kwargs

# %%
def minus(x,y,/,z):
    return x-y-z

# %%
minus(10,5,2)
# Out:
# 3

# %%
minus(x=10,y=5,z=2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 minus(x=10,y=5,z=2)
#
# TypeError: minus() got some positional-only arguments passed as keyword arguments: 'x, y'

# %%
minus(10,5,z=2)
# Out:
# 3

# %%
def minus(x,y,/,z,c,*,d,f):
    return x-y-z-c-d-f

# %%
minus(10,20,3,54,64,58)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 minus(10,20,3,54,64,58)
#
# TypeError: minus() takes 4 positional arguments but 6 were given

# %%
parameter :
    1.positional only before /
    2.keyword only after *
    3.standard -(p+k)

# %%
minus?
# Out:
# Signature: minus(x, y, /, z, c, *, d, f)
# Docstring: <no docstring>
# File:      c:\users\shubham\appdata\local\temp\ipykernel_25992\322353798.py
# Type:      function

# %%
minus(10,20,3,54,d=64,f=58)
# Out:
# -189

# %%
minus(10,20,3,54,f=58,d=64)
# Out:
# -189

# %%
minus(10,20,z=3,c=54,f=58,d=64)
# Out:
# -189

# %%
minus(10,20,3,c=54,f=58,d=64)
# Out:
# -189

# %%
minus?
# Out:
# Signature: minus(x, y, /, z, c, *, d, f)
# Docstring: <no docstring>
# File:      c:\users\shubham\appdata\local\temp\ipykernel_25992\322353798.py
# Type:      function

# %%
minus(10,20,3,z=54,f=58,d=64)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 minus(10,20,3,z=54,f=58,d=64)
#
# TypeError: minus() got multiple values for argument 'z'

# %%
def add(*nums):
    return nums,type(nums)

# %%
add(10,20,3)
# Out:
# ((10, 20, 3), tuple)

# %%
def minus(**nums):
    print(nums)
    return type(nums)

# %%
minus(12,35,56)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 minus(12,35,56)
#
# TypeError: minus() takes 0 positional arguments but 3 were given

# %%
minus(x=12,y=35,z=56)
# Out:
# {'x': 12, 'y': 35, 'z': 56}
# dict

# %%
def minus(z,x,c,*args):
    return args,z,x,c

# %%
minus(1,2,0,5,2,2,0,5,0,5,0,4,0,5,0,4,0,4,0,4)
# Out:
# ((5, 2, 2, 0, 5, 0, 5, 0, 4, 0, 5, 0, 4, 0, 4, 0, 4), 1, 2, 0)

# %%
minus(z=1,x=2,c=0,5,2,2,0,5,0,5,0,4,0,5,0,4,0,4,0,4)
# Out:
#   Cell In[66], line 1
#     minus(z=1,x=2,c=0,5,2,2,0,5,0,5,0,4,0,5,0,4,0,4,0,4)
#                                                        ^
# SyntaxError: positional argument follows keyword argument

# %%
minus(z=1,x=2,c=0)
# Out:
# ((), 1, 2, 0)

# %%
def minus(*args,z,x,c):
    return args,z,x,c

# %%
minus(1,2,0,5,2,2,0,5,0,5,0,4,0,5,0,4,0,4,0,4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 minus(1,2,0,5,2,2,0,5,0,5,0,4,0,5,0,4,0,4,0,4)
#
# TypeError: minus() missing 3 required keyword-only arguments: 'z', 'x', and 'c'

# %%
minus(1,2,0,5,2,2,0,5,0,5,0,4,0,5,0,4,0,z=4,x=0,c=4)
# Out:
# ((1, 2, 0, 5, 2, 2, 0, 5, 0, 5, 0, 4, 0, 5, 0, 4, 0), 4, 0, 4)

# %%
def fd(c,v):
    return c*v
    print("ok")

# %%
fd(5,3)

# %%
fd(c=5,v=3)

# %%
fd(5,v=3)

# %%
fd(v=5,3)

# %%
fd(5,c=3)

# %%
def addition(x,y):
    return x + y

# %%
addition(5,3)

# %%
sum?

# %%
def addition(*nums):
    print(type(nums))
    print(nums)
    return sum(nums)

# %%
addition(5,3)

# %%
addition(5,3,8)

# %%
addition()

# %%
(3,5,8)

# %%
(12,3)+(3,)

# %%
def addition(name,**nums):
    print(type(nums))
    print(nums)
    print(name)

# %%
addition("Shubham")

# %%
addition(name="Shubham",age = 30,edu = "Graduate")

# %%
def info(name,*marks,**result):
    print(name)
    print(sum(marks))
    print(result)

# %%
info("shubham",80,90,99,100,75,grade = "distinction",final_result = "pass")

# %%
info(name = "shubham",80,90,99,100,75,grade = "distinction",final_result = "pass")

# %%
info(80,90,99,100,75,grade = "distinction",final_result = "pass",name = "shubham")

# %%
def sd(science,maths,*marks):
    print(science)
    print(maths)
    print(marks)

# %%
sd(20,30,50,"shubham",70)

# %%
sd(20,30)

# %%
def sd(science,/,maths,**subjects):
    print(science)
    print(maths)
    print(subjects)

# %%
sd(45,65,history = 75,literature = 80)

# %%
sd(science = 45,maths = 65,history = 75,literature = 80)

# %%
def sd(science,*,maths,**subjects):
    print(science)
    print(maths)
    print(subjects)

# %%
sd(45,65,history = 75,literature = 80)

# %%
sd(science = 45,maths = 65,history = 75,literature = 80)
