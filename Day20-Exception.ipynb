# %%
x = 10
y = 0

# %%
x/y

# %%
10/1

# %%
b = 0
while True:
    
    try:
        10/b
        break
    except ZeroDivisionError:
        print("Division by zero is not possible")
        break
    except NameError:
        globals()['b'] = 10
    except Exception as e:
        print(e)
print(10+20)

# %%
m = 0
while True:
    
    try:
        10/m
        break
    except Exception as e:
        print(e)
        break
    except ZeroDivisionError:
        print("Division by zero is not possible")
        break
    except NameError:
        globals()['m'] = 10
    
print(10+20)

# %%
while True:
        age = int(input("Enter your age:"))
        if age <0 or age >120:
            raise InvaliedAgeError("Age should be between 0 to 120")
# Out:
# Enter your age: 563
# ---------------------------------------------------------------------------
# InvaliedAgeError                          Traceback (most recent call last)
# Cell In[25], line 4
#       1 while True:
#       2         age = int(input("Enter your age:"))
#       3         if age <0 or age >120:
# ----> 4             raise InvaliedAgeError("Age should be between 0 to 120")
#       5
#
# InvaliedAgeError: Age should be between 0 to 120

# %%
replay = "no"
while replay == "no":
    replay = input("Do you love me?")
# Out:
# Do you love me? no
# Do you love me? no
# Do you love me? no
# Do you love me? no
# Do you love me? no
# Do you love me? yes

# %%
try:
    numerator = 10
    denominator = 0
    result = numerator / denominator  # This will raise a ZeroDivisionError
    print(result)
except Exception as e:
    print("Oops! You can't divide by zero.")

print("Program continues after the try-except block.")
# Out:
# Oops! You can't divide by zero.
# Program continues after the try-except block.

# %%
try:
    num1 = int(input("Enter a number: "))
    num2 = int(input("Enter another number: "))
    result = num1 / num2
    print(f"The result is: {result}")
except ValueError:
    print("Invalid input. Please enter a valid number.")
except ZeroDivisionError:
    print("You can't divide by zero!")
# Out:
# Enter a number:  125
# Enter another number:  0
# You can't divide by zero!

# %%
try:
    num1 = int(input("Enter a number: "))
    num2 = int(input("Enter another number: "))
    result = num1 / num2
    print(f"The result is: {result}")
except ValueError:
    print("Invalid input. Please enter a valid number.")
except ZeroDivisionError:
    print("You can't divide by zero!")

# %%
try:
    file = open("my_file.txt", "r")
except FileNotFoundError:
    print("The file was not found.")
else:
    print("File opened successfully!")
    print(file.read())
    file.close() # It's safe to close the file here
# Out:
# The file was not found.

# %%
try:
    print(asfdfhh)
    file = open("another_file.txt", "r")
    content = file.read()
    print(content)
except (FileNotFoundError,NameError):
    print("Unexpected Thing Happen,Please try after some time.")
finally:
    # This will always execute, regardless of whether an error occurred
    print("Attempting to close the file if opened...")
    if 'file' in locals() and not file.closed:
        file.close()
    print("File closed.")
# Out:
# Unexpected Thing Happen,Please try after some time.
# Attempting to close the file if opened...
# File closed.

# %%
def calculate_age(year_of_birth):
    if year_of_birth > 2026:
        raise futureBirthError("Future Birth not possible")
    else:
        return 2026 - year_of_birth

try:
    age = calculate_age(2030)
except futureBirthError as e:
    print(f"Error: {e}")
# Out:
# Error: Future Birth not possible

# %%
class FutureBirthError(Exception):
    pass

# %%
class InvaliedDataError(Exception):
    pass

# %%
lis = [123,456,789,"str"]
error = []
try:
    for i in lis:
        i+123
except TypeError:
    lis.remove(i)
    error.append(i)
    raise InvaliedDataError("Data Should Be Numeric")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 9
#       7     lis.remove(i)
#       8     error.append(i)
# ----> 9     raise InvaliedDataError("Data Should Be Numeric")
#      10
#
# TypeError: can only concatenate str (not "int") to str
#
# During handling of the above exception, another exception occurred:
#
# InvaliedDataError                         Traceback (most recent call last)
# Cell In[29], line 9
#       5         i+123
#       6 except TypeError:
#       7     lis.remove(i)
#       8     error.append(i)
# ----> 9     raise InvaliedDataError("Data Should Be Numeric")
#      10
#      11
#      12
#
# InvaliedDataError: Data Should Be Numeric

# %%
error
# Out:
# ['str']
