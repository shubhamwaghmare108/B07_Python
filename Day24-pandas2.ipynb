# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel("Titanic.xlsx",sheet_name="Titanic")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                        Graham, Miss Margaret Edith  female  19.0      0
# 888            Johnston, Miss Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df.set_index?

# %%
df.set_index("PassengerId")
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                        Heikkinen, Miss Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 887                                      Montvila, Rev. Juozas    male  27.0
# 888                                Graham, Miss Margaret Edith  female  19.0
# 889                    Johnston, Miss Catherine Helen "Carrie"  female   NaN
# 890                                      Behr, Mr. Karl Howell    male  26.0
# 891                                        Dooley, Mr. Patrick    male  32.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S
# ...            ...    ...               ...      ...   ...      ...
# 887              0      0            211536  13.0000   NaN        S
# 888              0      0            112053  30.0000   B42        S
# 889              1      2        W./C. 6607  23.4500   NaN        S
# 890              0      0            111369  30.0000  C148        C
# 891              0      0            370376   7.7500   NaN        Q
#
# [891 rows x 11 columns]

# %%
df.set_index("PassengerId",inplace = True)

# %%
df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                        Heikkinen, Miss Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 887                                      Montvila, Rev. Juozas    male  27.0
# 888                                Graham, Miss Margaret Edith  female  19.0
# 889                    Johnston, Miss Catherine Helen "Carrie"  female   NaN
# 890                                      Behr, Mr. Karl Howell    male  26.0
# 891                                        Dooley, Mr. Patrick    male  32.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S
# ...            ...    ...               ...      ...   ...      ...
# 887              0      0            211536  13.0000   NaN        S
# 888              0      0            112053  30.0000   B42        S
# 889              1      2        W./C. 6607  23.4500   NaN        S
# 890              0      0            111369  30.0000  C148        C
# 891              0      0            370376   7.7500   NaN        Q
#
# [891 rows x 11 columns]

# %%
df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                        Heikkinen, Miss Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S

# %%
df.head(10)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 6                   0       3
# 7                   0       1
# 8                   0       3
# 9                   1       3
# 10                  1       2
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                        Heikkinen, Miss Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# 6                                             Moran, Mr. James    male   NaN
# 7                                      McCarthy, Mr. Timothy J    male  54.0
# 8                                Palsson, Master Gosta Leonard    male   2.0
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 10                         Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S
# 6                0      0            330877   8.4583   NaN        Q
# 7                0      0             17463  51.8625   E46        S
# 8                3      1            349909  21.0750   NaN        S
# 9                0      2            347742  11.1333   NaN        S
# 10               1      0            237736  30.0708   NaN        C

# %%
df.tail()
# Out:
#              Survived  Pclass                                     Name  \
# PassengerId
# 887                 0       2                    Montvila, Rev. Juozas
# 888                 1       1              Graham, Miss Margaret Edith
# 889                 0       3  Johnston, Miss Catherine Helen "Carrie"
# 890                 1       1                    Behr, Mr. Karl Howell
# 891                 0       3                      Dooley, Mr. Patrick
#
#                 Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# PassengerId
# 887            male  27.0      0      0      211536  13.00   NaN        S
# 888          female  19.0      0      0      112053  30.00   B42        S
# 889          female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 890            male  26.0      0      0      111369  30.00  C148        C
# 891            male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.tail(10)
# Out:
#              Survived  Pclass                                     Name  \
# PassengerId
# 882                 0       3                       Markun, Mr. Johann
# 883                 0       3              Dahlberg, Miss Gerda Ulrika
# 884                 0       2            Banfield, Mr. Frederick James
# 885                 0       3                   Sutehall, Mr. Henry Jr
# 886                 0       3     Rice, Mrs. William (Margaret Norton)
# 887                 0       2                    Montvila, Rev. Juozas
# 888                 1       1              Graham, Miss Margaret Edith
# 889                 0       3  Johnston, Miss Catherine Helen "Carrie"
# 890                 1       1                    Behr, Mr. Karl Howell
# 891                 0       3                      Dooley, Mr. Patrick
#
#                 Sex   Age  SibSp  Parch            Ticket     Fare Cabin  \
# PassengerId
# 882            male  33.0      0      0            349257   7.8958   NaN
# 883          female  22.0      0      0              7552  10.5167   NaN
# 884            male  28.0      0      0  C.A./SOTON 34068  10.5000   NaN
# 885            male  25.0      0      0   SOTON/OQ 392076   7.0500   NaN
# 886          female  39.0      0      5            382652  29.1250   NaN
# 887            male  27.0      0      0            211536  13.0000   NaN
# 888          female  19.0      0      0            112053  30.0000   B42
# 889          female   NaN      1      2        W./C. 6607  23.4500   NaN
# 890            male  26.0      0      0            111369  30.0000  C148
# 891            male  32.0      0      0            370376   7.7500   NaN
#
#             Embarked
# PassengerId
# 882                S
# 883                S
# 884                S
# 885                S
# 886                Q
# 887                S
# 888                S
# 889                S
# 890                C
# 891                Q

# %%
df.sample()
# Out:
#              Survived  Pclass                       Name   Sex   Age  SibSp  \
# PassengerId
# 128                 1       3  Madsen, Mr. Fridtjof Arne  male  24.0      0
#
#              Parch   Ticket    Fare Cabin Embarked
# PassengerId
# 128              0  C 17369  7.1417   NaN        S

# %%
df.sample(10)
# Out:
#              Survived  Pclass                           Name     Sex   Age  \
# PassengerId
# 285                 0       1     Smith, Mr. Richard William    male   NaN
# 333                 0       1      Graham, Mr. George Edward    male  38.0
# 597                 1       2      Leitch, Miss Jessie Wills  female   NaN
# 512                 0       3              Webber, Mr. James    male   NaN
# 837                 0       3               Pasic, Mr. Jakob    male  21.0
# 550                 1       2  Davies, Master John Morgan Jr    male   8.0
# 75                  1       3                  Bing, Mr. Lee    male  32.0
# 665                 1       3    Lindqvist, Mr. Eino William    male  20.0
# 383                 0       3             Tikkanen, Mr. Juho    male  32.0
# 488                 0       1        Kent, Mr. Edward Austin    male  58.0
#
#              SibSp  Parch             Ticket      Fare Cabin Embarked
# PassengerId
# 285              0      0             113056   26.0000   A19        S
# 333              0      1           PC 17582  153.4625   C91        S
# 597              0      0             248727   33.0000   NaN        S
# 512              0      0   SOTON/OQ 3101316    8.0500   NaN        S
# 837              0      0             315097    8.6625   NaN        S
# 550              1      1         C.A. 33112   36.7500   NaN        S
# 75               0      0               1601   56.4958   NaN        S
# 665              1      0  STON/O 2. 3101285    7.9250   NaN        S
# 383              0      0  STON/O 2. 3101293    7.9250   NaN        S
# 488              0      0              11771   29.7000   B37        C

# %%
clos =df.columns

# %%
clos
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare', 'Cabin', 'Embarked'],
#       dtype='str')

# %%
rows = df.index

# %%
rows
# Out:
# RangeIndex(start=1, stop=892, step=1, name='PassengerId')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    str
#  3   Sex       891 non-null    str
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    str
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    str
#  10  Embarked  889 non-null    str
# dtypes: float64(2), int64(4), str(5)
# memory usage: 111.7 KB

# %%
df.shape
# Out:
# (891, 11)

# %%
rows_count = df.shape[0]

# %%
rows_count
# Out:
# 891

# %%
columns_count = df.shape[1]

# %%
columns_count
# Out:
# 11

# %%
df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                        Heikkinen, Miss Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 887                                      Montvila, Rev. Juozas    male  27.0
# 888                                Graham, Miss Margaret Edith  female  19.0
# 889                    Johnston, Miss Catherine Helen "Carrie"  female   NaN
# 890                                      Behr, Mr. Karl Howell    male  26.0
# 891                                        Dooley, Mr. Patrick    male  32.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S
# ...            ...    ...               ...      ...   ...      ...
# 887              0      0            211536  13.0000   NaN        S
# 888              0      0            112053  30.0000   B42        S
# 889              1      2        W./C. 6607  23.4500   NaN        S
# 890              0      0            111369  30.0000  C148        C
# 891              0      0            370376   7.7500   NaN        Q
#
# [891 rows x 11 columns]

# %%
df.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df['Age']
# Out:
# PassengerId
# 1      22.0
# 2      38.0
# 3      26.0
# 4      35.0
# 5      35.0
#        ...
# 887    27.0
# 888    19.0
# 889     NaN
# 890    26.0
# 891    32.0
# Name: Age, Length: 891, dtype: float64

# %%
df[["Age"]]
# Out:
#               Age
# PassengerId
# 1            22.0
# 2            38.0
# 3            26.0
# 4            35.0
# 5            35.0
# ...           ...
# 887          27.0
# 888          19.0
# 889           NaN
# 890          26.0
# 891          32.0
#
# [891 rows x 1 columns]

# %%
df[["Age","Pclass"]]
# Out:
#               Age  Pclass
# PassengerId
# 1            22.0       3
# 2            38.0       1
# 3            26.0       3
# 4            35.0       1
# 5            35.0       3
# ...           ...     ...
# 887          27.0       2
# 888          19.0       1
# 889           NaN       3
# 890          26.0       1
# 891          32.0       3
#
# [891 rows x 2 columns]

# %%
df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                        Heikkinen, Miss Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 887                                      Montvila, Rev. Juozas    male  27.0
# 888                                Graham, Miss Margaret Edith  female  19.0
# 889                    Johnston, Miss Catherine Helen "Carrie"  female   NaN
# 890                                      Behr, Mr. Karl Howell    male  26.0
# 891                                        Dooley, Mr. Patrick    male  32.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S
# ...            ...    ...               ...      ...   ...      ...
# 887              0      0            211536  13.0000   NaN        S
# 888              0      0            112053  30.0000   B42        S
# 889              1      2        W./C. 6607  23.4500   NaN        S
# 890              0      0            111369  30.0000  C148        C
# 891              0      0            370376   7.7500   NaN        Q
#
# [891 rows x 11 columns]

# %%
df.loc[6,:]
# Out:
# Survived                   0
# Pclass                     3
# Name        Moran, Mr. James
# Sex                     male
# Age                      NaN
# SibSp                      0
# Parch                      0
# Ticket                330877
# Fare                  8.4583
# Cabin                    NaN
# Embarked                   Q
# Name: 6, dtype: object

# %%
df.loc[6,"Age"]
# Out:
# np.float64(nan)

# %%
df.loc[5:10,"Age":]
# Out:
#               Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# PassengerId
# 5            35.0      0      0  373450   8.0500   NaN        S
# 6             NaN      0      0  330877   8.4583   NaN        Q
# 7            54.0      0      0   17463  51.8625   E46        S
# 8             2.0      3      1  349909  21.0750   NaN        S
# 9            27.0      0      2  347742  11.1333   NaN        S
# 10           14.0      1      0  237736  30.0708   NaN        C

# %%
df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                        Heikkinen, Miss Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 887                                      Montvila, Rev. Juozas    male  27.0
# 888                                Graham, Miss Margaret Edith  female  19.0
# 889                    Johnston, Miss Catherine Helen "Carrie"  female   NaN
# 890                                      Behr, Mr. Karl Howell    male  26.0
# 891                                        Dooley, Mr. Patrick    male  32.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S
# ...            ...    ...               ...      ...   ...      ...
# 887              0      0            211536  13.0000   NaN        S
# 888              0      0            112053  30.0000   B42        S
# 889              1      2        W./C. 6607  23.4500   NaN        S
# 890              0      0            111369  30.0000  C148        C
# 891              0      0            370376   7.7500   NaN        Q
#
# [891 rows x 11 columns]

# %%
df.iloc[5:10,4:]
# Out:
#               Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# PassengerId
# 6             NaN      0      0  330877   8.4583   NaN        Q
# 7            54.0      0      0   17463  51.8625   E46        S
# 8             2.0      3      1  349909  21.0750   NaN        S
# 9            27.0      0      2  347742  11.1333   NaN        S
# 10           14.0      1      0  237736  30.0708   NaN        C

# %%
df.iloc[6,4]
# Out:
# np.float64(54.0)

# %%
df.iloc[[5,9,8,4,10],:]
# Out:
#              Survived  Pclass  \
# PassengerId
# 6                   0       3
# 10                  1       2
# 9                   1       3
# 5                   0       3
# 11                  1       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 6                                             Moran, Mr. James    male   NaN
# 10                         Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 5                                     Allen, Mr. William Henry    male  35.0
# 11                              Sandstrom, Miss Marguerite Rut  female   4.0
#
#              SibSp  Parch   Ticket     Fare Cabin Embarked
# PassengerId
# 6                0      0   330877   8.4583   NaN        Q
# 10               1      0   237736  30.0708   NaN        C
# 9                0      2   347742  11.1333   NaN        S
# 5                0      0   373450   8.0500   NaN        S
# 11               1      1  PP 9549  16.7000    G6        S

# %%
df.info()

# %%
df.nunique()
# Out:
# Survived      2
# Pclass        3
# Name        891
# Sex           2
# Age          88
# SibSp         7
# Parch         7
# Ticket      681
# Fare        248
# Cabin       147
# Embarked      3
# dtype: int64

# %%
df["Survived"].nunique()
# Out:
# 2

# %%
df["Survived"].unique()
# Out:
# array([0, 1])

# %%
df["Embarked"].unique()
# Out:
# <ArrowStringArray>
# ['S', 'C', 'Q', nan]
# Length: 4, dtype: str

# %%
df.isnull()
# Out:
#              Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# PassengerId
# 1               False   False  False  False  False  False  False   False
# 2               False   False  False  False  False  False  False   False
# 3               False   False  False  False  False  False  False   False
# 4               False   False  False  False  False  False  False   False
# 5               False   False  False  False  False  False  False   False
# ...               ...     ...    ...    ...    ...    ...    ...     ...
# 887             False   False  False  False  False  False  False   False
# 888             False   False  False  False  False  False  False   False
# 889             False   False  False  False   True  False  False   False
# 890             False   False  False  False  False  False  False   False
# 891             False   False  False  False  False  False  False   False
#
#               Fare  Cabin  Embarked
# PassengerId
# 1            False   True     False
# 2            False  False     False
# 3            False   True     False
# 4            False  False     False
# 5            False   True     False
# ...            ...    ...       ...
# 887          False   True     False
# 888          False  False     False
# 889          False   True     False
# 890          False  False     False
# 891          False   True     False
#
# [891 rows x 11 columns]

# %%
df.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
df.isnull().mean()*100
# Out:
# Survived     0.000000
# Pclass       0.000000
# Name         0.000000
# Sex          0.000000
# Age         19.865320
# SibSp        0.000000
# Parch        0.000000
# Ticket       0.000000
# Fare         0.000000
# Cabin       77.104377
# Embarked     0.224467
# dtype: float64

# %%
df["Age"]>70
# Out:
# PassengerId
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
#        ...
# 887    False
# 888    False
# 889    False
# 890    False
# 891    False
# Name: Age, Length: 891, dtype: bool

# %%
(df["Age"]>70).sum()
# Out:
# np.int64(5)

# %%
df[df["Age"]>70] # boolean filtering
# Out:
#              Survived  Pclass                                  Name   Sex  \
# PassengerId
# 97                  0       1             Goldschmidt, Mr. George B  male
# 117                 0       3                  Connors, Mr. Patrick  male
# 494                 0       1               Artagaveytia, Mr. Ramon  male
# 631                 1       1  Barkworth, Mr. Algernon Henry Wilson  male
# 852                 0       3                   Svensson, Mr. Johan  male
#
#               Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# PassengerId
# 97           71.0      0      0  PC 17754  34.6542    A5        C
# 117          70.5      0      0    370369   7.7500   NaN        Q
# 494          71.0      0      0  PC 17609  49.5042   NaN        C
# 631          80.0      0      0     27042  30.0000   A23        S
# 852          74.0      0      0    347060   7.7750   NaN        S

# %%
df[(df["Age"]>70) | (df["Age"]<10)]
# Out:
#              Survived  Pclass                                     Name  \
# PassengerId
# 8                   0       3            Palsson, Master Gosta Leonard
# 11                  1       3           Sandstrom, Miss Marguerite Rut
# 17                  0       3                      Rice, Master Eugene
# 25                  0       3             Palsson, Miss Torborg Danira
# 44                  1       2  Laroche, Miss Simonne Marie Anne Andree
# ...               ...     ...                                      ...
# 832                 1       2           Richards, Master George Sibley
# 851                 0       3   Andersson, Master Sigvard Harald Elias
# 852                 0       3                      Svensson, Mr. Johan
# 853                 0       3                   Boulos, Miss Nourelain
# 870                 1       3           Johnson, Master Harold Theodor
#
#                 Sex    Age  SibSp  Parch         Ticket     Fare Cabin  \
# PassengerId
# 8              male   2.00      3      1         349909  21.0750   NaN
# 11           female   4.00      1      1        PP 9549  16.7000    G6
# 17             male   2.00      4      1         382652  29.1250   NaN
# 25           female   8.00      3      1         349909  21.0750   NaN
# 44           female   3.00      1      2  SC/Paris 2123  41.5792   NaN
# ...             ...    ...    ...    ...            ...      ...   ...
# 832            male   0.83      1      1          29106  18.7500   NaN
# 851            male   4.00      4      2         347082  31.2750   NaN
# 852            male  74.00      0      0         347060   7.7750   NaN
# 853          female   9.00      1      1           2678  15.2458   NaN
# 870            male   4.00      1      1         347742  11.1333   NaN
#
#             Embarked
# PassengerId
# 8                  S
# 11                 S
# 17                 Q
# 25                 S
# 44                 C
# ...              ...
# 832                S
# 851                S
# 852                S
# 853                C
# 870                S
#
# [67 rows x 11 columns]

# %%
df

# %%
df["ASD"] = 1+2

# %%
df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                        Heikkinen, Miss Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 887                                      Montvila, Rev. Juozas    male  27.0
# 888                                Graham, Miss Margaret Edith  female  19.0
# 889                    Johnston, Miss Catherine Helen "Carrie"  female   NaN
# 890                                      Behr, Mr. Karl Howell    male  26.0
# 891                                        Dooley, Mr. Patrick    male  32.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked  ASD
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S    3
# 2                1      0          PC 17599  71.2833   C85        C    3
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S    3
# 4                1      0            113803  53.1000  C123        S    3
# 5                0      0            373450   8.0500   NaN        S    3
# ...            ...    ...               ...      ...   ...      ...  ...
# 887              0      0            211536  13.0000   NaN        S    3
# 888              0      0            112053  30.0000   B42        S    3
# 889              1      2        W./C. 6607  23.4500   NaN        S    3
# 890              0      0            111369  30.0000  C148        C    3
# 891              0      0            370376   7.7500   NaN        Q    3
#
# [891 rows x 12 columns]

# %%
df.insert?

# %%
df.insert(2,"Dfgg",0)

# %%
df
# Out:
#              Survived  Pclass  Dfgg  \
# PassengerId
# 1                   0       3     0
# 2                   1       1     0
# 3                   1       3     0
# 4                   1       1     0
# 5                   0       3     0
# ...               ...     ...   ...
# 887                 0       2     0
# 888                 1       1     0
# 889                 0       3     0
# 890                 1       1     0
# 891                 0       3     0
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                        Heikkinen, Miss Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 887                                      Montvila, Rev. Juozas    male  27.0
# 888                                Graham, Miss Margaret Edith  female  19.0
# 889                    Johnston, Miss Catherine Helen "Carrie"  female   NaN
# 890                                      Behr, Mr. Karl Howell    male  26.0
# 891                                        Dooley, Mr. Patrick    male  32.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked  ASD
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S    3
# 2                1      0          PC 17599  71.2833   C85        C    3
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S    3
# 4                1      0            113803  53.1000  C123        S    3
# 5                0      0            373450   8.0500   NaN        S    3
# ...            ...    ...               ...      ...   ...      ...  ...
# 887              0      0            211536  13.0000   NaN        S    3
# 888              0      0            112053  30.0000   B42        S    3
# 889              1      2        W./C. 6607  23.4500   NaN        S    3
# 890              0      0            111369  30.0000  C148        C    3
# 891              0      0            370376   7.7500   NaN        Q    3
#
# [891 rows x 13 columns]

# %%
df.sort_values?

# %%
df.sort_values(by="Age")
# Out:
#              Survived  Pclass  Dfgg                                     Name  \
# PassengerId
# 804                 1       3     0           Thomas, Master Assad Alexander
# 756                 1       2     0                 Hamalainen, Master Viljo
# 645                 1       3     0                    Baclini, Miss Eugenie
# 470                 1       3     0             Baclini, Miss Helene Barbara
# 79                  1       2     0             Caldwell, Master Alden Gates
# ...               ...     ...   ...                                      ...
# 860                 0       3     0                         Razi, Mr. Raihed
# 864                 0       3     0         Sage, Miss Dorothy Edith "Dolly"
# 869                 0       3     0              van Melkebeke, Mr. Philemon
# 879                 0       3     0                       Laleff, Mr. Kristo
# 889                 0       3     0  Johnston, Miss Catherine Helen "Carrie"
#
#                 Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked  \
# PassengerId
# 804            male  0.42      0      1        2625   8.5167   NaN        C
# 756            male  0.67      1      1      250649  14.5000   NaN        S
# 645          female  0.75      2      1        2666  19.2583   NaN        C
# 470          female  0.75      2      1        2666  19.2583   NaN        C
# 79             male  0.83      0      2      248738  29.0000   NaN        S
# ...             ...   ...    ...    ...         ...      ...   ...      ...
# 860            male   NaN      0      0        2629   7.2292   NaN        C
# 864          female   NaN      8      2    CA. 2343  69.5500   NaN        S
# 869            male   NaN      0      0      345777   9.5000   NaN        S
# 879            male   NaN      0      0      349217   7.8958   NaN        S
# 889          female   NaN      1      2  W./C. 6607  23.4500   NaN        S
#
#              ASD
# PassengerId
# 804            3
# 756            3
# 645            3
# 470            3
# 79             3
# ...          ...
# 860            3
# 864            3
# 869            3
# 879            3
# 889            3
#
# [891 rows x 13 columns]

# %%
df.sort_index?

# %%
df.sort_values(by="Age",ascending=False)
# Out:
#              Survived  Pclass  Dfgg                                     Name  \
# PassengerId
# 631                 1       1     0     Barkworth, Mr. Algernon Henry Wilson
# 852                 0       3     0                      Svensson, Mr. Johan
# 494                 0       1     0                  Artagaveytia, Mr. Ramon
# 97                  0       1     0                Goldschmidt, Mr. George B
# 117                 0       3     0                     Connors, Mr. Patrick
# ...               ...     ...   ...                                      ...
# 860                 0       3     0                         Razi, Mr. Raihed
# 864                 0       3     0         Sage, Miss Dorothy Edith "Dolly"
# 869                 0       3     0              van Melkebeke, Mr. Philemon
# 879                 0       3     0                       Laleff, Mr. Kristo
# 889                 0       3     0  Johnston, Miss Catherine Helen "Carrie"
#
#                 Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked  \
# PassengerId
# 631            male  80.0      0      0       27042  30.0000   A23        S
# 852            male  74.0      0      0      347060   7.7750   NaN        S
# 494            male  71.0      0      0    PC 17609  49.5042   NaN        C
# 97             male  71.0      0      0    PC 17754  34.6542    A5        C
# 117            male  70.5      0      0      370369   7.7500   NaN        Q
# ...             ...   ...    ...    ...         ...      ...   ...      ...
# 860            male   NaN      0      0        2629   7.2292   NaN        C
# 864          female   NaN      8      2    CA. 2343  69.5500   NaN        S
# 869            male   NaN      0      0      345777   9.5000   NaN        S
# 879            male   NaN      0      0      349217   7.8958   NaN        S
# 889          female   NaN      1      2  W./C. 6607  23.4500   NaN        S
#
#              ASD
# PassengerId
# 631            3
# 852            3
# 494            3
# 97             3
# 117            3
# ...          ...
# 860            3
# 864            3
# 869            3
# 879            3
# 889            3
#
# [891 rows x 13 columns]

# %%
df.sort_values(by=["Sex","Age"],ascending=[True,False])
# Out:
#              Survived  Pclass  Dfgg  \
# PassengerId
# 276                 1       1     0
# 484                 1       3     0
# 830                 1       1     0
# 367                 1       1     0
# 12                  1       1     0
# ...               ...     ...   ...
# 840                 1       1     0
# 847                 0       3     0
# 860                 0       3     0
# 869                 0       3     0
# 879                 0       3     0
#
#                                                          Name     Sex   Age  \
# PassengerId
# 276                          Andrews, Miss Kornelia Theodosia  female  63.0
# 484                                    Turkula, Mrs. (Hedwig)  female  63.0
# 830                 Stone, Mrs. George Nelson (Martha Evelyn)  female  62.0
# 367          Warren, Mrs. Frank Manley (Anna Sophia Atkinson)  female  60.0
# 12                                    Bonnell, Miss Elizabeth  female  58.0
# ...                                                       ...     ...   ...
# 840                                      Marechal, Mr. Pierre    male   NaN
# 847                                  Sage, Mr. Douglas Bullen    male   NaN
# 860                                          Razi, Mr. Raihed    male   NaN
# 869                               van Melkebeke, Mr. Philemon    male   NaN
# 879                                        Laleff, Mr. Kristo    male   NaN
#
#              SibSp  Parch    Ticket     Fare Cabin Embarked  ASD
# PassengerId
# 276              1      0     13502  77.9583    D7        S    3
# 484              0      0      4134   9.5875   NaN        S    3
# 830              0      0    113572  80.0000   B28      NaN    3
# 367              1      0    110813  75.2500   D37        C    3
# 12               0      0    113783  26.5500  C103        S    3
# ...            ...    ...       ...      ...   ...      ...  ...
# 840              0      0     11774  29.7000   C47        C    3
# 847              8      2  CA. 2343  69.5500   NaN        S    3
# 860              0      0      2629   7.2292   NaN        C    3
# 869              0      0    345777   9.5000   NaN        S    3
# 879              0      0    349217   7.8958   NaN        S    3
#
# [891 rows x 13 columns]

# %%
df.sort_index(ascending= False)
# Out:
#              Survived  Pclass  Dfgg  \
# PassengerId
# 891                 0       3     0
# 890                 1       1     0
# 889                 0       3     0
# 888                 1       1     0
# 887                 0       2     0
# ...               ...     ...   ...
# 5                   0       3     0
# 4                   1       1     0
# 3                   1       3     0
# 2                   1       1     0
# 1                   0       3     0
#
#                                                           Name     Sex   Age  \
# PassengerId
# 891                                        Dooley, Mr. Patrick    male  32.0
# 890                                      Behr, Mr. Karl Howell    male  26.0
# 889                    Johnston, Miss Catherine Helen "Carrie"  female   NaN
# 888                                Graham, Miss Margaret Edith  female  19.0
# 887                                      Montvila, Rev. Juozas    male  27.0
# ...                                                        ...     ...   ...
# 5                                     Allen, Mr. William Henry    male  35.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 3                                        Heikkinen, Miss Laina  female  26.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 1                                      Braund, Mr. Owen Harris    male  22.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked  ASD
# PassengerId
# 891              0      0            370376   7.7500   NaN        Q    3
# 890              0      0            111369  30.0000  C148        C    3
# 889              1      2        W./C. 6607  23.4500   NaN        S    3
# 888              0      0            112053  30.0000   B42        S    3
# 887              0      0            211536  13.0000   NaN        S    3
# ...            ...    ...               ...      ...   ...      ...  ...
# 5                0      0            373450   8.0500   NaN        S    3
# 4                1      0            113803  53.1000  C123        S    3
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S    3
# 2                1      0          PC 17599  71.2833   C85        C    3
# 1                1      0         A/5 21171   7.2500   NaN        S    3
#
# [891 rows x 13 columns]

# %%
df.sort_index(axis = 1,ascending= False)
# Out:
#                        Ticket  Survived  SibSp     Sex  Pclass  Parch  \
# PassengerId
# 1                   A/5 21171         0      1    male       3      0
# 2                    PC 17599         1      1  female       1      0
# 3            STON/O2. 3101282         1      0  female       3      0
# 4                      113803         1      1  female       1      0
# 5                      373450         0      0    male       3      0
# ...                       ...       ...    ...     ...     ...    ...
# 887                    211536         0      0    male       2      0
# 888                    112053         1      0  female       1      0
# 889                W./C. 6607         0      1  female       3      2
# 890                    111369         1      0    male       1      0
# 891                    370376         0      0    male       3      0
#
#                                                           Name     Fare  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris   7.2500
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  71.2833
# 3                                        Heikkinen, Miss Laina   7.9250
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  53.1000
# 5                                     Allen, Mr. William Henry   8.0500
# ...                                                        ...      ...
# 887                                      Montvila, Rev. Juozas  13.0000
# 888                                Graham, Miss Margaret Edith  30.0000
# 889                    Johnston, Miss Catherine Helen "Carrie"  23.4500
# 890                                      Behr, Mr. Karl Howell  30.0000
# 891                                        Dooley, Mr. Patrick   7.7500
#
#             Embarked  Dfgg Cabin   Age  ASD
# PassengerId
# 1                  S     0   NaN  22.0    3
# 2                  C     0   C85  38.0    3
# 3                  S     0   NaN  26.0    3
# 4                  S     0  C123  35.0    3
# 5                  S     0   NaN  35.0    3
# ...              ...   ...   ...   ...  ...
# 887                S     0   NaN  27.0    3
# 888                S     0   B42  19.0    3
# 889                S     0   NaN   NaN    3
# 890                C     0  C148  26.0    3
# 891                Q     0   NaN  32.0    3
#
# [891 rows x 13 columns]

# %%
# axis=1 refers to columns
df.sort_index(axis=1,ascending=False)

# %%
# Select only passengers older than 30
adults = df[df['Age'] > 30]

# %%
adults
# Out:
#              Survived  Pclass  Dfgg  \
# PassengerId
# 2                   1       1     0
# 4                   1       1     0
# 5                   0       3     0
# 7                   0       1     0
# 12                  1       1     0
# ...               ...     ...   ...
# 874                 0       3     0
# 880                 1       1     0
# 882                 0       3     0
# 886                 0       3     0
# 891                 0       3     0
#
#                                                           Name     Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# 7                                      McCarthy, Mr. Timothy J    male  54.0
# 12                                     Bonnell, Miss Elizabeth  female  58.0
# ...                                                        ...     ...   ...
# 874                                Vander Cruyssen, Mr. Victor    male  47.0
# 880              Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0
# 882                                         Markun, Mr. Johann    male  33.0
# 886                       Rice, Mrs. William (Margaret Norton)  female  39.0
# 891                                        Dooley, Mr. Patrick    male  32.0
#
#              SibSp  Parch    Ticket     Fare Cabin Embarked  ASD
# PassengerId
# 2                1      0  PC 17599  71.2833   C85        C    3
# 4                1      0    113803  53.1000  C123        S    3
# 5                0      0    373450   8.0500   NaN        S    3
# 7                0      0     17463  51.8625   E46        S    3
# 12               0      0    113783  26.5500  C103        S    3
# ...            ...    ...       ...      ...   ...      ...  ...
# 874              0      0    345765   9.0000   NaN        S    3
# 880              0      1     11767  83.1583   C50        C    3
# 882              0      0    349257   7.8958   NaN        S    3
# 886              0      5    382652  29.1250   NaN        Q    3
# 891              0      0    370376   7.7500   NaN        Q    3
#
# [305 rows x 13 columns]

# %%
# Select females AND passengers in 1st class
rich_females = df[(df['Sex'] == 'female') & (df['Pclass'] == 1)]

# Select passengers who paid more than $100 OR are in 1st class
high_value = df[(df['Fare'] > 100) | (df['Pclass'] == 1)]

# %%
rich_females
# Out:
#              Survived  Pclass  Dfgg  \
# PassengerId
# 2                   1       1     0
# 4                   1       1     0
# 12                  1       1     0
# 32                  1       1     0
# 53                  1       1     0
# ...               ...     ...   ...
# 857                 1       1     0
# 863                 1       1     0
# 872                 1       1     0
# 880                 1       1     0
# 888                 1       1     0
#
#                                                           Name     Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 12                                     Bonnell, Miss Elizabeth  female  58.0
# 32              Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN
# 53                    Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0
# ...                                                        ...     ...   ...
# 857                 Wick, Mrs. George Dennick (Mary Hitchcock)  female  45.0
# 863          Swift, Mrs. Frederick Joel (Margaret Welles Ba...  female  48.0
# 872           Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0
# 880              Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0
# 888                                Graham, Miss Margaret Edith  female  19.0
#
#              SibSp  Parch    Ticket      Fare Cabin Embarked  ASD
# PassengerId
# 2                1      0  PC 17599   71.2833   C85        C    3
# 4                1      0    113803   53.1000  C123        S    3
# 12               0      0    113783   26.5500  C103        S    3
# 32               1      0  PC 17569  146.5208   B78        C    3
# 53               1      0  PC 17572   76.7292   D33        C    3
# ...            ...    ...       ...       ...   ...      ...  ...
# 857              1      1     36928  164.8667   NaN        S    3
# 863              0      0     17466   25.9292   D17        S    3
# 872              1      1     11751   52.5542   D35        S    3
# 880              0      1     11767   83.1583   C50        C    3
# 888              0      0    112053   30.0000   B42        S    3
#
# [94 rows x 13 columns]

# %%
# Select passengers embarking from Southampton (S) or Cherbourg (C)
ports = df[df['Embarked'].isin(['S', 'C'])]

# %%
ports
# Out:
#              Survived  Pclass  Dfgg  \
# PassengerId
# 1                   0       3     0
# 2                   1       1     0
# 3                   1       3     0
# 4                   1       1     0
# 5                   0       3     0
# ...               ...     ...   ...
# 885                 0       3     0
# 887                 0       2     0
# 888                 1       1     0
# 889                 0       3     0
# 890                 1       1     0
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                        Heikkinen, Miss Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 885                                     Sutehall, Mr. Henry Jr    male  25.0
# 887                                      Montvila, Rev. Juozas    male  27.0
# 888                                Graham, Miss Margaret Edith  female  19.0
# 889                    Johnston, Miss Catherine Helen "Carrie"  female   NaN
# 890                                      Behr, Mr. Karl Howell    male  26.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked  ASD
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S    3
# 2                1      0          PC 17599  71.2833   C85        C    3
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S    3
# 4                1      0            113803  53.1000  C123        S    3
# 5                0      0            373450   8.0500   NaN        S    3
# ...            ...    ...               ...      ...   ...      ...  ...
# 885              0      0   SOTON/OQ 392076   7.0500   NaN        S    3
# 887              0      0            211536  13.0000   NaN        S    3
# 888              0      0            112053  30.0000   B42        S    3
# 889              1      2        W./C. 6607  23.4500   NaN        S    3
# 890              0      0            111369  30.0000  C148        C    3
#
# [812 rows x 13 columns]

# %%
# Select anyone with "Mr." in their name
misters = df[df['Name'].str.contains("Mr.",regex = False)]

# Select names that start with "A"
starts_with_a = df[df['Name'].str.startswith("A")]

# %%
misters
# Out:
#              Survived  Pclass  Dfgg                            Name   Sex  \
# PassengerId
# 1                   0       3     0         Braund, Mr. Owen Harris  male
# 5                   0       3     0        Allen, Mr. William Henry  male
# 6                   0       3     0                Moran, Mr. James  male
# 7                   0       1     0         McCarthy, Mr. Timothy J  male
# 13                  0       3     0  Saundercock, Mr. William Henry  male
# ...               ...     ...   ...                             ...   ...
# 882                 0       3     0              Markun, Mr. Johann  male
# 884                 0       2     0   Banfield, Mr. Frederick James  male
# 885                 0       3     0          Sutehall, Mr. Henry Jr  male
# 890                 1       1     0           Behr, Mr. Karl Howell  male
# 891                 0       3     0             Dooley, Mr. Patrick  male
#
#               Age  SibSp  Parch            Ticket     Fare Cabin Embarked  ASD
# PassengerId
# 1            22.0      1      0         A/5 21171   7.2500   NaN        S    3
# 5            35.0      0      0            373450   8.0500   NaN        S    3
# 6             NaN      0      0            330877   8.4583   NaN        Q    3
# 7            54.0      0      0             17463  51.8625   E46        S    3
# 13           20.0      0      0         A/5. 2151   8.0500   NaN        S    3
# ...           ...    ...    ...               ...      ...   ...      ...  ...
# 882          33.0      0      0            349257   7.8958   NaN        S    3
# 884          28.0      0      0  C.A./SOTON 34068  10.5000   NaN        S    3
# 885          25.0      0      0   SOTON/OQ 392076   7.0500   NaN        S    3
# 890          26.0      0      0            111369  30.0000  C148        C    3
# 891          32.0      0      0            370376   7.7500   NaN        Q    3
#
# [517 rows x 13 columns]

# %%
starts_with_a
# Out:
#              Survived  Pclass  Dfgg  \
# PassengerId
# 5                   0       3     0
# 14                  0       3     0
# 26                  1       3     0
# 41                  0       3     0
# 50                  0       3     0
# 69                  1       3     0
# 92                  0       3     0
# 115                 0       3     0
# 120                 0       3     0
# 145                 0       2     0
# 147                 1       3     0
# 183                 0       3     0
# 193                 1       3     0
# 208                 1       3     0
# 211                 0       3     0
# 234                 1       3     0
# 245                 0       3     0
# 262                 1       3     0
# 276                 1       1     0
# 280                 1       3     0
# 298                 0       1     0
# 306                 1       1     0
# 309                 0       2     0
# 354                 0       3     0
# 364                 0       3     0
# 366                 0       3     0
# 370                 1       1     0
# 402                 0       3     0
# 461                 1       1     0
# 494                 0       1     0
# 499                 0       1     0
# 519                 1       2     0
# 542                 0       3     0
# 543                 0       3     0
# 572                 1       1     0
# 611                 0       3     0
# 701                 1       1     0
# 731                 1       1     0
# 747                 0       3     0
# 781                 1       3     0
# 785                 0       3     0
# 807                 0       1     0
# 811                 0       3     0
# 814                 0       3     0
# 834                 0       3     0
# 835                 0       3     0
# 841                 0       3     0
# 846                 0       3     0
# 851                 0       3     0
# 856                 1       3     0
# 875                 1       2     0
#
#                                                           Name     Sex    Age  \
# PassengerId
# 5                                     Allen, Mr. William Henry    male  35.00
# 14                                 Andersson, Mr. Anders Johan    male  39.00
# 26           Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.00
# 41              Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  female  40.00
# 50               Arnold-Franchi, Mrs. Josef (Josefine Franchi)  female  18.00
# 69                              Andersson, Miss Erna Alexandra  female  17.00
# 92                                  Andreasson, Mr. Paul Edvin    male  20.00
# 115                                       Attalah, Miss Malake  female  17.00
# 120                           Andersson, Miss Ellis Anna Maria  female   2.00
# 145                                 Andrew, Mr. Edgardo Samuel    male  18.00
# 147               Andersson, Mr. August Edvard ("Wennerstrom")    male  27.00
# 183                       Asplund, Master Clarence Gustaf Hugo    male   9.00
# 193             Andersen-Jensen, Miss Carla Christine Nielsine  female  19.00
# 208                                Albimona, Mr. Nassef Cassem    male  26.00
# 211                                             Ali, Mr. Ahmed    male  24.00
# 234                              Asplund, Miss Lillian Gertrud  female   5.00
# 245                                       Attalah, Mr. Sleiman    male  30.00
# 262                           Asplund, Master Edvin Rojj Felix    male   3.00
# 276                           Andrews, Miss Kornelia Theodosia  female  63.00
# 280                           Abbott, Mrs. Stanton (Rosa Hunt)  female  35.00
# 298                                Allison, Miss Helen Loraine  female   2.00
# 306                              Allison, Master Hudson Trevor    male   0.92
# 309                                        Abelson, Mr. Samuel    male  30.00
# 354                                  Arnold-Franchi, Mr. Josef    male  25.00
# 364                                            Asim, Mr. Adola    male  35.00
# 366                             Adahl, Mr. Mauritz Nils Martin    male  30.00
# 370                              Aubart, Mme. Leontine Pauline  female  24.00
# 402                                            Adams, Mr. John    male  26.00
# 461                                        Anderson, Mr. Harry    male  48.00
# 494                                    Artagaveytia, Mr. Ramon    male  71.00
# 499            Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.00
# 519          Angle, Mrs. William A (Florence "Mary" Agnes H...  female  36.00
# 542                        Andersson, Miss Ingeborg Constanzia  female   9.00
# 543                           Andersson, Miss Sigrid Elisabeth  female  11.00
# 572              Appleton, Mrs. Edward Dale (Charlotte Lamson)  female  53.00
# 611          Andersson, Mrs. Anders Johan (Alfrida Konstant...  female  39.00
# 701          Astor, Mrs. John Jacob (Madeleine Talmadge Force)  female  18.00
# 731                               Allen, Miss Elisabeth Walton  female  29.00
# 747                                Abbott, Mr. Rossmore Edward    male  16.00
# 781                                        Ayoub, Miss Banoura  female  13.00
# 785                                           Ali, Mr. William    male  25.00
# 807                                     Andrews, Mr. Thomas Jr    male  39.00
# 811                                     Alexander, Mr. William    male  26.00
# 814                          Andersson, Miss Ebba Iris Alfrida  female   6.00
# 834                                     Augustsson, Mr. Albert    male  23.00
# 835                                     Allum, Mr. Owen George    male  18.00
# 841                                Alhomaki, Mr. Ilmari Rudolf    male  20.00
# 846                                        Abbing, Mr. Anthony    male  42.00
# 851                     Andersson, Master Sigvard Harald Elias    male   4.00
# 856                                 Aks, Mrs. Sam (Leah Rosen)  female  18.00
# 875                      Abelson, Mrs. Samuel (Hannah Wizosky)  female  28.00
#
#              SibSp  Parch              Ticket      Fare    Cabin Embarked  ASD
# PassengerId
# 5                0      0              373450    8.0500      NaN        S    3
# 14               1      5              347082   31.2750      NaN        S    3
# 26               1      5              347077   31.3875      NaN        S    3
# 41               1      0                7546    9.4750      NaN        S    3
# 50               1      0              349237   17.8000      NaN        S    3
# 69               4      2             3101281    7.9250      NaN        S    3
# 92               0      0              347466    7.8542      NaN        S    3
# 115              0      0                2627   14.4583      NaN        C    3
# 120              4      2              347082   31.2750      NaN        S    3
# 145              0      0              231945   11.5000      NaN        S    3
# 147              0      0              350043    7.7958      NaN        S    3
# 183              4      2              347077   31.3875      NaN        S    3
# 193              1      0              350046    7.8542      NaN        S    3
# 208              0      0                2699   18.7875      NaN        C    3
# 211              0      0  SOTON/O.Q. 3101311    7.0500      NaN        S    3
# 234              4      2              347077   31.3875      NaN        S    3
# 245              0      0                2694    7.2250      NaN        C    3
# 262              4      2              347077   31.3875      NaN        S    3
# 276              1      0               13502   77.9583       D7        S    3
# 280              1      1           C.A. 2673   20.2500      NaN        S    3
# 298              1      2              113781  151.5500  C22 C26        S    3
# 306              1      2              113781  151.5500  C22 C26        S    3
# 309              1      0           P/PP 3381   24.0000      NaN        C    3
# 354              1      0              349237   17.8000      NaN        S    3
# 364              0      0  SOTON/O.Q. 3101310    7.0500      NaN        S    3
# 366              0      0              C 7076    7.2500      NaN        S    3
# 370              0      0            PC 17477   69.3000      B35        C    3
# 402              0      0              341826    8.0500      NaN        S    3
# 461              0      0               19952   26.5500      E12        S    3
# 494              0      0            PC 17609   49.5042      NaN        C    3
# 499              1      2              113781  151.5500  C22 C26        S    3
# 519              1      0              226875   26.0000      NaN        S    3
# 542              4      2              347082   31.2750      NaN        S    3
# 543              4      2              347082   31.2750      NaN        S    3
# 572              2      0               11769   51.4792     C101        S    3
# 611              1      5              347082   31.2750      NaN        S    3
# 701              1      0            PC 17757  227.5250  C62 C64        C    3
# 731              0      0               24160  211.3375       B5        S    3
# 747              1      1           C.A. 2673   20.2500      NaN        S    3
# 781              0      0                2687    7.2292      NaN        C    3
# 785              0      0  SOTON/O.Q. 3101312    7.0500      NaN        S    3
# 807              0      0              112050    0.0000      A36        S    3
# 811              0      0                3474    7.8875      NaN        S    3
# 814              4      2              347082   31.2750      NaN        S    3
# 834              0      0              347468    7.8542      NaN        S    3
# 835              0      0                2223    8.3000      NaN        S    3
# 841              0      0    SOTON/O2 3101287    7.9250      NaN        S    3
# 846              0      0           C.A. 5547    7.5500      NaN        S    3
# 851              4      2              347082   31.2750      NaN        S    3
# 856              0      1              392091    9.3500      NaN        S    3
# 875              1      0           P/PP 3381   24.0000      NaN        C    3

# %%
df["Sex"].str.title()
# Out:
# PassengerId
# 1        Male
# 2      Female
# 3      Female
# 4      Female
# 5        Male
#         ...
# 887      Male
# 888    Female
# 889    Female
# 890      Male
# 891      Male
# Name: Sex, Length: 891, dtype: str

# %%
# Same as Method 2, but cleaner to read
rich_females = df.query('Sex == "female" and Pclass == 1')

# %%
rich_females
# Out:
#              Survived  Pclass  Dfgg  \
# PassengerId
# 2                   1       1     0
# 4                   1       1     0
# 12                  1       1     0
# 32                  1       1     0
# 53                  1       1     0
# ...               ...     ...   ...
# 857                 1       1     0
# 863                 1       1     0
# 872                 1       1     0
# 880                 1       1     0
# 888                 1       1     0
#
#                                                           Name     Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 12                                     Bonnell, Miss Elizabeth  female  58.0
# 32              Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN
# 53                    Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0
# ...                                                        ...     ...   ...
# 857                 Wick, Mrs. George Dennick (Mary Hitchcock)  female  45.0
# 863          Swift, Mrs. Frederick Joel (Margaret Welles Ba...  female  48.0
# 872           Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0
# 880              Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0
# 888                                Graham, Miss Margaret Edith  female  19.0
#
#              SibSp  Parch    Ticket      Fare Cabin Embarked  ASD
# PassengerId
# 2                1      0  PC 17599   71.2833   C85        C    3
# 4                1      0    113803   53.1000  C123        S    3
# 12               0      0    113783   26.5500  C103        S    3
# 32               1      0  PC 17569  146.5208   B78        C    3
# 53               1      0  PC 17572   76.7292   D33        C    3
# ...            ...    ...       ...       ...   ...      ...  ...
# 857              1      1     36928  164.8667   NaN        S    3
# 863              0      0     17466   25.9292   D17        S    3
# 872              1      1     11751   52.5542   D35        S    3
# 880              0      1     11767   83.1583   C50        C    3
# 888              0      0    112053   30.0000   B42        S    3
#
# [94 rows x 13 columns]

# %%
rich_females[rich_females["Name"].str.contains("Mrs.",regex = False)]["Survived"].value_counts()
# Out:
# Survived
# 1    41
# 0     1
# Name: count, dtype: int64

# %%
# Shows the count of missing values per column
df.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Dfgg          0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# ASD           0
# dtype: int64

# %%
# Returns True if the column contains any nulls
df.isnull().any()
# Out:
# Survived    False
# Pclass      False
# Dfgg        False
# Name        False
# Sex         False
# Age          True
# SibSp       False
# Parch       False
# Ticket      False
# Fare        False
# Cabin        True
# Embarked     True
# ASD         False
# dtype: bool

# %%
# Counts how many rows are duplicates
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Survived, Pclass, Dfgg, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, ASD]
# Index: []

# %%
# Counts how many rows are duplicates
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.duplicated(subset = ["Sex","Pclass","Embarked"],keep = False)
# Out:
# PassengerId
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
#        ...
# 887    True
# 888    True
# 889    True
# 890    True
# 891    True
# Length: 891, dtype: bool

# %%
df[df["Embarked"] == "Q"]
# Out:
#              Survived  Pclass  Dfgg                                  Name  \
# PassengerId
# 6                   0       3     0                      Moran, Mr. James
# 17                  0       3     0                   Rice, Master Eugene
# 23                  1       3     0            McGowan, Miss Anna "Annie"
# 29                  1       3     0          O'Dwyer, Miss Ellen "Nellie"
# 33                  1       3     0               Glynn, Miss Mary Agatha
# ...               ...     ...   ...                                   ...
# 791                 0       3     0              Keane, Mr. Andrew "Andy"
# 826                 0       3     0                       Flynn, Mr. John
# 829                 1       3     0          McCormack, Mr. Thomas Joseph
# 886                 0       3     0  Rice, Mrs. William (Margaret Norton)
# 891                 0       3     0                   Dooley, Mr. Patrick
#
#                 Sex   Age  SibSp  Parch  Ticket     Fare Cabin Embarked  ASD
# PassengerId
# 6              male   NaN      0      0  330877   8.4583   NaN        Q    3
# 17             male   2.0      4      1  382652  29.1250   NaN        Q    3
# 23           female  15.0      0      0  330923   8.0292   NaN        Q    3
# 29           female   NaN      0      0  330959   7.8792   NaN        Q    3
# 33           female   NaN      0      0  335677   7.7500   NaN        Q    3
# ...             ...   ...    ...    ...     ...      ...   ...      ...  ...
# 791            male   NaN      0      0   12460   7.7500   NaN        Q    3
# 826            male   NaN      0      0  368323   6.9500   NaN        Q    3
# 829            male   NaN      0      0  367228   7.7500   NaN        Q    3
# 886          female  39.0      0      5  382652  29.1250   NaN        Q    3
# 891            male  32.0      0      0  370376   7.7500   NaN        Q    3
#
# [77 rows x 13 columns]

# %%
df.query('Sex == "male" and Pclass == 1 and Embarked == "Q"')
# Out:
#              Survived  Pclass  Dfgg                         Name   Sex   Age  \
# PassengerId
# 246                 0       1     0  Minahan, Dr. William Edward  male  44.0
#
#              SibSp  Parch Ticket  Fare Cabin Embarked  ASD
# PassengerId
# 246              2      0  19928  90.0   C78        Q    3

# %%
df.query('Sex == "female" and Pclass == 1 and Embarked == "Q"')
# Out:
#              Survived  Pclass  Dfgg                   Name     Sex   Age  \
# PassengerId
# 413                 1       1     0  Minahan, Miss Daisy E  female  33.0
#
#              SibSp  Parch Ticket  Fare Cabin Embarked  ASD
# PassengerId
# 413              1      0  19928  90.0   C78        Q    3

# %%
df.query('Sex == "male" and Pclass == 2 and Embarked == "Q"')
# Out:
#              Survived  Pclass  Dfgg                            Name   Sex  \
# PassengerId
# 627                 0       2     0  Kirkland, Rev. Charles Leonard  male
#
#               Age  SibSp  Parch  Ticket   Fare Cabin Embarked  ASD
# PassengerId
# 627          57.0      0      0  219533  12.35   NaN        Q    3

# %%
df[~df.duplicated(subset = ["Sex","Pclass","Embarked"],keep = False)]
# Out:
#              Survived  Pclass  Dfgg                            Name     Sex  \
# PassengerId
# 246                 0       1     0     Minahan, Dr. William Edward    male
# 413                 1       1     0           Minahan, Miss Daisy E  female
# 627                 0       2     0  Kirkland, Rev. Charles Leonard    male
#
#               Age  SibSp  Parch  Ticket   Fare Cabin Embarked  ASD
# PassengerId
# 246          44.0      2      0   19928  90.00   C78        Q    3
# 413          33.0      1      0   19928  90.00   C78        Q    3
# 627          57.0      0      0  219533  12.35   NaN        Q    3

# %%
df[~df.duplicated(subset=["Pclass","Sex","Embarked"],keep = False)]
# Out:
#              Survived  Pclass  Dfgg                            Name     Sex  \
# PassengerId
# 246                 0       1     0     Minahan, Dr. William Edward    male
# 413                 1       1     0           Minahan, Miss Daisy E  female
# 627                 0       2     0  Kirkland, Rev. Charles Leonard    male
#
#               Age  SibSp  Parch  Ticket   Fare Cabin Embarked  ASD
# PassengerId
# 246          44.0      2      0   19928  90.00   C78        Q    3
# 413          33.0      1      0   19928  90.00   C78        Q    3
# 627          57.0      0      0  219533  12.35   NaN        Q    3

# %%
df.query('Pclass == 2 and Embarked == "Q"')
# Out:
#              Survived  Pclass  Dfgg                            Name     Sex  \
# PassengerId
# 304                 1       2     0              Keane, Miss Nora A  female
# 323                 1       2     0        Slayter, Miss Hilda Mary  female
# 627                 0       2     0  Kirkland, Rev. Charles Leonard    male
#
#               Age  SibSp  Parch  Ticket   Fare Cabin Embarked  ASD
# PassengerId
# 304           NaN      0      0  226593  12.35  E101        Q    3
# 323          30.0      0      0  234818  12.35   NaN        Q    3
# 627          57.0      0      0  219533  12.35   NaN        Q    3

# %%
df[df["Embarked"]=="Q"].groupby("Pclass")["Pclass"].count()
# Out:
# Pclass
# 1     2
# 2     3
# 3    72
# Name: Pclass, dtype: int64

# %%
(df[df["Embarked"]=="Q"].groupby("Pclass"))["Sex"].value_counts()
# Out:
# Pclass  Sex
# 1       male       1
#         female     1
# 2       female     2
#         male       1
# 3       male      39
#         female    33
# Name: count, dtype: int64

# %%
# Filters the DataFrame to show only the duplicated rows
df[df.duplicated(keep=False)]

# %%
# Removes duplicate rows, keeping the first occurrence
df.drop_duplicates(subset=["Pclass","Sex","Embarked"],keep = False)

# %%
# Shows the dtype of each column
df.dtypes

# %%
# Converts the 'PassengerId' column to string (object)
s=df['Survived'].astype('str')

# %%
# Converts the 'PassengerId' column to string (object)
z=df['Name'].astype('int',errors = 'ignore')

# %%
z
# Out:
# PassengerId
# 1                                Braund, Mr. Owen Harris
# 2      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3                                  Heikkinen, Miss Laina
# 4           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                               Allen, Mr. William Henry
#                              ...
# 887                                Montvila, Rev. Juozas
# 888                          Graham, Miss Margaret Edith
# 889              Johnston, Miss Catherine Helen "Carrie"
# 890                                Behr, Mr. Karl Howell
# 891                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: str

# %%
# Converts the 'PassengerId' column to string (object)
df.astype?

# %%
s
# Out:
# PassengerId
# 1      0
# 2      1
# 3      1
# 4      1
# 5      0
#       ..
# 887    0
# 888    1
# 889    0
# 890    1
# 891    0
# Name: Survived, Length: 891, dtype: str

# %%
s[1]+s[2]
# Out:
# '01'

# %%
# Shows the count of unique values per column
df.nunique()

# %%
# Shows the counts for each unique value in the 'Embarked' column
df['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
# Shows the counts for each unique value in the 'Sex' column
df['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df["Pclass"].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
df.dtypes
# Out:
# Survived      int64
# Pclass        int64
# Dfgg          int64
# Name            str
# Sex             str
# Age         float64
# SibSp         int64
# Parch         int64
# Ticket          str
# Fare        float64
# Cabin           str
# Embarked        str
# ASD           int64
# dtype: object

# %%
df["Age_New"]=df['Age'].astype(dtype='int64',errors="ignore")

# %%
df
# Out:
#              Survived  Pclass  Dfgg  \
# PassengerId
# 1                   0       3     0
# 2                   1       1     0
# 3                   1       3     0
# 4                   1       1     0
# 5                   0       3     0
# ...               ...     ...   ...
# 887                 0       2     0
# 888                 1       1     0
# 889                 0       3     0
# 890                 1       1     0
# 891                 0       3     0
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                        Heikkinen, Miss Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 887                                      Montvila, Rev. Juozas    male  27.0
# 888                                Graham, Miss Margaret Edith  female  19.0
# 889                    Johnston, Miss Catherine Helen "Carrie"  female   NaN
# 890                                      Behr, Mr. Karl Howell    male  26.0
# 891                                        Dooley, Mr. Patrick    male  32.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked  ASD  \
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S    3
# 2                1      0          PC 17599  71.2833   C85        C    3
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S    3
# 4                1      0            113803  53.1000  C123        S    3
# 5                0      0            373450   8.0500   NaN        S    3
# ...            ...    ...               ...      ...   ...      ...  ...
# 887              0      0            211536  13.0000   NaN        S    3
# 888              0      0            112053  30.0000   B42        S    3
# 889              1      2        W./C. 6607  23.4500   NaN        S    3
# 890              0      0            111369  30.0000  C148        C    3
# 891              0      0            370376   7.7500   NaN        Q    3
#
#              Age_New
# PassengerId
# 1               22.0
# 2               38.0
# 3               26.0
# 4               35.0
# 5               35.0
# ...              ...
# 887             27.0
# 888             19.0
# 889              NaN
# 890             26.0
# 891             32.0
#
# [891 rows x 14 columns]

# %%
pd.to_numeric?
# Out:
# Signature:
# pd.to_numeric(
#     arg,
#     errors: 'DateTimeErrorChoices' = 'raise',
#     downcast: "Literal['integer', 'signed', 'unsigned', 'float'] | None" = None,
#     dtype_backend: 'DtypeBackend | lib.NoDefault' = <no_default>,
# )
# Docstring:
# Convert argument to a numeric type.
#
# If the input is already of a numeric dtype, the dtype will be preserved.
# For non-numeric inputs, the default return dtype is `float64` or `int64`
# depending on the data supplied. Use the `downcast` parameter
# to obtain other dtypes.
#
# Please note that precision loss may occur if really large numbers
# are passed in. Due to the internal limitations of `ndarray`, if
# numbers smaller than `-9223372036854775808` (np.iinfo(np.int64).min)
# or larger than `18446744073709551615` (np.iinfo(np.uint64).max) are
# passed in, it is very likely they will be converted to float so that
# they can be stored in an `ndarray`. These warnings apply similarly to
# `Series` since it internally leverages `ndarray`.
#
# Parameters
# ----------
# arg : scalar, list, tuple, 1-d array, or Series
#     Argument to be converted.
#
# errors : {'raise', 'coerce'}, default 'raise'
#     - If 'raise', then invalid parsing will raise an exception.
#     - If 'coerce', then invalid parsing will be set as NaN.
#
# downcast : str, default None
#     Can be 'integer', 'signed', 'unsigned', or 'float'.
#     If not None, and if the data has been successfully cast to a
#     numerical dtype (or if the data was numeric to begin with),
#     downcast that resulting data to the smallest numerical dtype
#     possible according to the following rules:
#
#     - 'integer' or 'signed': smallest signed int dtype (min.: np.int8)
#     - 'unsigned': smallest unsigned int dtype (min.: np.uint8)
#     - 'float': smallest float dtype (min.: np.float32)
#
#     As this behaviour is separate from the core conversion to
#     numeric values, any errors raised during the downcasting
#     will be surfaced regardless of the value of the 'errors' input.
#
#     In addition, downcasting will only occur if the size
#     of the resulting data's dtype is strictly larger than
#     the dtype it is to be cast to, so if none of the dtypes
#     checked satisfy that specification, no downcasting will be
#     performed on the data.
#
# dtype_backend : {'numpy_nullable', 'pyarrow'}
#     Back-end data type applied to the resultant :class:`DataFrame`
#     (still experimental). If not specified, the default behavior
#     is to not use nullable data types. If specified, the behavior
#     is as follows:
#
#     * ``"numpy_nullable"``: returns nullable-dtype-backed object
#     * ``"pyarrow"``: returns with pyarrow-backed nullable object
#
#     .. versionadded:: 2.0
#
# Returns
# -------
# ret
#     Numeric if parsing succeeded.
#     Return type depends on input.  Series if Series, otherwise ndarray.
#
# Raises
# ------
# ValueError
#     If the input contains non-numeric values and `errors='raise'`.
# TypeError
#     If the input is not list-like, 1D, or scalar convertible to numeric,
#     such as nested lists or unsupported input types (e.g., dict).
#
# See Also
# --------
# DataFrame.astype : Cast argument to a specified dtype.
# to_datetime : Convert argument to datetime.
# to_timedelta : Convert argument to timedelta.
# numpy.ndarray.astype : Cast a numpy array to a specified type.
# DataFrame.convert_dtypes : Convert dtypes.
#
# Examples
# --------
# Take separate series and convert to numeric, coercing when told to
#
# >>> s = pd.Series(["1.0", "2", -3])
# >>> pd.to_numeric(s)
# 0    1.0
# 1    2.0
# 2   -3.0
# dtype: float64
# >>> pd.to_numeric(s, downcast="float")
# 0    1.0
# 1    2.0
# 2   -3.0
# dtype: float32
# >>> pd.to_numeric(s, downcast="signed")
# 0    1
# 1    2
# 2   -3
# dtype: int8
# >>> s = pd.Series(["apple", "1.0", "2", -3])
# >>> pd.to_numeric(s, errors="coerce")
# 0    NaN
# 1    1.0
# 2    2.0
# 3   -3.0
# dtype: float64
#
# Downcasting of nullable integer and floating dtypes is supported:
#
# >>> s = pd.Series([1, 2, 3], dtype="Int64")
# >>> pd.to_numeric(s, downcast="integer")
# 0    1
# 1    2
# 2    3
# dtype: Int8
# >>> s = pd.Series([1.0, 2.1, 3.0], dtype="Float64")
# >>> pd.to_numeric(s, downcast="float")
# 0    1.0
# 1    2.1
# 2    3.0
# dtype: Float32
# File:      c:\users\hp\appdata\local\programs\python\python312\lib\site-packages\pandas\core\tools\numeric.py
# Type:      function

# %%
df["Age_New"]=pd.to_numeric(df['Age'],errors = "coerce")

# %%
df["Ticket_New"]=pd.to_numeric(df['Ticket'],errors = "coerce")

# %%
df
# Out:
#              Survived  Pclass  Dfgg  \
# PassengerId
# 1                   0       3     0
# 2                   1       1     0
# 3                   1       3     0
# 4                   1       1     0
# 5                   0       3     0
# ...               ...     ...   ...
# 887                 0       2     0
# 888                 1       1     0
# 889                 0       3     0
# 890                 1       1     0
# 891                 0       3     0
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                        Heikkinen, Miss Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 887                                      Montvila, Rev. Juozas    male  27.0
# 888                                Graham, Miss Margaret Edith  female  19.0
# 889                    Johnston, Miss Catherine Helen "Carrie"  female   NaN
# 890                                      Behr, Mr. Karl Howell    male  26.0
# 891                                        Dooley, Mr. Patrick    male  32.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked  ASD  \
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S    3
# 2                1      0          PC 17599  71.2833   C85        C    3
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S    3
# 4                1      0            113803  53.1000  C123        S    3
# 5                0      0            373450   8.0500   NaN        S    3
# ...            ...    ...               ...      ...   ...      ...  ...
# 887              0      0            211536  13.0000   NaN        S    3
# 888              0      0            112053  30.0000   B42        S    3
# 889              1      2        W./C. 6607  23.4500   NaN        S    3
# 890              0      0            111369  30.0000  C148        C    3
# 891              0      0            370376   7.7500   NaN        Q    3
#
#              Age_New  Ticket_New
# PassengerId
# 1               22.0         NaN
# 2               38.0         NaN
# 3               26.0         NaN
# 4               35.0    113803.0
# 5               35.0    373450.0
# ...              ...         ...
# 887             27.0    211536.0
# 888             19.0    112053.0
# 889              NaN         NaN
# 890             26.0    111369.0
# 891             32.0    370376.0
#
# [891 rows x 15 columns]

# %%
df[df['Age']<10]

# %%
df.astype?

# %%
df['Ticket']

# %%
df['Ticket'].astype("int")

# %%
df['Ticket'].astype("int",errors = "ignore")

# %%
pd.to_numeric(df['Ticket'])

# %%
pd.to_numeric(df['Ticket'],errors='coerce')

# %%
pd.to_numeric?

# %%
# Convert 'Age' column to integer (int64)
df['Age'].astype('int64')

# Convert 'Sex' column to the more memory-efficient 'category' type
df['Sex'].astype('category')

# Convert a numerical column to string
df['Ticket'].astype(str)

# %%
df['Sex'] = df['Sex'].astype('category')

# %%
df.dtypes

# %%
df['Sex'].cat.remove_categories("male")

# %%
df['Sex'] = df['Sex'].cat.add_categories("other")

# %%
df['Sex'].cat.remove_unused_categories()

# %%
df['Sex'] = df['Sex'].cat.rename_categories({'female':'F','male':'M','other':'O'})

# %%
df

# %%
# Example: Convert 'Fare' which might contain placeholder strings
df['Fare'] = pd.to_numeric(df['Fare'], errors='coerce')

# Now, any non-convertible strings in 'Fare' are set to NaN.
# You can then use df.fillna() or df.drop_na() to handle them.

# %%
df['Name'] = df['Name'].str.replace("Miss","Miss.")

# %%
# Extracts the word after the comma and before the period
df['Title'] = df['Name'].str.extract('([A-Za-z]+)\.')

# %%
df
# Out:
#              Survived  Pclass  Dfgg  \
# PassengerId
# 1                   0       3     0
# 2                   1       1     0
# 3                   1       3     0
# 4                   1       1     0
# 5                   0       3     0
# ...               ...     ...   ...
# 887                 0       2     0
# 888                 1       1     0
# 889                 0       3     0
# 890                 1       1     0
# 891                 0       3     0
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 887                                      Montvila, Rev. Juozas    male  27.0
# 888                               Graham, Miss. Margaret Edith  female  19.0
# 889                   Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 890                                      Behr, Mr. Karl Howell    male  26.0
# 891                                        Dooley, Mr. Patrick    male  32.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked  ASD  \
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S    3
# 2                1      0          PC 17599  71.2833   C85        C    3
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S    3
# 4                1      0            113803  53.1000  C123        S    3
# 5                0      0            373450   8.0500   NaN        S    3
# ...            ...    ...               ...      ...   ...      ...  ...
# 887              0      0            211536  13.0000   NaN        S    3
# 888              0      0            112053  30.0000   B42        S    3
# 889              1      2        W./C. 6607  23.4500   NaN        S    3
# 890              0      0            111369  30.0000  C148        C    3
# 891              0      0            370376   7.7500   NaN        Q    3
#
#              Age_New  Ticket_New Title
# PassengerId
# 1               22.0         NaN    Mr
# 2               38.0         NaN   Mrs
# 3               26.0         NaN  Miss
# 4               35.0    113803.0   Mrs
# 5               35.0    373450.0    Mr
# ...              ...         ...   ...
# 887             27.0    211536.0   Rev
# 888             19.0    112053.0  Miss
# 889              NaN         NaN  Miss
# 890             26.0    111369.0    Mr
# 891             32.0    370376.0    Mr
#
# [891 rows x 16 columns]

# %%
df.dtypes
# Out:
# Survived        int64
# Pclass          int64
# Dfgg            int64
# Name              str
# Sex               str
# Age           float64
# SibSp           int64
# Parch           int64
# Ticket            str
# Fare          float64
# Cabin             str
# Embarked          str
# ASD             int64
# Age_New       float64
# Ticket_New    float64
# Title             str
# dtype: object

# %%
enumerate?
# Out:
# Init signature: enumerate(iterable, start=0)
# Docstring:
# Return an enumerate object.
#
#   iterable
#     an object supporting iteration
#
# The enumerate object yields pairs containing a count (from start, which
# defaults to zero) and a value yielded by the iterable argument.
#
# enumerate is useful for obtaining an indexed list:
#     (0, seq[0]), (1, seq[1]), (2, seq[2]), ...
# Type:           type
# Subclasses:

# %%
title_map = dict(enumerate(df["Title"].unique(),start = 1))

# %%
title_map = {j:i for i,j in title_map.items()}

# %%
df["Title_Num"] = df["Title"].map(title_map)

# %%
df.columns
# Out:
# Index(['Survived', 'Pclass', 'Dfgg', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked', 'ASD', 'Age_New', 'Ticket_New',
#        'Title', 'Title_Num'],
#       dtype='str')

# %%
df.dtypes
# Out:
# Survived        int64
# Pclass          int64
# Dfgg            int64
# Name              str
# Sex               str
# Age           float64
# SibSp           int64
# Parch           int64
# Ticket            str
# Fare          float64
# Cabin             str
# Embarked          str
# ASD             int64
# Age_New       float64
# Ticket_New    float64
# Title             str
# Title_Num       int64
# dtype: object

# %%
[i for i in df.columns if df[i].dtype != "str"]
# Out:
# ['Survived',
#  'Pclass',
#  'Dfgg',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Fare',
#  'ASD',
#  'Age_New',
#  'Ticket_New',
#  'Title_Num']

# %%
df.select_dtypes(exclude="str").columns.tolist()
# Out:
# ['Survived',
#  'Pclass',
#  'Dfgg',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Fare',
#  'ASD',
#  'Age_New',
#  'Ticket_New',
#  'Title_Num']

# %%
num_cols = df.select_dtypes(include="number").columns.tolist()
print(num_cols)
# Out:
# ['Survived', 'Pclass', 'Dfgg', 'Age', 'SibSp', 'Parch', 'Fare', 'ASD', 'Age_New', 'Ticket_New', 'Title_Num']

# %%
df[num_cols].corr()
# Out:
#             Survived    Pclass  Dfgg       Age     SibSp     Parch      Fare  \
# Survived    1.000000 -0.338481   NaN -0.077221 -0.035322  0.081629  0.257307
# Pclass     -0.338481  1.000000   NaN -0.369226  0.083081  0.018443 -0.549500
# Dfgg             NaN       NaN   NaN       NaN       NaN       NaN       NaN
# Age        -0.077221 -0.369226   NaN  1.000000 -0.308247 -0.189119  0.096067
# SibSp      -0.035322  0.083081   NaN -0.308247  1.000000  0.414838  0.159651
# Parch       0.081629  0.018443   NaN -0.189119  0.414838  1.000000  0.216225
# Fare        0.257307 -0.549500   NaN  0.096067  0.159651  0.216225  1.000000
# ASD              NaN       NaN   NaN       NaN       NaN       NaN       NaN
# Age_New    -0.077221 -0.369226   NaN  1.000000 -0.308247 -0.189119  0.096067
# Ticket_New -0.122464  0.275151   NaN -0.148640  0.269342  0.088722 -0.139868
# Title_Num   0.290260 -0.191152   NaN -0.075120  0.148118  0.137145  0.108309
#
#             ASD   Age_New  Ticket_New  Title_Num
# Survived    NaN -0.077221   -0.122464   0.290260
# Pclass      NaN -0.369226    0.275151  -0.191152
# Dfgg        NaN       NaN         NaN        NaN
# Age         NaN  1.000000   -0.148640  -0.075120
# SibSp       NaN -0.308247    0.269342   0.148118
# Parch       NaN -0.189119    0.088722   0.137145
# Fare        NaN  0.096067   -0.139868   0.108309
# ASD         NaN       NaN         NaN        NaN
# Age_New     NaN  1.000000   -0.148640  -0.075120
# Ticket_New  NaN -0.148640    1.000000  -0.019109
# Title_Num   NaN -0.075120   -0.019109   1.000000

# %%
# Convert a standard date string column
df['Date'] = pd.to_datetime(df['DateString'])

# %%
Code,  Meaning,          Example
# %Y,    Year with century,2025
# %m,    Month as a number,12
# %d,    Day of the month,  15
# %b,    Abbreviated month name,Dec

# %%
# Example for a date string like '15-12-2025'
df['PurchaseDate'] = pd.to_datetime(
    df['PurchaseDate'], 
    format='%d-%m-%Y'
)

# %%
df['Title']
# Out:
# PassengerId
# 1       Mr
# 2      Mrs
# 3      NaN
# 4      Mrs
# 5       Mr
#       ...
# 887    Rev
# 888    NaN
# 889    NaN
# 890     Mr
# 891     Mr
# Name: Title, Length: 891, dtype: str

# %%
Attribute,Purpose,Example
.dt.year,Extracts the year as an integer.,df['Date'].dt.year
.dt.month,Extracts the month (1-12).,df['Date'].dt.month
.dt.day,Extracts the day of the month.,df['Date'].dt.day
.dt.day_name(),"Extracts the weekday name (e.g., 'Monday').",df['Date'].dt.day_name()
.dt.is_leap_year,Returns a boolean (True/False).,df['Date'].dt.is_leap_year

# %%
# Extracts the week of the year (01-52)
df['Week_of_Year'] = df['OrderDate'].dt.isocalendar().week

# Filters for data in the first quarter (Jan, Feb, Mar)
q1_data = df[df['OrderDate'].dt.quarter == 1]

# %%
# Convert to 'category' type first
df['Severity'] = df['Severity'].astype('category')

# Define the logical order
new_order = ['Low', 'Medium', 'High', 'Critical']

# Apply the new order
df['Severity'] = df['Severity'].cat.reorder_categories(new_order, ordered=True)

# %%
# Calculate the average Fare paid by passengers in each Pclass (1st, 2nd, 3rd)
df.groupby('Pclass')['Fare'].mean()
# Out:
# Pclass
# 1    84.154687
# 2    20.662183
# 3    13.675550
# Name: Fare, dtype: float64

# %%
# Group by 'Pclass' and calculate:
# 1. The min and max of 'Age'
# 2. The sum of 'Fare'
grouped_stats = df.groupby('Pclass').agg(
    {
        'Age': ['min', 'max'],
        'Fare': 'sum'
    }
)

# %%
grouped_stats
# Out:
#          Age              Fare
#          min   max         sum
# Pclass
# 1       0.92  80.0  18177.4125
# 2       0.67  70.0   3801.8417
# 3       0.42  74.0   6714.6951

# %%
df['Pclass'].value_counts().sort_index()
# Out:
# Pclass
# 1    216
# 2    184
# 3    491
# Name: count, dtype: int64

# %%
df.isna().sum()
# Out:
# Survived        0
# Pclass          0
# Dfgg            0
# Name            0
# Sex             0
# Age           177
# SibSp           0
# Parch           0
# Ticket          0
# Fare            0
# Cabin         687
# Embarked        2
# ASD             0
# Age_New       177
# Ticket_New    230
# Title          40
# Title_Num       0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Survived        0
# Pclass          0
# Dfgg            0
# Name            0
# Sex             0
# Age           177
# SibSp           0
# Parch           0
# Ticket          0
# Fare            0
# Cabin         687
# Embarked        2
# ASD             0
# Age_New       177
# Ticket_New    230
# Title          40
# Title_Num       0
# dtype: int64

# %% [markdown]
# # Missing Data

# %%
df.isna().sum()
# Out:
# Survived        0
# Pclass          0
# Dfgg            0
# Name            0
# Sex             0
# Age           177
# SibSp           0
# Parch           0
# Ticket          0
# Fare            0
# Cabin         687
# Embarked        2
# ASD             0
# Age_New       177
# Ticket_New    230
# Title          40
# Title_Num       0
# dtype: int64

# %%
df.isna().mean()*100
# Out:
# Survived       0.000000
# Pclass         0.000000
# Dfgg           0.000000
# Name           0.000000
# Sex            0.000000
# Age           19.865320
# SibSp          0.000000
# Parch          0.000000
# Ticket         0.000000
# Fare           0.000000
# Cabin         77.104377
# Embarked       0.224467
# ASD            0.000000
# Age_New       19.865320
# Ticket_New     0.448934
# Title          4.489338
# Title_Num      0.000000
# dtype: float64

# %%
df['Ticket_New'] = df['Ticket'].str.extract(r"\b(\d+)")

# %%
df[df['Ticket_New'].isna()][['Ticket_New','Ticket']]
# Out:
#             Ticket_New Ticket
# PassengerId
# 180                NaN   LINE
# 272                NaN   LINE
# 303                NaN   LINE
# 598                NaN   LINE

# %%
df
# Out:
#              Survived  Pclass  Dfgg  \
# PassengerId
# 1                   0       3     0
# 2                   1       1     0
# 3                   1       3     0
# 4                   1       1     0
# 5                   0       3     0
# ...               ...     ...   ...
# 887                 0       2     0
# 888                 1       1     0
# 889                 0       3     0
# 890                 1       1     0
# 891                 0       3     0
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 887                                      Montvila, Rev. Juozas    male  27.0
# 888                               Graham, Miss. Margaret Edith  female  19.0
# 889                   Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 890                                      Behr, Mr. Karl Howell    male  26.0
# 891                                        Dooley, Mr. Patrick    male  32.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked  ASD  \
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S    3
# 2                1      0          PC 17599  71.2833   C85        C    3
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S    3
# 4                1      0            113803  53.1000  C123        S    3
# 5                0      0            373450   8.0500   NaN        S    3
# ...            ...    ...               ...      ...   ...      ...  ...
# 887              0      0            211536  13.0000   NaN        S    3
# 888              0      0            112053  30.0000   B42        S    3
# 889              1      2        W./C. 6607  23.4500   NaN        S    3
# 890              0      0            111369  30.0000  C148        C    3
# 891              0      0            370376   7.7500   NaN        Q    3
#
#              Age_New Ticket_New Title  Title_Num
# PassengerId
# 1               22.0          5    Mr          1
# 2               38.0      17599   Mrs          2
# 3               26.0    3101282  Miss          3
# 4               35.0     113803   Mrs          2
# 5               35.0     373450    Mr          1
# ...              ...        ...   ...        ...
# 887             27.0     211536   Rev          6
# 888             19.0     112053  Miss          3
# 889              NaN       6607  Miss          3
# 890             26.0     111369    Mr          1
# 891             32.0     370376    Mr          1
#
# [891 rows x 17 columns]

# %%
df['Ticket_New'] = df['Ticket_New'].fillna("Ticket Number Not Available")

# %%
df.at[1,'Ticket_New'] = '21171'

# %%
df
# Out:
#              Survived  Pclass  Dfgg  \
# PassengerId
# 1                   0       3     0
# 2                   1       1     0
# 3                   1       3     0
# 4                   1       1     0
# 5                   0       3     0
# ...               ...     ...   ...
# 887                 0       2     0
# 888                 1       1     0
# 889                 0       3     0
# 890                 1       1     0
# 891                 0       3     0
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 887                                      Montvila, Rev. Juozas    male  27.0
# 888                               Graham, Miss. Margaret Edith  female  19.0
# 889                   Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 890                                      Behr, Mr. Karl Howell    male  26.0
# 891                                        Dooley, Mr. Patrick    male  32.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked  ASD  \
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S    3
# 2                1      0          PC 17599  71.2833   C85        C    3
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S    3
# 4                1      0            113803  53.1000  C123        S    3
# 5                0      0            373450   8.0500   NaN        S    3
# ...            ...    ...               ...      ...   ...      ...  ...
# 887              0      0            211536  13.0000   NaN        S    3
# 888              0      0            112053  30.0000   B42        S    3
# 889              1      2        W./C. 6607  23.4500   NaN        S    3
# 890              0      0            111369  30.0000  C148        C    3
# 891              0      0            370376   7.7500   NaN        Q    3
#
#              Age_New Ticket_New Title  Title_Num
# PassengerId
# 1               22.0      21171    Mr          1
# 2               38.0      17599   Mrs          2
# 3               26.0    3101282  Miss          3
# 4               35.0     113803   Mrs          2
# 5               35.0     373450    Mr          1
# ...              ...        ...   ...        ...
# 887             27.0     211536   Rev          6
# 888             19.0     112053  Miss          3
# 889              NaN       6607  Miss          3
# 890             26.0     111369    Mr          1
# 891             32.0     370376    Mr          1
#
# [891 rows x 17 columns]

# %%
df["Embarked_Full"] = df["Embarked"].dropna()

# %%
df[df["Embarked_Full"].isna() ]
# Out:
#              Survived  Pclass  Dfgg  \
# PassengerId
# 62                  1       1     0
# 830                 1       1     0
#
#                                                   Name     Sex   Age  SibSp  \
# PassengerId
# 62                                 Icard, Miss. Amelie  female  38.0      0
# 830          Stone, Mrs. George Nelson (Martha Evelyn)  female  62.0      0
#
#              Parch  Ticket  Fare Cabin Embarked  ASD  Age_New Ticket_New  \
# PassengerId
# 62               0  113572  80.0   B28      NaN    3     38.0     113572
# 830              0  113572  80.0   B28      NaN    3     62.0     113572
#
#             Title  Title_Num Embarked_Full
# PassengerId
# 62           Miss          3           NaN
# 830           Mrs          2           NaN

# %%
df1 = df.dropna(subset = "Embarked_Full")

# %%
df.dropna?
# Out:
# Signature:
# df.dropna(
#     *,
#     axis: 'Axis' = 0,
#     how: 'AnyAll | lib.NoDefault' = <no_default>,
#     thresh: 'int | lib.NoDefault' = <no_default>,
#     subset: 'IndexLabel | AnyArrayLike | None' = None,
#     inplace: 'bool' = False,
#     ignore_index: 'bool' = False,
# ) -> 'DataFrame | None'
# Docstring:
# Remove missing values.
#
# See the :ref:`User Guide <missing_data>` for more on which values are
# considered missing, and how to work with missing data.
#
# Parameters
# ----------
# axis : {0 or 'index', 1 or 'columns'}, default 0
#     Determine if rows or columns which contain missing values are
#     removed.
#
#     * 0, or 'index' : Drop rows which contain missing values.
#     * 1, or 'columns' : Drop columns which contain missing value.
#
#     Only a single axis is allowed.
#
# how : {'any', 'all'}, default 'any'
#     Determine if row or column is removed from DataFrame, when we have
#     at least one NA or all NA.
#
#     * 'any' : If any NA values are present, drop that row or column.
#     * 'all' : If all values are NA, drop that row or column.
#
# thresh : int, optional
#     Require that many non-NA values. Cannot be combined with how.
# subset : column label or iterable of labels, optional
#     Labels along other axis to consider, e.g. if you are dropping rows
#     these would be a list of columns to include.
# inplace : bool, default False
#     Whether to modify the DataFrame rather than creating a new one.
# ignore_index : bool, default ``False``
#     If ``True``, the resulting axis will be labeled 0, 1, …, n - 1.
#
#     .. versionadded:: 2.0.0
#
# Returns
# -------
# DataFrame or None
#     DataFrame with NA entries dropped from it or None if ``inplace=True``.
#
# See Also
# --------
# DataFrame.isna: Indicate missing values.
# DataFrame.notna : Indicate existing (non-missing) values.
# DataFrame.fillna : Replace missing values.
# Series.dropna : Drop missing values.
# Index.dropna : Drop missing indices.
#
# Examples
# --------
# >>> df = pd.DataFrame(
# ...     {
# ...         "name": ["Alfred", "Batman", "Catwoman"],
# ...         "toy": [np.nan, "Batmobile", "Bullwhip"],
# ...         "born": [pd.NaT, pd.Timestamp("1940-04-25"), pd.NaT],
# ...     }
# ... )
# >>> df
#        name        toy       born
# 0    Alfred        NaN        NaT
# 1    Batman  Batmobile 1940-04-25
# 2  Catwoman   Bullwhip        NaT
#
# Drop the rows where at least one element is missing.
#
# >>> df.dropna()
#      name        toy       born
# 1  Batman  Batmobile 1940-04-25
#
# Drop the columns where at least one element is missing.
#
# >>> df.dropna(axis="columns")
#        name
# 0    Alfred
# 1    Batman
# 2  Catwoman
#
# Drop the rows where all elements are missing.
#
# >>> df.dropna(how="all")
#        name        toy       born
# 0    Alfred        NaN        NaT
# 1    Batman  Batmobile 1940-04-25
# 2  Catwoman   Bullwhip        NaT
#
# Keep only the rows with at least 2 non-NA values.
#
# >>> df.dropna(thresh=2)
#        name        toy       born
# 1    Batman  Batmobile 1940-04-25
# 2  Catwoman   Bullwhip        NaT
#
# Define in which columns to look for missing values.
#
# >>> df.dropna(subset=["name", "toy"])
#        name        toy       born
# 1    Batman  Batmobile 1940-04-25
# 2  Catwoman   Bullwhip        NaT
# File:      c:\users\hp\appdata\local\programs\python\python312\lib\site-packages\pandas\core\frame.py
# Type:      method

# %%
df['Embarked'].drop_na?
# Out:
# Object `drop_na` not found.

# %%
df[df['Embarked'].isna()]

# %%
df['Embarked'].unique()

# %%
df.dropna(how="any",axis=1)

# %%
df['Embarked_fill']=df['Embarked'].fillna("Data Missing")

# %%
df

# %%
df['Embarked'].unique()

# %%
df['Embarked_fill'].unique()

# %%
df[df['Embarked'].isnull()]

# %%
embares=df.loc[[60,61,62,63,64,65,828,829,830,831,832],:]

# %%
embares['Embarked'].fillna(method='ffill')

# %%
embares['Embarked'].fillna(method='bfill')

# %%
df['Embarked'].mode()

# %%
df['Embarked'].fillna("S").unique()

# %%
# Filters the DataFrame to show only rows where 'Age' is null
missing_age_rows = df[df['Age'].isnull()]

# %%
# Fills all missing 'Cabin' values with the string 'Unknown'
df['Cabin'].fillna('Unknown', inplace=True)

# %%
# Calculate the median of the 'Age' column
age_median = df['Age'].median()

# Fill the missing 'Age' values with the calculated median
df['Age'].fillna(age_median, inplace=True)

# %% [raw]
# Method,Description,Example
# method='ffill',Forward Fill: Replaces null with the previous non-null value.,"df['StockPrice'].fillna(method='ffill', inplace=True)"
# method='bfill',Backward Fill: Replaces null with the next non-null value.,"df['StockPrice'].fillna(method='bfill', inplace=True)"
