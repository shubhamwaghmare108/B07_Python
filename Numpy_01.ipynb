# %%
import numpy as np

# %%
np.__version__
# Out:
# '1.26.4'

# %%
arr1 = np.array([1,2,3,'4',5,6],dtype=int)

# %%
arr1
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
print(arr1)
# Out:
# ['1' '2' '3' 'sdf' '5' '6']

# %%
arr1.dtype
# Out:
# dtype('int32')

# %%
arr1.size
# Out:
# 6

# %%
arr1.shape
# Out:
# (6,)

# %%
arr1.ndim
# Out:
# 1

# %%
arr1.itemsize
# Out:
# 4

# %%
arr1.nbytes
# Out:
# 24

# %%
arr1.dump("arr1.npy")

# %%
del arr1

# %%
arr1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 arr1
#
# NameError: name 'arr1' is not defined

# %%
arr1 = np.load("arr1.npy",allow_pickle=True)

# %%
arr1
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
import pickle

# %%
list1 = [1,2,3,4,5,6]

# %%
pickle.dump(list1,open("list1.pkl","wb"))

# %%
del list1

# %%
list1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 list1
#
# NameError: name 'list1' is not defined

# %%
list1 = pickle.load(open("list1.pkl","rb"))

# %%
list1
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
arr1
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
arr1[2]
# Out:
# 3

# %%
arr1[2]=56

# %%
arr1
# Out:
# array([ 1,  2, 56,  4,  5,  6])

# %%
del arr1[2]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 del arr1[2]
#
# ValueError: cannot delete array elements

# %%
arr1[0:3]
# Out:
# array([ 1,  2, 56])

# %%
arr1[0:3] =[1,2]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 arr1[0:3] =[1,2]
#
# ValueError: could not broadcast input array from shape (2,) into shape (3,)

# %%
print(arr1.reshape(3,2))
# Out:
# [[1 2]
#  [3 4]
#  [5 6]]

# %%
arr1
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
arr1[0] = 'sdf'

# %%
arr1[0] = '123'

# %%
arr1

# %%
arr1.dtype

# %%
arr1.ndim

# %%
arr1.shape

# %%
arr1.size

# %%
arr1.itemsize

# %%
arr1.nbytes

# %%
arr1.dtype
# Out:
# dtype('int32')

# %%
arr1 = arr1.astype(np.int8)

# %%
arr1.dtype
# Out:
# dtype('int8')

# %%
arr1[0] = 256
# Out:
# C:\Users\SHUBHAM\AppData\Local\Temp\ipykernel_33400\2056697916.py:1: DeprecationWarning: NumPy will stop allowing conversion of out-of-bound Python integers to integer arrays.  The conversion of 256 to int8 will fail in the future.
# For the old behavior, usually:
#     np.array(value).astype(dtype)
# will give the desired result (the cast overflows).
#   arr1[0] = 256

# %%
arr1 =arr1.astype(np.int16)

# %%
arr1[0] = 256

# %%
arr1
# Out:
# array([256,   2,   3,   4,   5,   6], dtype=int16)

# %%
arr1 = arr1.astype(str)

# %%
arr1
# Out:
# array(['256', '2', '3', '4', '5', '6'], dtype='<U6')

# %%
np.resize(arr1,(4,4))
# Out:
# array([['256', '2', '3', '4'],
#        ['5', '6', '256', '2'],
#        ['3', '4', '5', '6'],
#        ['256', '2', '3', '4']], dtype='<U6')

# %%
arr1.resize(10,refcheck=False)

# %%
arr1
# Out:
# array(['256', '2', '3', '4', '', '', '', '', '', ''], dtype='<U6')

# %%
arr1 = np.array([1,2,3,4,5,6])

# %%
arr1.resize(10,refcheck=False)

# %%
arr1
# Out:
# array([1, 2, 3, 4, 5, 6, 0, 0, 0, 0])

# %%
arr1.reshape(5,2)
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6],
#        [0, 0],
#        [0, 0]])

# %%
arr1[0] = 255

# %%
arr2 = np.array((1,6,5,5))

# %%
print(arr2)

# %%
print(type(arr1))

# %%
x = {456,123,789}

# %%
arr3 = np.array(x)

# %%
print(arr3)

# %%
type(arr1)
# Out:
# numpy.ndarray

# %%
type(x)

# %%
type(arr3)

# %% [markdown]
# # Attribute

# %%
arr1.size

# %%
arr1.shape

# %%
arr1.dtype

# %%
arr1

# %%
arr1.ndim

# %%
arr1.itemsize

# %%
arr1.nbytes

# %% [markdown]
# # Array Creation

# %%
arr4 = np.arange(1,1000,2)

# %%
print(arr4)

# %%
arr5 = np.linspace(1,10,500) #linear spaced item

# %%
print(arr5)

# %%
arr5[1] - arr5[0]

# %%
arr5[2] - arr5[1]

# %%
arr5 = np.linspace(1,10,500,endpoint=False) #linear spaced item

# %%
print(arr5)

# %%
matrix_list = [[1,2,3],[4,5,6],[7,8,9]]

# %%
type(matrix_list)

# %%
matrix = np.array(matrix_list)

# %%
matrix

# %%
type(matrix)

# %%
matrix.size

# %%
matrix.shape

# %% [markdown]
# # indexing

# %%
arr2

# %%
arr2[2]

# %%
matrix

# %%
matrix[1,2]

# %%
matrix[1,1]

# %%
matrix[2,2]

# %%
matrix[-2,-2]

# %%
matrix[2,-2]

# %% [markdown]
# # Slicing

# %%
matrix

# %%
matrix[1,:]

# %%
matrix[1,0:2]

# %%
matrix[1,0::2]

# %%
matrix

# %%
matrix[0,0]

# %%
matrix[0,-3]

# %%
matrix[0::2,0]

# %%
x = np.arange(12)

# %%
x.ndim

# %%
X = x.reshape((3,2,2))

# %%
X

# %%
X[0,0,0]

# %%
X[0,0,1]

# %%
X[1,0,0]

# %%
X.shape

# %%
X.size

# %%
X

# %%
X[1,1,1] # (last:column,secondlast:row,thirdlast:page)

# %%
X[0,1,0]

# %%
X

# %%
X[0,1,:]

# %%
y = np.arange(36)

# %%
y = y.reshape(3,3,4)

# %%
y

# %%
y[1,1,0::2]

# %%
y = y.astype("float")

# %%
y.dtype

# %%
y

# %%
iter_a = range(10)

# %%
np.fromiter(iter_a,dtype = "int")

# %%
str1 = "shubham"
str1 = iter(str1)

# %%
np.zeros(3)

# %%
np.ones(10)

# %%
np.ones(10).size

# %%
np.empty((2,2))

# %%
np.zeros((3,3))

# %%
z = np.ones((5,6))

# %%
z[1,3] = 56

# %%
z

# %%
np.full(3,2)

# %%
np.full((3,3),5)

# %%
np.ones((3,3))*5

# %%
np.eye(3,1)

# %%
np.eye(3,k = -1)

# %%
np.eye(3)

# %%
np.eye?

# %%
np.identity(3)

# %%
np.identity(5)

# %%
np.identity(6)

# %%
np.identity?

# %%
np.diag?

# %%
a = np.arange(3,7).reshape(2,2)

# %%
a

# %%
b = np.diag(a)

# %%
b

# %%
np.diag(a,k = -1)

# %%
np.diag(b)

# %%
np.random.rand(100)

# %%
np.random.rand?

# %%
np.random.rand(3,3)

# %%
np.random.rand(3,5,2)

# %%
c = np.random.randn(10000) # normally distributed

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(c)

# %%
np.random.randint(2,10, size=(2,3))

# %%
np.random.seed(5)
otp = np.random.randint(10,size = 4)

# %%
otp

# %%
np.random.seed(5)

# %%
np.random.random(10) # 0 to 1 # probability

# %%
list1 = [1,40,56]

# %%
np.random.choice(list1)

# %%
com = 0
player = 0

# %%
list_choice = ["rock","paper","scissor"]

# %%
com_choice = np.random.choice(list_choice)

# %%
player_choice = list_choice[int(input(f"{list(enumerate(list_choice))}"))]

# %%
if com_choice == player_choice:
    print("tie")
elif com_choice == "rock" and player_choice == "sciser":
    com += 1
    print("com win")
else:
    player += 1
    print("player win")

# %%
com

# %%
player

# %%
np.random.seed(0) # lock or reproduce results
print("Reproducible random:", np.random.choice(list_choice))

# %%
print("Reproducible random:", np.random.choice(list_choice))

# %%
 np.random.shuffle(list_choice)

# %%
list_choice = np.array(list_choice)

# %%
list_choice.T

# %%
t1 = np.arange(12).reshape(4,3)

# %%
t1

# %%
t1.T

# %%
t1.sum(axis=0)

# %%
t1.sum(axis=1)

# %%
t1.sum()
