# %% [markdown]
# # Control Flow

# %% [markdown]
# ## If-elif-else

# %%
name = input("Enter Your Name:\n") # stroge in str form
print(type(name))
print(f"Hello,{name}")
print("Hello,",name)
# Out:
# Enter Your Name:
#  shubham
# <class 'str'>
# Hello,shubham
# Hello, shubham

# %%
age = int(input("enter your age:"))
if age>=18:
    print("you are eligible for voter registration")
else:
    print("not eligible")
# Out:
# enter your age: 15
# not eligible

# %%
age = int(input("enter your age:"))
if age>=18:
    print("you are eligible for voter registration")
print(213)
# Out:
# enter your age: 26
# you are eligible for voter registration
# 213

# %%
age = int(input("enter your age:"))
if age>=18:
    print("you are eligible for voter registration")
else:
    print("not eligible")
print("Done")
# Out:
# enter your age: 56
# you are eligible for voter registration
# Done

# %%
age = int(input("enter your age:"))
if age==18:
    print("you are eligible for voter registration")
else:
    print("if not executed")
print("Done")
# Out:
# enter your age: 19
# if not executed
# Done

# %%
current_light = input("enter color\n")

if current_light == "red":
    print("Traffic Light is RED: STOP! Do not proceed.")

elif current_light == "yellow":
    print("Traffic Light is YELLOW: Prepare to stop. \
    Clear the intersection if it is safe to do so.")

elif current_light == "green":
    print("Traffic Light is GREEN: PROCEED with caution.")

else:
    print("Invalid traffic light state. Something is wrong!")
# Out:
# enter color
#  Green
# Invalid traffic light state. Something is wrong!

# %%
current_light = input("enter color  ").lower()
if current_light == "red":
    print("Traffic Light is RED: STOP! Do not proceed.")
elif current_light == "yellow":
    print("Traffic Light is YELLOW: Prepare to stop. Clear the intersection if it is safe to do so.")
elif current_light == "green":
    print("Traffic Light is GREEN: PROCEED with caution.")
else:
    print("Invalid traffic light state. Something is wrong!")
# Out:
# enter color   YELLOW
# Traffic Light is YELLOW: Prepare to stop. Clear the intersection if it is safe to do so.

# %%
name = "shubham"
if "y" in name:
    print("Yes")
else:
    print("no")
# Out:
# no

# %%
name = "shubhamy" # nested structure
if "y" in name:
    print("y")
    if "s" in name:
        print("s")
    if "g" in name:
        print("g")
else:
    print("there is no 'y' in name")
print("out")
# Out:
# y
# s
# out

# %%
if True:
    print("ok")
# Out:
# ok

# %%
age =60
has_membership= True

if age>60 and has_membership==True:
    print("Eligible for discount")

else:
    print("not eligible")
# Out:
# not eligible

# %%
a = 333
b = 200
if b > a:
    print("b is greater than a")
elif b==a:
    print("b is equal to a")
else:
    print("b is less than a")
# Out:
# b is less than a

# %%
a = 34
b = 33
if b > a:
  print("b is greater than a")
elif a == b:
  print("a and b are equal")
print("out")
# Out:
# out

# %%
a = 200
b = 333
if b > a:
  print("a is greater than b")
elif a == b:
  print("a and b are equal")
else:
  print("a is greater than b")
# Out:
# a is greater than b

# %%
a = 200
b = 33
c = 500
if a > b and c > a:
    print("c is greater than a and b")
    
    print("Both conditions are True")
# Out:
# c is greater than a and b
# Both conditions are True

# %%
a = 200
b = 33
c = 500
if a > b or a > c:
  print("At least one of the conditions is True")
# Out:
# At least one of the conditions is True

# %%
a = 33
b = 200
if not a > b:
  print("a is NOT greater than b")
# Out:
# a is NOT greater than b

# %%
x = 41

if x > 10:
  print("Above ten,")
  if x > 20:
    print("and also above 20!")
  else:
    print("but not above 20.")
# Out:
# Above ten,
# and also above 20!

# %%
x = 15

if x > 10:
  print("Above ten,")
  if x > 20:
    print("and also above 20!")
  else:
    print("but not above 20.")

else:
    pass
# Out:
# Above ten,
# but not above 20.

# %%
x = 20

if x > 10:
  print("Above ten,")
  if x > 20:
    print("and also above 20!")
  else:
    print("but not above 20.")

else:
    pass

# %%
x = 10

if x > 10:
    print("Above ten,")
    if x > 20:
      print("and also above 20!")
    else:
      print("but not above 20.")

else:
    print("less than or equal to 10")
