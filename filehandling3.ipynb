# %%
file = open("asdfghj.txt",'r')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 file = open("asdfghj.txt",'r')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'asdfghj.txt'

# %%
file = open("asdfghj.txt",'x')

# %%
file.close()

# %%
file = open("asdfghj.txt",'r')

# %%
file.read()
# Out:
# ''

# %%
file.write("Hello")
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 file.write("Hello")
#
# UnsupportedOperation: not writable

# %%
file.close()

# %%
file = open("asdfghj.txt",'w')

# %%
file.read()
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 file.read()
#
# UnsupportedOperation: not readable

# %%
file.write("Hello")
# Out:
# 5

# %%
file.tell()
# Out:
# 5

# %%
file.seek(0,0)
# Out:
# 0

# %%
file.tell()
# Out:
# 0

# %%
file.write("123")
# Out:
# 3

# %%
file.close()

# %%
file = open("asdfghj.txt",'w')

# %%
file.close()

# %%
file = open("asdfghj.txt",'w')

# %%
file.write("123")
# Out:
# 3

# %%
file.tell()
# Out:
# 3

# %%
file.write("123")
# Out:
# 3

# %%
file.close()

# %%
file = open("asdfghj.txt",'a+')

# %%
file.tell()
# Out:
# 9

# %%
file.seek(0,0)
# Out:
# 0

# %%
file.tell()
# Out:
# 0

# %%
file.read()
# Out:
# '123123asd'

# %%
file.read()
# Out:
# ''

# %% [raw]
# file.write("123")

# %%
file.write("123")
# Out:
# 3

# %%
file.close()
