# %% [markdown]
# ## How to create an empty dict

# %%
contact_list = {}
# contact_list = dict()

# %%
contact_list.update?
# Out:
# Docstring:
# D.update([E, ]**F) -> None.  Update D from dict/iterable E and F.
# If E is present and has a .keys() method, then does:  for k in E: D[k] = E[k]
# If E is present and lacks a .keys() method, then does:  for k, v in E: D[k] = v
# In either case, this is followed by: for k in F:  D[k] = F[k]
# Type:      builtin_function_or_method

# %%
contact_list.update({"Shubham":8983471527})

# %%
contact_list
# Out:
# {'Shubham': 8983471527}

# %%
print("Call shubham")
print("Dial number",contact_list["Shubham"])
# Out:
# Call shubham
# Dial number 8983471527

# %%
contact_list.update({"Shubham":9373621299})

# %%
contact_list["Shubham"]
# Out:
# 9373621299

# %%
contact_list.update({"Shubham":[]})

# %%
contact_list["Shubham"]
# Out:
# []

# %%
contact_list["Shubham"].append(8983471527)

# %%
contact_list["Shubham"]
# Out:
# [8983471527]

# %%
contact_list["Shubham"].append(9373621299)

# %%
contact_list
# Out:
# {'Shubham': [8983471527, 9373621299]}

# %%
contact_list["Shubham"].remove(9373621299)

# %%
contact_list
# Out:
# {'Shubham': [8983471527]}

# %%
contact_list.update({"Raj":[]})
contact_list["Raj"].append(9373621299)

# %%
name = input("Search Contact : ").title()

contact = contact_list[name]
print(dict(enumerate(contact)))
contact = dict(enumerate(contact))
choice = int(input(f"Enter number choice {contact.keys()}: "))
number = contact[choice]
print(f"calling {name}")
print(f"Trying to connect {name} on number {number}")
# Out:
# Search Contact :  shubham
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[45], line 3
#       1 name = input("Search Contact : ").title()
#       2
# ----> 3 contact = contact_list[name]
#       4 print(dict(enumerate(contact)))
#       5 contact = dict(enumerate(contact))
#       6 choice = int(input(f"Enter number choice {contact.keys()}: "))
#
# KeyError: 'Shubham'

# %%
contact_list.pop?

# %%
contact_list.pop("Shubham")
# Out:
# [8983471527, 9373621299]

# %%
contact_list.pop("Shubham")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 contact_list.pop("Shubham")
#
# KeyError: 'Shubham'

# %%
contact_list.pop("Shubham","Contact not found")
# Out:
# 'Contact not found'

# %%
contact_list
# Out:
# {'Raj': [9373621299]}

# %%
contact_list["Shubham"] = []

# %%
contact_list
# Out:
# {'Raj': [9373621299], 'Shubham': []}

# %%
contact_list["Shubham"].append(9373621299)

# %%
contact_list
# Out:
# {'Raj': [9373621299], 'Shubham': [9373621299]}

# %%
contact_list.update({(1,2,3):"sdvb"})

# %%
contact_list
# Out:
# {'Raj': [9373621299], 'Shubham': [9373621299], (1, 2, 3): 'sdvb'}

# %%
contact_list.pop("Shubham","Contact not found")
# Out:
# 'Contact not found'

# %%
contact_list.popitem?
# Out:
# Signature: contact_list.popitem()
# Docstring:
# Remove and return a (key, value) pair as a 2-tuple.
#
# Pairs are returned in LIFO (last-in, first-out) order.
# Raises KeyError if the dict is empty.
# Type:      builtin_function_or_method

# %%
contact_list.popitem()
# Out:
# ((1, 2, 3), 'sdvb')

# %%
contact_list.update({(1,2,3):"sdkl"})

# %%
contact_list.popitem()
# Out:
# ((1, 2, 3), 'sdkl')

# %%
contact_list
# Out:
# {'Raj': [9373621299]}

# %%
hash(123)

# %%
hash("shubham")

# %%
contact_list.clear()

# %%
contact_list
# Out:
# {}

# %%
contact_list.update({"Shubham":[8983471527,9373621299],"Raj":[4564567891]})

# %%
contact_list
# Out:
# {'Shubham': [8983471527, 9373621299], 'Raj': [4564567891]}

# %%
contact_list.update({"Pratik":[1489653278]})

# %%
contact_list
# Out:
# {'Shubham': [8983471527, 9373621299],
#  'Raj': [4564567891],
#  'Pratik': [1489653278]}

# %%
contact_list.keys()
# Out:
# dict_keys(['Shubham', 'Raj', 'Pratik'])

# %%
contact_list.values()
# Out:
# dict_values([[8983471527, 9373621299], [4564567891], [1489653278]])

# %%
contact_list.items()
# Out:
# dict_items([('Shubham', [8983471527, 9373621299]), ('Raj', [4564567891]), ('Pratik', [1489653278])])

# %%
dict1 = dict()

# %%
type(dict1)
# Out:
# dict

# %%
dict1
# Out:
# {}

# %%
dict1["Name"]= "Shubham"

# %%
dict1
# Out:
# {'Name': 'Shubham'}

# %%
dict1["Name"] # there shall be no duplicate key
# Out:
# 'Shubham'

# %%
dict1["Name"] ="Ravi"

# %%
dict1
# Out:
# {'Name': 'Ravi'}

# %% [markdown]
# ## no integer based indexing,but key based

# %%
del dict1["Name"]

# %%
dict1
# Out:
# {}

# %%
dict1["Name"] ="Ravi"

# %%
dict1["Age"] =30

# %%
dict1
# Out:
# {'Name': 'Ravi', 'Age': 30}

# %%
for i in dict1: # loop on Key
    print(i)
# Out:
# Name
# Age

# %%
dict1
# Out:
# {'Name': 'Ravi', 'Age': 30}

# %%
dict1['Age1']=30

# %%
dict1
# Out:
# {'Name': 'Ravi', 'Age': 30, 'Age1': 30}

# %% [markdown]
# ## key should be hashable

# %%
dict1[1]=123

# %%
dict1
# Out:
# {'Name': 'Ravi', 'Age': 30, 'Age1': 30, 1: 123}

# %%
dict1[1]
# Out:
# 123

# %%
hash([1,2,4,3])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 hash([1,2,4,3])
#
# TypeError: unhashable type: 'list'

# %%
dict1[[1,2,4,3]] = "asdh"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 dict1[[1,2,4,3]] = "asdh"
#
# TypeError: unhashable type: 'list'

# %%
dict1[{1,2,4,3}] = "asdh"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 dict1[{1,2,4,3}] = "asdh"
#
# TypeError: unhashable type: 'set'

# %%
dict1[(1,2,4,3)] = "asdh"

# %%
dict1
# Out:
# {'Name': 'Ravi', 'Age': 30, 'Age1': 30, 1: 123, (1, 2, 4, 3): 'asdh'}

# %%
len(dict1)
# Out:
# 5

# %%
dict1[([1,2],4,3)] = "asdh"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 dict1[([1,2],4,3)] = "asdh"
#
# TypeError: unhashable type: 'list'

# %% [markdown]
# ## Key rule

# %% [markdown]
# 1. No duplicate
# 2. Non hashable is not allowed

# %%
dict2 = dict1.copy()

# %%
dict2
# Out:
# {'Name': 'Ravi', 'Age': 30, 'Age1': 30, 1: 123, (1, 2, 4, 3): 'asdh'}

# %%
dict2.clear()

# %%
dict2
# Out:
# {}

# %%
dict1[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[84], line 1
# ----> 1 dict1[0]
#
# KeyError: 0

# %%
dict1.get(0)

# %%
dict1.get?

# %%
dict1.get(0,"Not Found")
# Out:
# 'Not Found'

# %%
dict1
# Out:
# {'Name': 'Ravi', 'Age': 30, 'Age1': 30, 1: 123, (1, 2, 4, 3): 'asdh'}

# %%
dict1.setdefault(0) # default=none

# %%
dict1
# Out:
# {'Name': 'Ravi', 'Age': 30, 'Age1': 30, 1: 123, (1, 2, 4, 3): 'asdh', 0: None}

# %%
print(dict1.setdefault(0,"Not Found"))
# Out:
# None

# %%
dict1.setdefault(10,"Not Found")
# Out:
# 'Not Found'

# %%
dict1
# Out:
# {'Name': 'Ravi',
#  'Age': 30,
#  'Age1': 30,
#  1: 123,
#  (1, 2, 4, 3): 'asdh',
#  0: None,
#  10: 'Not Found'}

# %% [markdown]
# ## Dict ordered

# %%
dict1[{1:"sf",2:"dfh"}] = 123
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[95], line 1
# ----> 1 dict1[{1:"sf",2:"dfh"}] = 123
#
# TypeError: unhashable type: 'dict'

# %%
dict1.items()
# Out:
# dict_items([('Name', 'Ravi'), ('Age', 30), ('Age1', 30), (1, 123), ((1, 2, 4, 3), 'asdh'), (0, None), (10, 'Not Found')])

# %%
dict1.keys()
# Out:
# dict_keys(['Name', 'Age', 'Age1', 1, (1, 2, 4, 3), 0, 10])

# %%
dict1.values()
# Out:
# dict_values(['Ravi', 30, 30, 123, 'asdh', None, 'Not Found'])

# %%
dict1.keys?

# %%
dict1.values?

# %%
dict1.items?

# %%
for i,j in dict1.items():
    print(i,"====>>",j)

# %%
dict1.update?

# %%
dict1

# %%
dict1.update({"Name":"Shubham","City":"Nagpur"})

# %%
dict1

# %%
dict2

# %%
dict2.update({"Name":"Ravi","Age":29})

# %%
dict2

# %%
dict2.update({"Name":"Shubham"})

# %%
dict2

# %%
dict2.fromkeys?

# %%
dict2.fromkeys("Shubham",29)
# Out:
# {'S': 29, 'h': 29, 'u': 29, 'b': 29, 'a': 29, 'm': 29}

# %%
result  = {}.fromkeys("qwertyuiopasdfghjklzxcvbnm",0)

# %%
result
# Out:
# {'q': 0,
#  'w': 0,
#  'e': 0,
#  'r': 0,
#  't': 0,
#  'y': 0,
#  'u': 0,
#  'i': 0,
#  'o': 0,
#  'p': 0,
#  'a': 0,
#  's': 0,
#  'd': 0,
#  'f': 0,
#  'g': 0,
#  'h': 0,
#  'j': 0,
#  'k': 0,
#  'l': 0,
#  'z': 0,
#  'x': 0,
#  'c': 0,
#  'v': 0,
#  'b': 0,
#  'n': 0,
#  'm': 0}

# %%
input_text = "We are learning Data Science"

# %%
dict2.fromkeys("Shubham")

# %%
for i in input_text:
    if i.lower() in result.keys():
        result[i.lower()] += 1
    else:
        result[i.lower()] = 1

# %%
result
# Out:
# {'q': 0,
#  'w': 2,
#  'e': 6,
#  'r': 2,
#  't': 1,
#  'y': 0,
#  'u': 0,
#  'i': 2,
#  'o': 0,
#  'p': 0,
#  'a': 4,
#  's': 1,
#  'd': 1,
#  'f': 0,
#  'g': 1,
#  'h': 0,
#  'j': 0,
#  'k': 0,
#  'l': 1,
#  'z': 0,
#  'x': 0,
#  'c': 2,
#  'v': 0,
#  'b': 0,
#  'n': 3,
#  'm': 0,
#  ' ': 4}

# %%
inp_text = "We are learning Data Science"

result = {}

for i in inp_text.lower():
    result[i] = result.get(i, 0) + 1

print(result)

# %%
def get_count(word):
    print(result.get(word,0))

# %%
get_count(1)
# Out:
# 0

# %%
dict2.fromkeys("Shubham",[1,2,3,4,5,6,7])

# %%
dict2

# %%
lis = [1,5,6,4,5,8,9,5,6,4,2,2,3,1]
result = dict2.fromkeys(set(lis),0)

# %%
result

# %%
for i in lis:
    if i in result.keys():
        result[i]+=1

# %%
result

# %%
user_input = input("What you want to count?/n")
print(f"you ask for {user_input}'s count and here is your count result {result.get(user_input,0)}.")
# Out:
# What you want to count?/n a
# you ask for a's count and here is your count result 4.

# %%
dict2.pop?

# %%
dict2

# %%
dict2.pop('Age')

# %%
dict2

# %%
dict2.popitem?

# %%
dict2.popitem()
