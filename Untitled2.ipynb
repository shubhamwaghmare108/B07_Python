# %%
name = input("Enter Your Name : ").isalpha()
# Out:
# Enter Your Name :  123

# %%
name
# Out:
# False

# %%
if name == False:
    name = input("Enter Your Name : ").isalpha()
# Out:
# Enter Your Name :  123

# %%
name = False
while name == False:
    name = input("Enter Your First Name : ").isalpha()
# Out:
# Enter Your First Name :  shubham waghmate
# Enter Your First Name :  shubham
