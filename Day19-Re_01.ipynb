# %%
import re

# %%
txt="adssfogf hhhhhhho"
print(re.search("h*o$",txt))
# Out:
# <re.Match object; span=(9, 17), match='hhhhhhho'>

# %%
txt[9:11]
# Out:
# 'ho'

# %%
txt[11:12]

# %%
address="ward no.2, 441111 new koradi 441112"
print(re.findall("\d{6}",address))
# Out:
# ['441111', '441112']

# %%
tet="colour"
tet1="colour  colour color"
print(re.findall("colou?r",tet1))
# Out:
# ['colour', 'colour', 'color']

# %%
tez="aaaaaaaaaaaaaaaaaaa"
print(re.search("a{6,9}",tez))

# %%
text = "My number is 898347152715526 and my parent num is 8986532569 "

re.findall("(\d{10})",text)
# Out:
# ['8983471527', '8986532569']

# %%
text2 = "yes or no"
re.findall("yes|no",text2)
# Out:
# ['yes', 'no']

# %%
test = "hmy name hhhhh naae       123 is shubhhm"
re.findall("h{2,4}",test)
# Out:
# ['hhhh', 'hh']

# %%
re.findall("na.e",test)
# Out:
# ['name', 'naae']

# %%
re.search("^v",test)

# %%
re.search("h.m$",test)
# Out:
# <re.Match object; span=(30, 33), match='hhm'>

# %%
test
# Out:
# 'hhhhmy name hhhhh naae is shubhhm'

# %%
re.search("h.?m",test) # ham,hm
# Out:
# <re.Match object; span=(0, 2), match='hm'>

# %%
re.findall("h+",test)
# Out:
# ['h', 'hhhhh', 'h', 'hh']

# %%
test
# Out:
# 'hmy name hhhhh naae is shubhhm'

# %%
re.search("[asd]",test)
# Out:
# <re.Match object; span=(5, 6), match='a'>

# %%
re.findall("[asd]",test)
# Out:
# ['a', 'a', 'a', 's', 's']

# %%
re.findall("[^asd]",test)
# Out:
# ['h',
#  'm',
#  'y',
#  ' ',
#  'n',
#  'm',
#  'e',
#  ' ',
#  'h',
#  'h',
#  'h',
#  'h',
#  'h',
#  ' ',
#  'n',
#  'e',
#  ' ',
#  'i',
#  ' ',
#  'h',
#  'u',
#  'b',
#  'h',
#  'h',
#  'm']

# %%
re.findall("[a-z]",test)
# Out:
# ['h',
#  'm',
#  'y',
#  'n',
#  'a',
#  'm',
#  'e',
#  'h',
#  'h',
#  'h',
#  'h',
#  'h',
#  'n',
#  'a',
#  'a',
#  'e',
#  'i',
#  's',
#  's',
#  'h',
#  'u',
#  'b',
#  'h',
#  'h',
#  'm']

# %%
re.findall("[^a-z]",test)
# Out:
# [' ', ' ', ' ', ' ', '1', '2', '3', ' ', ' ']

# %%
re.findall("[0-9]",test)
# Out:
# ['1', '2', '3']

# %%
re.findall("[0123456789]",test)
# Out:
# ['1', '2', '3']

# %%
re.findall("[^0-9]",test)
# Out:
# ['h',
#  'm',
#  'y',
#  ' ',
#  'n',
#  'a',
#  'm',
#  'e',
#  ' ',
#  'h',
#  'h',
#  'h',
#  'h',
#  'h',
#  ' ',
#  'n',
#  'a',
#  'a',
#  'e',
#  ' ',
#  ' ',
#  'i',
#  's',
#  ' ',
#  's',
#  'h',
#  'u',
#  'b',
#  'h',
#  'h',
#  'm']

# %%
re.findall("[^\d]",test)
# Out:
# ['h',
#  'm',
#  'y',
#  ' ',
#  'n',
#  'a',
#  'm',
#  'e',
#  ' ',
#  'h',
#  'h',
#  'h',
#  'h',
#  'h',
#  ' ',
#  'n',
#  'a',
#  'a',
#  'e',
#  ' ',
#  ' ',
#  'i',
#  's',
#  ' ',
#  's',
#  'h',
#  'u',
#  'b',
#  'h',
#  'h',
#  'm']

# %%
re.findall("[\d]",test)
# Out:
# ['1', '2', '3']

# %%
re.findall("[\d{3}]",test)
# Out:
# ['1', '2', '3']

# %%
re.findall("[\D]",test)
# Out:
# ['h',
#  'm',
#  'y',
#  ' ',
#  'n',
#  'a',
#  'm',
#  'e',
#  ' ',
#  'h',
#  'h',
#  'h',
#  'h',
#  'h',
#  ' ',
#  'n',
#  'a',
#  'a',
#  'e',
#  ' ',
#  ' ',
#  'i',
#  's',
#  ' ',
#  's',
#  'h',
#  'u',
#  'b',
#  'h',
#  'h',
#  'm']

# %%
re.findall("\w",test)
# Out:
# ['h',
#  'm',
#  'y',
#  'n',
#  'a',
#  'm',
#  'e',
#  'h',
#  'h',
#  'h',
#  'h',
#  'h',
#  'n',
#  'a',
#  'a',
#  'e',
#  '1',
#  '2',
#  '3',
#  'i',
#  's',
#  's',
#  'h',
#  'u',
#  'b',
#  'h',
#  'h',
#  'm']

# %%
test
# Out:
# 'hmy name hhhhh naae 123 is shubhhm'

# %%
a-z,A-Z,0-9,_

# %%
re.findall("\W",test)
# Out:
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']

# %%
re.findall("\s",test)
# Out:
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']

# %%
re.findall("\S",test)
# Out:
# ['h',
#  'm',
#  'y',
#  'n',
#  'a',
#  'm',
#  'e',
#  'h',
#  'h',
#  'h',
#  'h',
#  'h',
#  'n',
#  'a',
#  'a',
#  'e',
#  '1',
#  '2',
#  '3',
#  'i',
#  's',
#  's',
#  'h',
#  'u',
#  'b',
#  'h',
#  'h',
#  'm']
