# %%
import re

# %%
txt="adssfogf h0o"
print(re.search("h*o$",txt))
# Out:
# <re.Match object; span=(11, 12), match='o'>

# %%
txt[11:12]
# Out:
# 'o'

# %%
address="ward no.2,44444445646new koradi,441111"
print(re.search("\d{6,}",address))
# Out:
# <re.Match object; span=(10, 21), match='44444445646'>
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\hp\AppData\Local\Temp\ipykernel_18984\1296324075.py:2: SyntaxWarning: invalid escape sequence '\d'
#   print(re.search("\d{6,}",address))

# %%
tet="colour"
tet1="colour  colour color"
print(re.findall("colou?r",tet1))
# Out:
# ['colour', 'colour', 'color']

# %%
tez="aaaaaaaaaaaaaaaaaaa"
print(re.search("a{6,9}",tez))
# Out:
# <re.Match object; span=(0, 9), match='aaaaaaaaa'>
