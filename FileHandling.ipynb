# %%
file = open("B12.txt","r")

# %%
file.read(10)
# Out:
# 'Hello Clas'

# %%
file.read()
# Out:
# 's\nHello student'

# %%
file.write("This is my first file handling program in python")
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 file.write("This is my first file handling program in python")
#
# UnsupportedOperation: not writable

# %%
file.close()

# %%
file.read()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 file.read()
#
# ValueError: I/O operation on closed file.

# %%
file = open("B12.txt","w")

# %%
file.write("Hello Student")
# Out:
# 13

# %%
file.close()

# %%
file = open("B12.txt","r")

# %%
file.read()
# Out:
# 'Hello Student'

# %%
file.close()

# %%
file = open(r"C:\Users\SHUBHAM\Desktop\B07_Sql\ddl_dml_tcl.sql", "rb")

# %%
file.read()
# Out:
# b'-- create delete database\r\ndrop database if exists b07;\r\ncreate database b07;\r\n\r\n-- database select\r\nuse b07;\r\n\r\n-- table creation\r\ncreate table student(\r\nstuid int,\r\nstuname varchar(10),\r\nmobno varchar(10));\r\n\r\n-- list of tables\r\nshow tables;\r\n\r\n-- table information\r\ndesc student;\r\n\r\n-- read data\r\nselect * from student;\r\n\r\n-- delete table\r\ndrop table student;\r\nshow tables;\r\n\r\n-- add column\r\nalter table student\r\nadd column city varchar(20);\r\n\r\nalter table student\r\nadd column city varchar(20) after stuname;\r\n\r\nalter table student\r\nadd column city varchar(20) first;\r\n\r\n\r\nselect * from student;\r\n\r\n-- delete column\r\nalter table student\r\ndrop column city;\r\n\r\n\r\n-- change column position\r\nalter table student\r\nmodify column city varchar(10) after mobno;\r\n\r\n-- change data type\r\nalter table student\r\nmodify column stuname char(50);\r\ndesc student;\r\n\r\n-- change column name\r\nalter table student\r\nrename column stuname to `name`;\r\n\r\n-- change table name\r\nrename table student to student_record;\r\nselect * from student;\r\nselect * from student_record;\r\n\r\nrename table student_record to student;\r\n\r\nselect * from student;\r\nalter table student\r\ndrop column city;\r\ninsert into student values\r\n(1,"shubham","8983471527"),\r\n(1,"shubham","8983471527"),\r\n(1,"shubham","8983471527"),\r\n(1,"shubham","8983471527"),\r\n(1,"shubham","8983471527");\r\n\r\nselect * from student;\r\n-- delete all records\r\ntruncate table student;\r\n\r\nset sql_safe_updates=0;\r\ndesc student;\r\n\r\ninsert into student(`name`,stuid,mobno)\r\nvalues("raj",2,"99999999"),\r\n("suraj",3,"8945654626");\r\n\r\ninsert into student\r\nvalues("raj",2,"99999999"),\r\n("suraj",3,"8945654626");\r\ndesc student;\r\ninsert into student values\r\n(1,"shubham","8983471527");\r\n\r\nselect * from student;\r\n\r\nstart transaction;\r\nupdate student\r\nset `name`=\'Raj\'\r\nwhere stuid=1;\r\nrollback;\r\n\r\nstart transaction;\r\nupdate student\r\nset `name`=\'Raj\';\r\nrollback;\r\nselect * from student;\r\nrollback;\r\n\r\n\r\nstart transaction;\r\ndelete from student;\r\nrollback;\r\nselect * from student;\r\ndrop table student;\r\nshow tables;\r\nshow databases;\r\ndrop database b07;\r\n\r\nstart transaction;\r\nselect * from student;\r\ndelete from student\r\nwhere stuid=2;\r\nsavepoint s1;\r\nupdate student\r\nset name=\'Niraj\'\r\nwhere stuid=3;\r\nsavepoint s2;\r\ndelete from student\r\nwhere stuid=1;\r\nselect * from student;\r\nrollback;\r\n\r\nselect * from student;\r\n\r\nstart transaction;\r\nselect * from student;\r\ndelete from student\r\nwhere stuid=2;\r\nsavepoint s1;\r\nupdate student\r\nset name=\'Niraj\'\r\nwhere stuid=3;\r\nsavepoint s2;\r\ndelete from student\r\nwhere stuid=1;\r\nselect * from student;\r\nrollback to s2;\r\nselect * from student;\r\nrollback to s1;\r\nselect * from student;\r\n\r\nrollback to s2;\r\ncommit;\r\n'

# %%
file.tell()
# Out:
# 2657

# %%
file.seek?
# Out:
# Signature: file.seek(cookie, whence=0, /)
# Docstring:
# Set the stream position, and return the new stream position.
#
#   cookie
#     Zero or an opaque number returned by tell().
#   whence
#     The relative position to seek from.
#
# Four operations are supported, given by the following argument
# combinations:
#
# - seek(0, SEEK_SET): Rewind to the start of the stream.
# - seek(cookie, SEEK_SET): Restore a previous position;
#   'cookie' must be a number returned by tell().
# - seek(0, SEEK_END): Fast-forward to the end of the stream.
# - seek(0, SEEK_CUR): Leave the current stream position unchanged.
#
# Any other argument combinations are invalid,
# and may raise exceptions.
# Type:      builtin_function_or_method

# %%
file.seek(0,0)
# Out:
# 0

# %%
file.read()
# Out:
# b'-- create delete database\r\ndrop database if exists b07;\r\ncreate database b07;\r\n\r\n-- database select\r\nuse b07;\r\n\r\n-- table creation\r\ncreate table student(\r\nstuid int,\r\nstuname varchar(10),\r\nmobno varchar(10));\r\n\r\n-- list of tables\r\nshow tables;\r\n\r\n-- table information\r\ndesc student;\r\n\r\n-- read data\r\nselect * from student;\r\n\r\n-- delete table\r\ndrop table student;\r\nshow tables;\r\n\r\n-- add column\r\nalter table student\r\nadd column city varchar(20);\r\n\r\nalter table student\r\nadd column city varchar(20) after stuname;\r\n\r\nalter table student\r\nadd column city varchar(20) first;\r\n\r\n\r\nselect * from student;\r\n\r\n-- delete column\r\nalter table student\r\ndrop column city;\r\n\r\n\r\n-- change column position\r\nalter table student\r\nmodify column city varchar(10) after mobno;\r\n\r\n-- change data type\r\nalter table student\r\nmodify column stuname char(50);\r\ndesc student;\r\n\r\n-- change column name\r\nalter table student\r\nrename column stuname to `name`;\r\n\r\n-- change table name\r\nrename table student to student_record;\r\nselect * from student;\r\nselect * from student_record;\r\n\r\nrename table student_record to student;\r\n\r\nselect * from student;\r\nalter table student\r\ndrop column city;\r\ninsert into student values\r\n(1,"shubham","8983471527"),\r\n(1,"shubham","8983471527"),\r\n(1,"shubham","8983471527"),\r\n(1,"shubham","8983471527"),\r\n(1,"shubham","8983471527");\r\n\r\nselect * from student;\r\n-- delete all records\r\ntruncate table student;\r\n\r\nset sql_safe_updates=0;\r\ndesc student;\r\n\r\ninsert into student(`name`,stuid,mobno)\r\nvalues("raj",2,"99999999"),\r\n("suraj",3,"8945654626");\r\n\r\ninsert into student\r\nvalues("raj",2,"99999999"),\r\n("suraj",3,"8945654626");\r\ndesc student;\r\ninsert into student values\r\n(1,"shubham","8983471527");\r\n\r\nselect * from student;\r\n\r\nstart transaction;\r\nupdate student\r\nset `name`=\'Raj\'\r\nwhere stuid=1;\r\nrollback;\r\n\r\nstart transaction;\r\nupdate student\r\nset `name`=\'Raj\';\r\nrollback;\r\nselect * from student;\r\nrollback;\r\n\r\n\r\nstart transaction;\r\ndelete from student;\r\nrollback;\r\nselect * from student;\r\ndrop table student;\r\nshow tables;\r\nshow databases;\r\ndrop database b07;\r\n\r\nstart transaction;\r\nselect * from student;\r\ndelete from student\r\nwhere stuid=2;\r\nsavepoint s1;\r\nupdate student\r\nset name=\'Niraj\'\r\nwhere stuid=3;\r\nsavepoint s2;\r\ndelete from student\r\nwhere stuid=1;\r\nselect * from student;\r\nrollback;\r\n\r\nselect * from student;\r\n\r\nstart transaction;\r\nselect * from student;\r\ndelete from student\r\nwhere stuid=2;\r\nsavepoint s1;\r\nupdate student\r\nset name=\'Niraj\'\r\nwhere stuid=3;\r\nsavepoint s2;\r\ndelete from student\r\nwhere stuid=1;\r\nselect * from student;\r\nrollback to s2;\r\nselect * from student;\r\nrollback to s1;\r\nselect * from student;\r\n\r\nrollback to s2;\r\ncommit;\r\n'

# %%
file.tell()
# Out:
# 2657

# %%
file.seek(5,0)
# Out:
# 5

# %%
file.read()
# Out:
# b'eate delete database\r\ndrop database if exists b07;\r\ncreate database b07;\r\n\r\n-- database select\r\nuse b07;\r\n\r\n-- table creation\r\ncreate table student(\r\nstuid int,\r\nstuname varchar(10),\r\nmobno varchar(10));\r\n\r\n-- list of tables\r\nshow tables;\r\n\r\n-- table information\r\ndesc student;\r\n\r\n-- read data\r\nselect * from student;\r\n\r\n-- delete table\r\ndrop table student;\r\nshow tables;\r\n\r\n-- add column\r\nalter table student\r\nadd column city varchar(20);\r\n\r\nalter table student\r\nadd column city varchar(20) after stuname;\r\n\r\nalter table student\r\nadd column city varchar(20) first;\r\n\r\n\r\nselect * from student;\r\n\r\n-- delete column\r\nalter table student\r\ndrop column city;\r\n\r\n\r\n-- change column position\r\nalter table student\r\nmodify column city varchar(10) after mobno;\r\n\r\n-- change data type\r\nalter table student\r\nmodify column stuname char(50);\r\ndesc student;\r\n\r\n-- change column name\r\nalter table student\r\nrename column stuname to `name`;\r\n\r\n-- change table name\r\nrename table student to student_record;\r\nselect * from student;\r\nselect * from student_record;\r\n\r\nrename table student_record to student;\r\n\r\nselect * from student;\r\nalter table student\r\ndrop column city;\r\ninsert into student values\r\n(1,"shubham","8983471527"),\r\n(1,"shubham","8983471527"),\r\n(1,"shubham","8983471527"),\r\n(1,"shubham","8983471527"),\r\n(1,"shubham","8983471527");\r\n\r\nselect * from student;\r\n-- delete all records\r\ntruncate table student;\r\n\r\nset sql_safe_updates=0;\r\ndesc student;\r\n\r\ninsert into student(`name`,stuid,mobno)\r\nvalues("raj",2,"99999999"),\r\n("suraj",3,"8945654626");\r\n\r\ninsert into student\r\nvalues("raj",2,"99999999"),\r\n("suraj",3,"8945654626");\r\ndesc student;\r\ninsert into student values\r\n(1,"shubham","8983471527");\r\n\r\nselect * from student;\r\n\r\nstart transaction;\r\nupdate student\r\nset `name`=\'Raj\'\r\nwhere stuid=1;\r\nrollback;\r\n\r\nstart transaction;\r\nupdate student\r\nset `name`=\'Raj\';\r\nrollback;\r\nselect * from student;\r\nrollback;\r\n\r\n\r\nstart transaction;\r\ndelete from student;\r\nrollback;\r\nselect * from student;\r\ndrop table student;\r\nshow tables;\r\nshow databases;\r\ndrop database b07;\r\n\r\nstart transaction;\r\nselect * from student;\r\ndelete from student\r\nwhere stuid=2;\r\nsavepoint s1;\r\nupdate student\r\nset name=\'Niraj\'\r\nwhere stuid=3;\r\nsavepoint s2;\r\ndelete from student\r\nwhere stuid=1;\r\nselect * from student;\r\nrollback;\r\n\r\nselect * from student;\r\n\r\nstart transaction;\r\nselect * from student;\r\ndelete from student\r\nwhere stuid=2;\r\nsavepoint s1;\r\nupdate student\r\nset name=\'Niraj\'\r\nwhere stuid=3;\r\nsavepoint s2;\r\ndelete from student\r\nwhere stuid=1;\r\nselect * from student;\r\nrollback to s2;\r\nselect * from student;\r\nrollback to s1;\r\nselect * from student;\r\n\r\nrollback to s2;\r\ncommit;\r\n'

# %%
file.seek(10,1)
# Out:
# 10

# %%
file.tell()
# Out:
# 10

# %%
file.seek(-3,1)
# Out:
# 7

# %%
file.seek(3,1)
# Out:
# 10

# %%
file.seek(-5,2)
# Out:
# 2652

# %%
file.seek(-5,1)
# Out:
# 2647

# %%
file.seek(0,2)
# Out:
# 2657

# %%
file.close()

# %%
file.read()

# %%
file.tail()

# %%
file.seek(-1,2)

# %%
file.seek(2,1)

# %%
file.close()

# %%
file = open("B12.txt","wb")

# %%
file.read()
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 file.read()
#
# UnsupportedOperation: read

# %%
file.write(b"Hello Class")
# Out:
# 11

# %%
file.close()

# %%
file = open("B12.txt","r")

# %%
file.read()
# Out:
# 'Hello Class'

# %%
file.write("123")
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 file.write("123")
#
# UnsupportedOperation: not writable

# %%
file.close()

# %%
file = open("B12.txt","a")

# %%
file.read()
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 file.read()
#
# UnsupportedOperation: not readable

# %%
file.write("\nHello student")
# Out:
# 14

# %%
file.close()

# %%
file = open("B12.txt","r")

# %%
file.readline()
# Out:
# ''

# %%
file.seek(0,0)
# Out:
# 0

# %%
file.readlines()
# Out:
# ['Hello Class\n', 'Hello student']

# %%
file.close()

# %%
file = open("B12.txt","x")
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 file = open("B12.txt","x")
#
# FileExistsError: [Errno 17] File exists: 'B12.txt'

# %%
file = open("B14.txt","x")

# %%
file.close()

# %%
file = open("B15.txt","a")

# %%
file.write("I love Python")
# Out:
# 13

# %%
file.writelines(["I love Python", "I love Java"])

# %%
file.close()

# %%
file = open("B13.txt","r+")

# %%
file.read()
# Out:
# 'I love Python\nI Hate Coding\nI Love Data AnalysisI Love Machine Learning\nI Love Machine LearningI love Python\nI Hate Coding\nI Love Data AnalysisI Love Machine Learning\nI Love Machine Learning'

# %%
file.tell()
# Out:
# 196

# %%
file.seek(5,0)
# Out:
# 5

# %%
file.read()
# Out:
# 'e Python\nI Hate Coding\nI Love Data AnalysisI Love Machine Learning\nI Love Machine LearningI love Python\nI Hate Coding\nI Love Data AnalysisI Love Machine Learning\nI Love Machine Learning'

# %%
file.seek(-3,2)
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[90], line 1
# ----> 1 file.seek(-3,2)
#
# UnsupportedOperation: can't do nonzero end-relative seeks

# %%
file.read()
# Out:
# ''

# %%
file.tell()
# Out:
# 196

# %%
file.seek(0,0)
# Out:
# 0

# %%
file.seek(0,2)
# Out:
# 196

# %%
file.write("This is my first file handling program in python")
# Out:
# 48

# %%
file.close()

# %%
file = open("B15.txt","r+")

# %%
file.close()

# %%
file = open("B17.txt","w+")

# %%
file.write("Hello Student")
# Out:
# 13

# %%
file.tell()
# Out:
# 13

# %%
file.seek(0,0)
# Out:
# 0

# %%
file.read(10)
# Out:
# ''

# %%
file.seek(0,0)
# Out:
# 0

# %%
file.seek(-2,1)

# %%
file.read(5)

# %%
file.tell()

# %%
file.read(2)

# %%
file.close()

# %%
file = open("B13.txt","rb+")

# %%
file.readline()

# %%
file.readline()

# %%
file.readline()

# %%
file.readline()

# %%
file.readline?

# %%
file.tell()

# %%
file.seek(0,0)

# %%
file.readlines()

# %%
file.readlines()

# %%
file.write(b"\nI Love Machine Learning")

# %%
file.tell()

# %%
file.seek(0,0)

# %%
file.readlines()

# %%
file.write(b"\nI Love Machine Learning")

# %%
file.seek(0)

# %%
inputlines = file.readlines()

# %%
file.writelines(inputlines)

# %%
file.tell()

# %%
file.seek(0)

# %%
file.readlines()

# %%
file.close()
