# %% [markdown]
# # Variables in Python

# %% [markdown]
# ## Naming Rule

# %% [markdown]
# ### Allowed Charecter

# %% [markdown]
# 1. Variable Creation
# 2. Rules of Creation
# 3. Example

# %% [markdown]
# - Variable Creation
# - Rules of Creation
# - Example

# %% [markdown]
# |name|age|
# |-----|----|
# |shubham|30|

# %% [markdown]
# **shubham**

# %% [markdown]
# *shubham*

# %% [markdown]
# ***shubham***

# %% [markdown]
# __shubham__

# %% [markdown]
# _shubham_

# %% [markdown]
# *sdfgh*

# %% [markdown]
# ~~asdfgh~~

# %% [markdown]
# ___

# %% [markdown]
# ***

# %% [markdown]
# - Apple
# - Mango
# - Orange

# %% [markdown]
# - Fruits
#     - Apple
#     - Mango
# - Vegetables

# %% [markdown]
# 1. Python
# 2. SQL
# 3. Power BI

# %% [markdown]
# - [x] Python
# - [x] SQL
# - [ ] Deep Learning

# %% [markdown]
# > This is a note.

# %%
print(123)
# Out:
# 123

# %% [markdown]
# Use `print()` function.

# %% [markdown]
# ```python
# for i in range(5):
#     print(i)
# ```

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# [OpenAI](https://openai.com)

# %% [markdown]
# [ChatGPT](https://chatgpt.com)

# %% [markdown]
# [YOUTUBE](https://youtube.com)

# %% [markdown]
# https://www.python.org

# %% [markdown]
# ![PythonLogo](https://www.python.org/static/community_logos/python-powered-w-200x80.png)

# %% [markdown]
# <img src="Desktop/B07_Python/python-powered-w-200x80.png" width="300">

# %%
12233
