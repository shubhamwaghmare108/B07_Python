# %%
file = open('SamratAshok.txt','x')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 file = open('SamratAshok.txt','x')
#
# FileExistsError: [Errno 17] File exists: 'SamratAshok.txt'

# %%
file = open('SamratAshok.txt','a')

# %%
file.read()
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 file.read()
#
# UnsupportedOperation: not readable

# %%
file.write("Samrat Ashok is a great warrior of ancient india")
# Out:
# 48

# %%
file.close()

# %%
file = open('SamratAshok.txt','a')

# %%
file.read()
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 file.read()
#
# UnsupportedOperation: not readable

# %%
file.write(" and great emporer of mourya dynasty which rule entire indian subcontinent")
# Out:
# 74

# %%
file.close()

# %%
file = open('SamratAshok.txt','r')

# %%
file.read()
# Out:
# 'Samrat Ashok is a great warrior of ancient india and great emporer of mourya dynasty which rule entire indian subcontinent'

# %%
file.close()
