# %% [markdown]
# # Complete Matplotlib Tutorial
#
# Matplotlib is the most widely used Python library for data visualization. It provides:
# - **Fine-grained control** over every plot element
# - **Publication-quality** figures
# - **Integration** with NumPy, Pandas, and Jupyter
# - **Extensive customization** (colors, fonts, axes, annotations)
# - **Backend support** (interactive, static, web)
#
# This tutorial covers everything from basic plots to advanced 3D visualizations.

# %% [markdown]
# | Style Name               | Description |
# |---------------------------|-------------|
# | 'classic'                 | Original Matplotlib look (pre-2.0) |
# | 'seaborn-v0_8-darkgrid'   | Seaborn dark grid style |
# | 'seaborn-v0_8-whitegrid'  | Seaborn white grid style |
# | 'seaborn-v0_8-dark'       | Seaborn dark background (no grid) |
# | 'seaborn-v0_8-notebook'   | Seaborn notebook style |
# | 'seaborn-v0_8-poster'     | Seaborn poster style (larger fonts) |
# | 'Solarize_Light2'         | Light theme inspired by Solarized |
# | 'bmh'                     | Bayesian Methods for Hackers style |
# | 'ggplot'                  | Inspired by R’s ggplot2 |
# | 'fivethirtyeight'         | Inspired by FiveThirtyEight graphics |
# | 'grayscale'               | Black-and-white plots |
# | 'dark_background'         | Dark background with bright lines |
# | 'fast'                    | Simplified style for speed |
# | 'tableau-colorblind10'    | Colorblind-friendly Tableau palette |

# %% [markdown]
# | rcParams Key            | Description | Example Value |
# |--------------------------|-------------|---------------|
# | figure.figsize           | Default figure size (width, height in inches) | (10, 6) |
# | figure.dpi               | Resolution of figure (dots per inch) | 100 |
# | font.size                | Default font size | 12 |
# | font.family              | Font family for all text | 'serif' |
# | axes.titlesize           | Font size of axes titles | 'large' |
# | axes.labelsize           | Font size of x/y labels | 'medium' |
# | axes.grid                | Show grid by default | True |
# | axes.edgecolor           | Color of axes edge | 'black' |
# | axes.linewidth           | Width of axes edge lines | 1.0 |
# | lines.linewidth          | Default line width | 2 |
# | lines.linestyle          | Default line style | '-' |
# | lines.marker             | Default marker style | 'o' |
# | legend.loc               | Default legend location | 'best' |
# | legend.fontsize          | Font size of legend text | 'small' |
# | grid.color               | Grid line color | 'gray' |
# | grid.linestyle           | Grid line style | '--' |
# | grid.alpha               | Transparency of grid lines | 0.7 |
# | xtick.labelsize          | Font size of x-axis tick labels | 'small' |
# | ytick.labelsize          | Font size of y-axis tick labels | 'small' |
# | savefig.dpi              | Resolution of saved figures | 300 |
# | savefig.format           | Default file format for saving | 'png' |

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl

# For 3D plots
from mpl_toolkits.mplot3d import Axes3D

# Set style and defaults
plt.style.use('seaborn-v0_8-whitegrid')
mpl.rcParams['figure.figsize'] = (10, 6)
mpl.rcParams['font.size'] = 12
mpl.rcParams['lines.linewidth'] = 2
mpl.rcParams['grid.color'] = 'yellow'

# For Jupyter notebook inline display
# %matplotlib inline

np.random.seed(42)

# %% [markdown]
# ## 1. Basic Plotting
#
# The core of Matplotlib is the `pyplot` module, which provides a MATLAB-like interface.

# %% [markdown]
# | Parameter | Values (examples)                  | Description                          |
# |-----------|------------------------------------|--------------------------------------|
# | family    | 'serif', 'sans-serif', 'monospace' | Font family type                     |
# | style     | 'normal', 'italic', 'oblique'      | Font style                           |
# | weight    | 'light', 'normal', 'bold'          | Font thickness/weight                |
# | size      | integer (e.g., 10, 12, 14)         | Font size in points                  |

# %%
x = [0,10,20,30,40]
y = [125,456,785,45,59]
plt.figure(figsize = (6,4))
plt.plot(x, y,linestyle = '--',linewidth = 1,color = 'red',marker = 'o',markersize = 5,markerfacecolor='yellow',      # Fill color
    markeredgecolor='black')
plt.title("Basic Line chart",color = 'gold',size=10,style = 'oblique',family='monospace',weight= 'bold')
plt.xlabel("X values",color = 'red')
plt.ylabel("Y values",color = 'green',size = 50)
plt.xticks(color = 'blue',rotation = 90)
plt.yticks(color = 'purple')
plt.grid(True,linestyle='--',linewidth = 1,color='magenta')
plt.axhline(785)
plt.axvline(20)
plt.annotate(
    "Peak here",              # Text
    xy=(20, 785),               # Point to annotate
    xytext=(25, 700),           # Text position
    arrowprops=dict(facecolor='green', shrink=0.05)  # Arrow style
)
plt.show()

# %% [markdown]
# | Parameter    | Example Value                          | Description                                |
# |--------------|----------------------------------------|--------------------------------------------|
# | `text`       | "Peak here"                            | The annotation text                        |
# | `xy`         | (x, y)                                 | Point in data coordinates to annotate      |
# | `xytext`     | (x_offset, y_offset)                   | Position of the text                       |
# | `arrowprops` | dict(facecolor='black', shrink=0.05)   | Arrow style (color, shrink, width, etc.)   |
# | `fontsize`   | 12                                     | Size of annotation text                    |
# | `color`      | 'red'                                  | Text color                                 |
# | `ha`         | 'center', 'left', 'right'              | Horizontal alignment of text               |
# | `va`         | 'top', 'center', 'bottom'              | Vertical alignment of text                 |

# %%
# Simple line plot
x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.figure(figsize = (6,4))
plt.plot(x, y)
plt.title('Sine Wave')
plt.xlabel('x values',color ='red',fontsize = 50)
plt.ylabel('sin(x)',color = 'black')
plt.grid(True,alpha = 0.9)
plt.show()

# %%
plt.legend?

# %% [markdown]
# | Line Style | String Code | Description | Example Usage |
# |------------|-------------|-------------|---------------|
# | Solid      | `'-'`       | Continuous line | `plt.plot(x, y, linestyle='-')` |
# | Dashed     | `'--'`      | Long dashes | `plt.plot(x, y, linestyle='--')` |
# | Dash-dot   | `'-.'`      | Dash + dot pattern | `plt.plot(x, y, linestyle='-.')` |
# | Dotted     | `':'`       | Small dots | `plt.plot(x, y, linestyle=':')` |
# | None       | `'None'` or `''` | No line (only markers) | `plt.plot(x, y, linestyle='None', marker='o')` |

# %% [markdown]
# | Location String | Location Code |
# |-----------------|---------------|
# | 'best' (Axes only) | 0 |
# | 'upper right'      | 1 |
# | 'upper left'       | 2 |
# | 'lower left'       | 3 |
# | 'lower right'      | 4 |
# | 'right'            | 5 |
# | 'center left'      | 6 |
# | 'center right'     | 7 |
# | 'lower center'     | 8 |
# | 'upper center'     | 9 |
# | 'center'           | 10 |

# %% [markdown]
# | Marker | String Code | Description | Example Usage |
# |--------|-------------|-------------|---------------|
# | `.`    | `'.'`       | Point marker | `plt.plot(x, y, marker='.')` |
# | `o`    | `'o'`       | Circle marker | `plt.plot(x, y, marker='o')` |
# | `v`    | `'v'`       | Downward triangle | `plt.plot(x, y, marker='v')` |
# | `^`    | `'^'`       | Upward triangle | `plt.plot(x, y, marker='^')` |
# | `<`    | `'<'`       | Left triangle | `plt.plot(x, y, marker='<')` |
# | `>`    | `'>'`       | Right triangle | `plt.plot(x, y, marker='>')` |
# | `s`    | `'s'`       | Square marker | `plt.plot(x, y, marker='s')` |
# | `p`    | `'p'`       | Pentagon marker | `plt.plot(x, y, marker='p')` |
# | `*`    | `'*'`       | Star marker | `plt.plot(x, y, marker='*')` |
# | `h`    | `'h'`       | Hexagon1 marker | `plt.plot(x, y, marker='h')` |
# | `H`    | `'H'`       | Hexagon2 marker | `plt.plot(x, y, marker='H')` |
# | `+`    | `'+'`       | Plus marker | `plt.plot(x, y, marker='+')` |
# | `x`    | `'x'`       | Cross marker | `plt.plot(x, y, marker='x')` |
# | `D`    | `'D'`       | Diamond marker | `plt.plot(x, y, marker='D')` |
# | `d`    | `'d'`       | Thin diamond marker | `plt.plot(x, y, marker='d')` |
# | `|`    | `'|'`       | Vertical line marker | `plt.plot(x, y, marker='|')` |
# | `_`    | `'_'`       | Horizontal line marker | `plt.plot(x, y, marker='_')` |

# %%
# Multiple lines on same plot
y2 = np.cos(x)

plt.plot(x, y, label='sin(x)', color='blue', linestyle='-.', linewidth=2,marker = 'o')
plt.plot(x, y2, label='cos(x)', color='red', linestyle='--', linewidth=2)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Sine and Cosine')
plt.legend(loc='center')
plt.grid(True, alpha=0.5)
plt.show()

# %% [markdown]
# ## 2. Subplots – Multiple Axes in One Figure
#
# Use `plt.subplots()` to create a grid of subplots.

# %%
# 2x2 subplots
fig, axes = plt.subplots(2, 2, figsize=(12, 8))

# First subplot
axes[0, 0].plot(x, np.sin(x), 'b^-')
axes[0, 0].set_title('Sine')
axes[0, 0].set_xlabel('x')
axes[0, 0].set_ylabel('sin(x)')

# Second subplot
axes[0, 1].plot(x, np.cos(x), 'ro--')
axes[0, 1].set_title('Cosine')
axes[0, 1].set_xlabel('x')
axes[0, 1].set_ylabel('cos(x)')

# Third subplot
axes[1, 0].plot(x, np.tanh(x), 'g*-.')
axes[1, 0].set_title('Tanh')
axes[1, 0].set_xlabel('x')
axes[1, 0].set_ylabel('tanh(x)')

# Fourth subplot
axes[1, 1].scatter(x[::5], np.sin(x[::5]), c='purple', alpha=0.6)
axes[1, 1].set_title('Scatter')
axes[1, 1].set_xlabel('x')
axes[1, 1].set_ylabel('sin(x)')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 3. Common Plot Types
#
# ### Line Plot
# Already covered.
#
# ### Scatter Plot

# %% [markdown]
# | Colormap Name   | Type        | Description / Usage |
# |-----------------|-------------|----------------------|
# | 'viridis'       | Sequential  | Default colormap, perceptually uniform |
# | 'plasma'        | Sequential  | Bright, high-contrast sequential map |
# | 'inferno'       | Sequential  | Dark-to-light, good for heatmaps |
# | 'magma'         | Sequential  | Dark purple to yellow |
# | 'cividis'       | Sequential  | Colorblind-friendly, uniform |
# | 'Greys'         | Sequential  | Black → white grayscale |
# | 'Blues'         | Sequential  | Light → dark blue shades |
# | 'Reds'          | Sequential  | Light → dark red shades |
# | 'coolwarm'      | Diverging   | Blue → red, balanced around midpoint |
# | 'bwr'           | Diverging   | Blue → white → red |
# | 'seismic'       | Diverging   | Blue → white → red, high contrast |
# | 'PiYG'          | Diverging   | Pink → green |
# | 'PRGn'          | Diverging   | Purple → green |
# | 'tab10'         | Qualitative | 10 distinct colors for categories |
# | 'tab20'         | Qualitative | 20 distinct colors |
# | 'Set1'          | Qualitative | Bright categorical colors |
# | 'Pastel1'       | Qualitative | Soft pastel colors |
# | 'Accent'        | Qualitative | Distinct accent colors |
# | 'hsv'           | Cyclical    | Hue-based circular map |
# | 'twilight'      | Cyclical    | Smooth cyclic transitions |
# | 'twilight_shifted' | Cyclical | Shifted version of twilight |

# %% [markdown]
# | Color Name   | String Code | Example Usage |
# |--------------|-------------|---------------|
# | Black        | `'black'`   | `plt.plot(x, y, color='black')` |
# | White        | `'white'`   | `plt.plot(x, y, color='white')` |
# | Red          | `'red'`     | `plt.plot(x, y, color='red')` |
# | Blue         | `'blue'`    | `plt.plot(x, y, color='blue')` |
# | Green        | `'green'`   | `plt.plot(x, y, color='green')` |
# | Yellow       | `'yellow'`  | `plt.plot(x, y, color='yellow')` |
# | Cyan         | `'cyan'`    | `plt.plot(x, y, color='cyan')` |
# | Magenta      | `'magenta'` | `plt.plot(x, y, color='magenta')` |
# | Orange       | `'orange'`  | `plt.plot(x, y, color='orange')` |
# | Purple       | `'purple'`  | `plt.plot(x, y, color='purple')` |
# | Brown        | `'brown'`   | `plt.plot(x, y, color='brown')` |
# | Pink         | `'pink'`    | `plt.plot(x, y, color='pink')` |
# | Gray         | `'gray'`    | `plt.plot(x, y, color='gray')` |
# | Lime         | `'lime'`    | `plt.plot(x, y, color='lime')` |
# | Navy         | `'navy'`    | `plt.plot(x, y, color='navy')` |
# | Teal         | `'teal'`    | `plt.plot(x, y, color='teal')` |
# | Olive        | `'olive'`   | `plt.plot(x, y, color='olive')` |
# | Gold         | `'gold'`    | `plt.plot(x, y, color='gold')` |
# | Silver       | `'silver'`  | `plt.plot(x, y, color='silver')` |

# %%
plt.scatter?
# Out:
# Signature:
# plt.scatter(
#     x: 'float | ArrayLike',
#     y: 'float | ArrayLike',
#     s: 'float | ArrayLike | None' = None,
#     c: 'ArrayLike | Sequence[ColorType] | ColorType | None' = None,
#     *,
#     marker: 'MarkerType | None' = None,
#     cmap: 'str | Colormap | None' = None,
#     norm: 'str | Normalize | None' = None,
#     vmin: 'float | None' = None,
#     vmax: 'float | None' = None,
#     alpha: 'float | None' = None,
#     linewidths: 'float | Sequence[float] | None' = None,
#     edgecolors: "Literal['face', 'none'] | ColorType | Sequence[ColorType] | None" = None,
#     colorizer: 'Colorizer | None' = None,
#     plotnonfinite: 'bool' = False,
#     data: 'DataParamType' = None,
#     **kwargs,
# ) -> 'PathCollection'
# Docstring:
# A scatter plot of *y* vs. *x* with varying marker size and/or color.
#
# Parameters
# ----------
# x, y : float or array-like, shape (n, )
#     The data positions.
#
# s : float or array-like, shape (n, ), optional
# ...

# %%
# Scatter plot with color mapping
n = 200
x_scatter = np.random.randn(n)
y_scatter = np.random.randn(n)
colors = np.random.rand(n)
sizes = np.random.randint(20, 200, n)

plt.scatter(x_scatter, y_scatter, c=colors, s=sizes, alpha=0.6, cmap='plasma')
plt.colorbar(label='Color value')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Scatter Plot with Variable Size and Color')
plt.show()

# %%
# Bar plot
categories = ['A', 'B', 'C', 'D', 'E']
values = [23, 45, 56, 78, 34]
plt.figure(figsize=(5,3))
plt.bar(categories, values, color='orange', edgecolor='red', alpha=0.7)
plt.xlabel('Category',color = 'orange')
plt.ylabel('Value')
plt.title('Bar Chart')
plt.show()

# %%
# Horizontal bar chart
plt.figure(figsize=(5,3))
plt.barh(categories, values, color='lightcoral')
plt.xlabel('Value')
plt.ylabel('Category')
plt.title('Horizontal Bar Chart')
plt.show()

# %%
# Histogram
data = np.random.randn(1000)
plt.figure(figsize=(4,4))
plt.hist(data, bins=[-4,-3,-2,-1,0,1,2,3,4], color='black', alpha=0.7, edgecolor='blue')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram')
plt.axhline(60, color='red', linestyle='--', label=f'Mean: {data.mean():.2f}')
plt.axvline(data.mean(), color='red', linestyle='--', label=f'Mean: {data.mean():.2f}')
plt.legend()
plt.show()

# %%
# Box plot (shows median, quartiles, outliers)
np.random.seed(45)
data_by_group = [np.random.normal(0, 1, 100) for _ in range(4)]

plt.boxplot(data_by_group, label=['Group 1', 'Group 2', 'Group 3', 'Group 4'], patch_artist=True)
plt.ylabel('Value')
plt.title('Box Plot')
plt.grid(axis='y', alpha=0.3)
plt.show()

# %%
plt.pie?
# Out:
# Signature:
# plt.pie(
#     x: 'ArrayLike',
#     *,
#     explode: 'ArrayLike | None' = None,
#     labels: 'Sequence[str] | None' = None,
#     colors: 'ColorType | Sequence[ColorType] | None' = None,
#     autopct: 'str | Callable[[float], str] | None' = None,
#     pctdistance: 'float' = 0.6,
#     shadow: 'bool' = False,
#     labeldistance: 'float | None' = 1.1,
#     startangle: 'float' = 0,
#     radius: 'float' = 1,
#     counterclock: 'bool' = True,
#     wedgeprops: 'dict[str, Any] | None' = None,
#     textprops: 'dict[str, Any] | None' = None,
#     center: 'tuple[float, float]' = (0, 0),
#     frame: 'bool' = False,
#     rotatelabels: 'bool' = False,
#     normalize: 'bool' = True,
#     hatch: 'str | Sequence[str] | None' = None,
#     data: 'DataParamType' = None,
# ) -> 'PieContainer'
# Docstring:
# Plot a pie chart.
#
# Make a pie chart of array *x*.  The fractional area of each wedge is
# given by ``x/sum(x)``.
#
# ...

# %%
# Pie chart
sizes = [25, 30, 20, 15, 10]
labels = ['Category A', 'Category B', 'Category C', 'Category D', 'Category E']
colors = ['gold', 'lightblue', 'lightgreen', 'coral', 'purple']
plt.figure(figsize=(6,3))
plt.pie(sizes, labels=labels, radius=10,colors=colors, autopct='%0.1f%%', startangle=45, explode=(0.0, 0.0, 0, 0, 0.2))
plt.title('Pie Chart')
plt.axis('equal')
plt.savefig("piechart.pdf")
plt.show()

# %% [markdown]
# ## 4. Customization
#
# Matplotlib gives you complete control over every visual element.

# %%
plt.xlabel?

# %%
# Customizing lines, markers, and colors
x = np.linspace(0, 5, 20)
y1 = x
y2 = x**2
y3 = np.sqrt(x)

plt.plot(x, y1, 'ro-', label='Linear', linewidth=2, markersize=8)
plt.plot(x, y2, 'gs--', label='Quadratic', linewidth=3, markersize=6)
plt.plot(x, y3, 'b<-.', label='Square root', linewidth=1, markersize=3)

plt.xlabel('X', fontsize=14, fontweight='bold',loc ='right')
plt.ylabel('Y', fontsize=14, fontweight='bold')
plt.xticks(fontsize=14,color='red')
plt.title('Customized Line Plot', fontsize=16, fontweight='bold',color = 'blue')
plt.legend(loc='upper left', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %%
# Adding annotations
x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.plot(x, y, 'b-')

# Annotate the maximum point
max_idx = np.argmax(y)
plt.plot(x[max_idx], y[max_idx], 'ro', markersize=10)
plt.annotate(f'Max: {y[max_idx]:.2f}', xy=(x[max_idx], y[max_idx]), xytext=(x[max_idx]+1, y[max_idx]-0.2),
             arrowprops=dict(facecolor='black', shrink=0.05, width=1, headwidth=8))

# Add text box
plt.text(0, 0, 'Sine wave\nPeriodic function', bbox=dict(facecolor='yellow', alpha=0.5))

plt.title('Line Plot with Annotations')
plt.show()

# %% [markdown]
# ## 5. Colormaps and Color Bars
#
# Use colormaps to represent a third dimension (e.g., density, time, value).

# %%
# 2D color plot (pcolormesh / imshow)
X, Y = np.meshgrid(np.linspace(-3, 3, 100), np.linspace(-3, 3, 100))
Z = np.sin(X) * np.cos(Y)

plt.figure(figsize=(8, 6))
plt.pcolormesh(X, Y, Z, cmap='plasma', shading='auto')
plt.colorbar(label='sin(x) * cos(y)')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('2D Colormap Plot')
plt.show()

# %%
# Available colormaps
print("Some useful colormaps: 'viridis', 'plasma', 'inferno', 'magma', 'cividis', 'RdBu', 'coolwarm', 'jet'")
# You can reverse a colormap by appending '_r' (e.g., 'viridis_r')

# %% [markdown]
# ## 6. 3D Plots
#
# Matplotlib supports 3D plotting via the `mplot3d` toolkit.

# %%
# 3D scatter plot
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

n_pts = 200
xs = np.random.randn(n_pts)
ys = np.random.randn(n_pts)
zs = np.random.randn(n_pts)

ax.scatter(xs, ys, zs, c=zs, cmap='viridis', s=30, alpha=0.6)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('3D Scatter Plot')
plt.show()

# %%
# 3D surface plot
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

X, Y = np.meshgrid(np.linspace(-5, 5, 50), np.linspace(-5, 5, 50))
Z = np.sin(np.sqrt(X**2 + Y**2))

surf = ax.plot_surface(X, Y, Z, cmap='coolwarm', linewidth=0, antialiased=True)
fig.colorbar(surf, shrink=0.5, aspect=10, label='sin(r)')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('3D Surface Plot')
plt.show()

# %%
# 3D contour plot
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

ax.contour3D(X, Y, Z, 50, cmap='viridis')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('3D Contour Plot')
plt.show()

# %% [markdown]
# ## 7. Plotting with Pandas
#
# Pandas DataFrames have built‑in plotting methods that use Matplotlib.

# %%
# Create sample DataFrame
dates = pd.date_range('2024-01-01', periods=100, freq='D')
df_plot = pd.DataFrame({
    'sales': np.random.randn(100).cumsum() + 100,
    'expenses': np.random.randn(100).cumsum() + 90,
    'profit': np.random.randn(100).cumsum() + 10
}, index=dates)

# Line plot
df_plot.plot(title='Financial Trends', figsize=(10, 6))
plt.xlabel('Date')
plt.ylabel('Amount')
plt.grid(True, alpha=0.3)
plt.show()

# %%
# Histogram from DataFrame
df_plot.hist(bins=30, alpha=0.7, figsize=(10, 6))
plt.suptitle('Histograms of Financial Metrics', y=1.02)
plt.tight_layout()
plt.show()

# %%
# Scatter matrix (pair plot)
from pandas.plotting import scatter_matrix

df_pair = pd.DataFrame(np.random.randn(500, 3), columns=['A', 'B', 'C'])
scatter_matrix(df_pair, alpha=0.5, figsize=(10, 10), diagonal='hist')
plt.suptitle('Scatter Matrix', y=1.02)
plt.show()

# %% [markdown]
# ## 8. Saving Figures
#
# Save plots to various formats: PNG, PDF, SVG, EPS, etc.

# %%
plt.figure(figsize=(8, 6))
plt.plot(x, np.sin(x))
plt.title('Sine Wave')
plt.xlabel('x')
plt.ylabel('sin(x)')

# Save as PNG with high DPI
plt.savefig('sine_wave.png', dpi=300, bbox_inches='tight')
print("Saved as 'sine_wave.png'")

# Save as PDF (vector format)
plt.savefig('sine_wave.pdf', bbox_inches='tight')
print("Saved as 'sine_wave.pdf'")

# Save as SVG (editable in Illustrator/Inkscape)
plt.savefig('sine_wave.svg', bbox_inches='tight')
print("Saved as 'sine_wave.svg'")

plt.show()

# %% [markdown]
# ## 9. Matplotlib Styles
#
# Apply predefined styles or create your own.

# %%
# List available styles
print("Available styles:", plt.style.available[:10])

# Demo different styles
fig, axes = plt.subplots(2, 2, figsize=(12, 10))

styles = ['default', 'seaborn-v0_8-darkgrid', 'ggplot', 'fivethirtyeight']
for ax, style in zip(axes.flatten(), styles):
    with plt.style.context(style):
        ax.plot(x, np.sin(x), label='sin(x)')
        ax.plot(x, np.cos(x), label='cos(x)')
        ax.set_title(f'Style: {style}')
        ax.legend()
        ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 10. Advanced Plot Types
#
# ### Violin Plot (combines box plot and kernel density)

# %%
data_violin = [np.random.normal(0, std, 100) for std in range(1, 5)]

plt.violinplot(data_violin, showmeans=True, showmedians=True)
plt.xticks(range(1, 5), ['Std=1', 'Std=2', 'Std=3', 'Std=4'])
plt.ylabel('Value')
plt.title('Violin Plot')
plt.grid(axis='y', alpha=0.3)
plt.show()

# %% [markdown]
# ### Heatmap

# %%
# Create correlation matrix
df_corr = pd.DataFrame(np.random.randn(10, 10), columns=[f'Var{i}' for i in range(1, 11)])
corr = df_corr.corr()

plt.figure(figsize=(10, 8))
plt.imshow(corr, cmap='coolwarm', interpolation='nearest')
plt.colorbar(label='Correlation')
plt.xticks(range(10), corr.columns, rotation=45)
plt.yticks(range(10), corr.columns)
plt.title('Correlation Heatmap')

# Add text annotations
for i in range(10):
    for j in range(10):
        plt.text(j, i, f'{corr.iloc[i, j]:.2f}', ha='center', va='center', color='black')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Error Bars

# %%
x = np.arange(5)
y = [10, 15, 20, 25, 30]
y_err = [2, 3, 2.5, 4, 3]

plt.errorbar(x, y, yerr=y_err, fmt='o-', capsize=5, capthick=2, elinewidth=2, markersize=8)
plt.xlabel('Category')
plt.ylabel('Value')
plt.title('Line Plot with Error Bars')
plt.xticks(x, ['A', 'B', 'C', 'D', 'E'])
plt.grid(alpha=0.3)
plt.show()

# %% [markdown]
# ### Inset Axes (Zoomed View)

# %%
fig, ax = plt.subplots(figsize=(8, 6))

x = np.linspace(0, 10, 1000)
y = np.sin(x) * np.exp(-0.1 * x)
ax.plot(x, y)
ax.set_title('Main Plot')

# Inset axes
axins = ax.inset_axes([0.6, 0.6, 0.3, 0.3])
axins.plot(x, y)
axins.set_xlim(2, 4)
axins.set_ylim(-0.5, 0.5)
axins.set_title('Zoomed')
ax.indicate_inset_zoom(axins)

plt.show()

# %% [markdown]
# ## 11. Interactive Features (Zoom, Pan, Widgets)
#
# Use `%matplotlib notebook` or `mplcursors` for interactivity. Here’s a simple slider example.

# %%
from matplotlib.widgets import Slider

fig, ax = plt.subplots()
plt.subplots_adjust(bottom=0.25)

t = np.linspace(0, 2*np.pi, 500)
initial_freq = 1
line, = ax.plot(t, np.sin(initial_freq * t), lw=2)
ax.set_xlabel('t')
ax.set_ylabel('Amplitude')
ax.set_title('Interactive Sine Wave')
ax.grid(True, alpha=0.3)

ax_slider = plt.axes([0.25, 0.1, 0.65, 0.03])
slider = Slider(ax_slider, 'Frequency', 0.1, 10.0, valinit=initial_freq)

def update(val):
    freq = slider.val
    line.set_ydata(np.sin(freq * t))
    fig.canvas.draw_idle()

slider.on_changed(update)
plt.show()
# Out:
# <div id='05269edc-06cb-4715-91d8-5c16d67b6a81'></div>

# %% [markdown]
# ## 12. Performance Tips for Large Datasets
#
# - Use `rasterized=True` for dense scatter plots
# - Use `linewidth=0` for scatter plots with many points
# - Use `step` instead of `plot` for large step functions
# - Downsample data before plotting
# - Use `hexbin` for 2D density heatmaps

# %%
# Hexbin plot (efficient for large datasets)
x_hex = np.random.randn(10000)
y_hex = x_hex * 0.5 + np.random.randn(10000) * 0.2

plt.hexbin(x_hex, y_hex, gridsize=50, cmap='YlOrRd', mincnt=1)
plt.colorbar(label='Count in bin')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Hexbin Plot (Density Heatmap)')
plt.show()

# %% [markdown]
# ## 13. Configuration and rcParams
#
# Set global defaults using `plt.rcParams`.

# %%
# View current configuration
print("Current figure size:", plt.rcParams['figure.figsize'])
print("Current font size:", plt.rcParams['font.size'])

# Temporarily change settings
with plt.rc_context({'font.size': 16, 'lines.linewidth': 3}):
    plt.plot(x[:50], y[:50], 'b-')
    plt.title('Temporary Settings (larger font)')
    plt.show()

# Permanent change (uncomment to use)
# plt.rcParams['figure.dpi'] = 150
# plt.rcParams['savefig.dpi'] = 300
# plt.rcParams['axes.grid'] = True
# plt.rcParams['grid.alpha'] = 0.3

# %% [markdown]
# ## Summary
#
# You have now covered:
# - **Basic line plots** and customization
# - **Subplots** – multiple axes in one figure
# - **Common plot types**: scatter, bar, histogram, boxplot, pie, error bars, violin
# - **Advanced** – annotations, colormaps, 3D plots (scatter, surface, contour)
# - **Pandas integration** – direct DataFrame plotting
# - **Saving figures** – PNG, PDF, SVG with high DPI
# - **Styles** – pre‑defined and custom
# - **Heatmaps and hexbin** for large data
# - **Interactive widgets** – sliders and updates
# - **Performance** – rasterization, downsampling, hexbin
# - **Configuration** – rcParams for global settings
#
# Matplotlib is the foundation of Python visualization. Combine it with Seaborn, Plotly, or Bokeh for even more capabilities.
