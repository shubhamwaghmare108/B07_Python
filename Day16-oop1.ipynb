# %%
print(type(len))
# Out:
# <class 'builtin_function_or_method'>

# %%
print(type(print))
# Out:
# <class 'builtin_function_or_method'>

# %%
print(type(int))
# Out:
# <class 'type'>

# %%
print(type(float))
# Out:
# <class 'type'>

# %%
print(type(str))
# Out:
# <class 'type'>

# %%
class animal:
    pass

# %%
s = animal()

# %%
print(type(s))
# Out:
# <class '__main__.animal'>

# %%
s = int()

# %%
print(type(s))
# Out:
# <class 'int'>

# %%
s = 123

# %%
s = int(123)

# %%
type(s)
# Out:
# int

# %%
print(type(s))
# Out:
# <class 'int'>

# %%
a = animal()

# %%
a

# %%
class animal:
    """We are creating a class called animal"""
    jungle = "Amazon"
    def __init__(self,species,age,weight):
        print(id(self))
        self.species = species
        self.age = age
        self.weight = weight
        print(f"Animal Created: {self.species}, Age: {self.age}")
    def __repr__(self):
        return f"Animal: {self.species}, Age: {self.age}"
    def walk(self):
        print(f"{self.species} is walking")

# %%
animal()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 animal()
#
# TypeError: animal.__init__() missing 2 required positional arguments: 'species' and 'age'

# %%
a1 = animal("Dog", 5,20)
# Out:
# 1972218730624
# Animal Created: Dog, Age: 5

# %%
id(a1)
# Out:
# 1972218534256

# %%
 a2=animal("lion",3,150)
# Out:
# 1972218731776
# Animal Created: lion, Age: 3

# %%
id(a2)
# Out:
# 1972218066032

# %%
a1.species
# Out:
# 'Dog'

# %%
a2.species
# Out:
# 'lion'

# %%
a1.__dict__
# Out:
# {'species': 'Dog', 'age': 5, 'weight': 20}

# %%
a1.species
# Out:
# 'Dog'

# %%
a1.age
# Out:
# 5

# %%
a1.weight
# Out:
# 20

# %%
a1.weight = 20

# %%
a1.weight
# Out:
# 20

# %%
a1.__dict__
# Out:
# {'species': 'Dog', 'age': 5, 'weight': 20}

# %%
a2.__dict__
# Out:
# {'species': 'lion', 'age': 3, 'weight': 150}

# %%
animal.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               '__doc__': 'We are creating a class called animal',
#               'jungle': 'Amazon',
#               '__init__': <function __main__.animal.__init__(self, species, age, weight)>,
#               '__repr__': <function __main__.animal.__repr__(self)>,
#               'walk': <function __main__.animal.walk(self)>,
#               '__dict__': <attribute '__dict__' of 'animal' objects>,
#               '__weakref__': <attribute '__weakref__' of 'animal' objects>})

# %%
a2.walk()
# Out:
# lion is walking

# %%
a1.walk()
# Out:
# Dog is walking

# %%
animal.jungle
# Out:
# 'Amazon'

# %%
a1.jungle
# Out:
# 'Amazon'

# %%
a2.jungle
# Out:
# 'Amazon'

# %%
del a2.age

# %%
a2.__dict__
# Out:
# {'species': 'lion', 'weight': 150}

# %%
animal.jungle = "Sundarban"

# %%
animal.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               '__doc__': 'We are creating a class called animal',
#               'jungle': 'Sundarban',
#               '__init__': <function __main__.animal.__init__(self, species, age, weight)>,
#               '__repr__': <function __main__.animal.__repr__(self)>,
#               '__dict__': <attribute '__dict__' of 'animal' objects>,
#               '__weakref__': <attribute '__weakref__' of 'animal' objects>})

# %%
a1.jungle
# Out:
# 'Sundarban'

# %%
a1.jungle = "Pench"

# %%
a1.__dict__
# Out:
# {'species': 'Dog', 'age': 5, 'weight': 20, 'jungle': 'Pench'}

# %%
a2.jungle
# Out:
# 'Sundarban'

# %%
class complexx:
    """
    we want to built an implimentation of python complex class.
    """
    counter = 0
    iscomplex = True
    def __init__(self,real,imag): # constructur method-- initilizer #__dgfh__ dunder method
        self.real = float(real) # private
        self.imag = float(imag)
        complexx.counter += 1
    
    def __repr__(self):
        if '-' in str(self.imag):
            return  f"({self.real}{self.imag}i)"
        return f"({self.real}+{self.imag}i)"

    def __add__(self,other):
        real = self.real + other.real
        imag = self.imag + other.imag
        
        return complexx(real,imag)
    
    def __sub__(self,other):
        real = self.real - other.real
        imag = self.imag - other.imag
        return complexx(real,imag)
    def __mul__(self,other):
        real = self.real * other.real
        imag = self.imag * other.imag
        
        return complexx(real,imag)
    
    def __eq__(self,other):
        return (self.real == other.real) and (self.imag == other.imag)

    def __gt__(self,other):
        return (self.real +self.imag) > (other.real + other.imag)

    def __ge__(self,other):
        return ((self.real +self.imag) > (other.real + other.imag)) \
        or ((self.real == other.real) and (self.imag == other.imag))
    """# getter method
    @property
    def real(self,passwd):
        if passwd == '123':
            return self.real
        else:
            print("Bhag yahase")

    # setter method
    @real.setter
    def real(self):
        passwd = input("Enter Passwd:\n")
        if passwd == '123':
            new = input("Enter new value:\n")
            self.__real =float(new)
            print("Value updated sucessfully")
        else:
            print("Invalied Credential,Try Again....")

    @classmethod
    def get_counter(cls):
        return cls.counter"""

# %%
s = complexx(10,20) # self=s,real=10,imag =20

# %%
s.iscomplex
# Out:
# True

# %%
s.counter
# Out:
# 1

# %%
s.imag
# Out:
# 20.0

# %%
s.real
# Out:
# 10.0

# %%
s
# Out:
# (10.0+20.0i)

# %%
s1 = complexx(12,-58)

# %%
s1
# Out:
# (12.0-58.0i)

# %%
s1.imag
# Out:
# -58.0

# %%
s1.counter
# Out:
# 2

# %%
s1+s
# Out:
# (22.0-38.0i)

# %%
s == s1
# Out:
# False

# %%
s != s1
# Out:
# True

# %%
s > s1
# Out:
# True

# %%
s < s1
# Out:
# False

# %%
s >= s1
# Out:
# True

# %%
s.real('123')

# %%
'123'._iscomplex

# %%
s._iscomplex

# %%
s._iscomplex

# %%
s.real(123)

# %%
id(s)

# %%
s.__dict__

# %%
c = complexx(20,56)

# %%
id(c)

# %%
complexx.__counter

# %%
s.counter

# %%
c.counter

# %%
complexx.get_counter()

# %%
s.__dict__

# %%
complexx.__dict__

# %%
print(complexx.__doc__)

# %%
s.real

# %%
s.__real

# %%
s._complexx__real

# %%
s.get_real()

# %%
complexx.real

# %%
complexx.s.real

# %%
s.real=20

# %%
s.real

# %%
com = 10+20j

# %%
com.real # getter

# %%
com

# %%
c.real

# %%
c.__dict__

# %%
s.real=25

# %%
s.real

# %%
s

# %%
c

# %%
c.imag

# %%
d = complexx(5,-5)

# %%
d

# %%
d+s

# %%
com+(20+5j)

# %%
com

# %%
d-s

# %%
d

# %%
s

# %%
"sytrt"+3

# %%
d*s

# %%
d==s

# %%
d!=s

# %%
d>s

# %%
d<s

# %%
d.get_real('123')

# %%
d.set_real()

# %%
d.get_real('123')

# %%
class student:
    pass

# %%
stu1 = student()

# %%
type(stu1)

# %%
stu1.name = "shubham"

# %%
stu1.name

# %%
stu1.age = 30

# %%
stu1.age

# %%
stu2 = student()

# %%
type(stu2)

# %%
stu2.name

# %%
stu2.name = "palash"

# %%
stu2.name

# %%
stu1.name

# %%
class student1:
    classNo = 1 # class attribute

    def __init__(self,name,age):
        print(id(self))
        self.name = name # instance attribute
        self.age = age

# %%
s1 = student1()

# %%
s1 = student1("shubham",30)

# %%
s1.name

# %%
s1.age

# %%
s2 = student1("nikita",28) #(s2,"nikita",28)

# %%
s2.name

# %%
s2.age

# %%
id(s1)

# %%
id(s2)

# %%
s1.__dict__

# %%
s2.__dict__

# %%
s1.salary

# %%
s1.salary = 30000

# %%
s1.salary

# %%
s1.__dict__

# %%
s1.classNo

# %%
s2.classNo

# %%
s2.__dict__

# %%
s1.classNo = 2

# %%
s1.classNo

# %%
s2.classNo

# %%
s1.__dict__

# %%
s2.__dict__

# %%
student1.classNo = 2

# %%
s2.__dict__

# %%
s2.classNo

# %%
student1.fees = 60000

# %%
s1.fees

# %%
s2.fees

# %%
student1.fees

# %%
s1.fees = 58000

# %%
s1.fees

# %%
s1.update({"x":123})

# %%
student1.__dict__

# %%
s1.name

# %%
s1.name = "mukesh"

# %%
s1.name

# %%
student1.name = 123
