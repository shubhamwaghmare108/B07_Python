# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("Titanic.xlsx")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.set_index("PassengerId",inplace = True)

# %%
df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                        Heikkinen, Miss Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
df.head()

# %%
df.tail()

# %%
df.info()

# %%
df.nunique().plot(kind = "bar")

# %%
for i in df.columns:
    print(i,df[i].unique())

# %%
df[df["Age"]>75]
# Out:
#              Survived  Pclass                                  Name   Sex  \
# PassengerId
# 631                 1       1  Barkworth, Mr. Algernon Henry Wilson  male
#
#               Age  SibSp  Parch Ticket  Fare Cabin Embarked
# PassengerId
# 631          80.0      0      0  27042  30.0   A23        S

# %%
df[(df["Age"]>45) & (df["Sex"]=="female") &(df["Survived"]==1)].shape[0]
# Out:
# 26

# %%
df.loc[(df["Age"]>45) & (df["Sex"]=="female") &(df["Survived"]==1),:].shape[0]
# Out:
# 26

# %%
np.where?
# Out:
# Call signature:  np.where(*args, **kwargs)
# Type:            _ArrayFunctionDispatcher
# String form:     <built-in function where>
# Docstring:
# where(condition, [x, y], /)
#
# Return elements chosen from `x` or `y` depending on `condition`.
#
# .. note::
#     When only `condition` is provided, this function is a shorthand for
#     ``np.asarray(condition).nonzero()``. Using `nonzero` directly should be
#     preferred, as it behaves correctly for subclasses. The rest of this
#     documentation covers only the case where all three arguments are
#     provided.
#
# Parameters
# ----------
# condition : array_like, bool
#     Where True, yield `x`, otherwise yield `y`.
# x, y : array_like
#     Values from which to choose. `x`, `y` and `condition` need to be
#     broadcastable to some shape.
#
# Returns
# -------
# out : ndarray
#     An array with elements from `x` where `condition` is True, and elements
#     from `y` elsewhere.
#
# See Also
# --------
# choose
# ...

# %%
df["is age>60"] = np.where(df["Age"]>60,1,0)

# %%
df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                        Heikkinen, Miss Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
df[df["Age"]>60]
# Out:
#              Survived  Pclass                                       Name  \
# PassengerId
# 34                  0       2                      Wheadon, Mr. Edward H
# 55                  0       1             Ostby, Mr. Engelhart Cornelius
# 97                  0       1                  Goldschmidt, Mr. George B
# 117                 0       3                       Connors, Mr. Patrick
# 171                 0       1                  Van der hoef, Mr. Wyckoff
# 253                 0       1                  Stead, Mr. William Thomas
# 276                 1       1           Andrews, Miss Kornelia Theodosia
# 281                 0       3                           Duane, Mr. Frank
# 327                 0       3                  Nysveen, Mr. Johan Hansen
# 439                 0       1                          Fortune, Mr. Mark
# 457                 0       1                  Millet, Mr. Francis Davis
# 484                 1       3                     Turkula, Mrs. (Hedwig)
# ...

# %%
df["Sex"].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare', 'Cabin', 'Embarked', 'is age>60'],
#       dtype='object')

# %%
df['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
df['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
df.sort_values("Sex").sort_index()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                        Heikkinen, Miss Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
df.columns
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare', 'Cabin', 'Embarked', 'is age>60'],
#       dtype='object')

# %%
df.groupby("Sex")['Survived'].sum()
# Out:
# Sex
# female    233
# male      109
# Name: Survived, dtype: int64

# %%
df["Sex"].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare', 'Cabin', 'Embarked', 'is age>60'],
#       dtype='object')

# %%
df.groupby(['Pclass','Survived'])["Name"].count()
# Out:
# Pclass  Survived
# 1       0            80
#         1           136
# 2       0            97
#         1            87
# 3       0           372
#         1           119
# Name: Name, dtype: int64

# %%
df.groupby(['Pclass','Survived','Sex'])["Name"].count()
# Out:
# Pclass  Survived  Sex
# 1       0         female      3
#                   male       77
#         1         female     91
#                   male       45
# 2       0         female      6
#                   male       91
#         1         female     70
#                   male       17
# 3       0         female     72
#                   male      300
#         1         female     72
#                   male       47
# Name: Name, dtype: int64

# %%
3/80
# Out:
# 0.0375

# %%
6/97
# Out:
# 0.061855670103092786

# %%
72/372
# Out:
# 0.1935483870967742

# %%
df.columns
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare', 'Cabin', 'Embarked', 'is age>60'],
#       dtype='object')

# %%
x = df[['Embarked']]

# %%
x.drop_duplicates(keep=False)
# Out:
# Empty DataFrame
# Columns: [Embarked]
# Index: []

# %%
y =df[["Name"]]

# %%
y.duplicated()
# Out:
# PassengerId
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
#        ...
# 887    False
# 888    False
# 889    False
# 890    False
# 891    False
# Length: 891, dtype: bool

# %%
y.drop_duplicates()
# Out:
#                                                           Name
# PassengerId
# 1                                      Braund, Mr. Owen Harris
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3                                        Heikkinen, Miss Laina
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                                     Allen, Mr. William Henry
# ...                                                        ...
# 887                                      Montvila, Rev. Juozas
# 888                                Graham, Miss Margaret Edith
# 889                    Johnston, Miss Catherine Helen "Carrie"
# 890                                      Behr, Mr. Karl Howell
# 891                                        Dooley, Mr. Patrick
#
# [891 rows x 1 columns]

# %%
df.duplicated(subset=["Pclass","Sex"]).value_counts()
# Out:
# True     885
# False      6
# Name: count, dtype: int64

# %%
df.duplicated().value_counts()
# Out:
# False    891
# Name: count, dtype: int64

# %%
df.drop(columns=["Name","Sex","is age>60"])
# Out:
#              Survived  Pclass   Age  SibSp  Parch            Ticket     Fare  \
# PassengerId
# 1                   0       3  22.0      1      0         A/5 21171   7.2500
# 2                   1       1  38.0      1      0          PC 17599  71.2833
# 3                   1       3  26.0      0      0  STON/O2. 3101282   7.9250
# 4                   1       1  35.0      1      0            113803  53.1000
# 5                   0       3  35.0      0      0            373450   8.0500
# ...               ...     ...   ...    ...    ...               ...      ...
# 887                 0       2  27.0      0      0            211536  13.0000
# 888                 1       1  19.0      0      0            112053  30.0000
# 889                 0       3   NaN      1      2        W./C. 6607  23.4500
# 890                 1       1  26.0      0      0            111369  30.0000
# 891                 0       3  32.0      0      0            370376   7.7500
#
#             Cabin Embarked
# ...

# %%
df.query('Age>10 and Pclass==1')
# Out:
#              Survived  Pclass  \
# PassengerId
# 2                   1       1
# 4                   1       1
# 7                   0       1
# 12                  1       1
# 24                  1       1
# ...               ...     ...
# 872                 1       1
# 873                 0       1
# 880                 1       1
# 888                 1       1
# 890                 1       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 7                                      McCarthy, Mr. Timothy J    male  54.0
# 12                                     Bonnell, Miss Elizabeth  female  58.0
# 24                                Sloper, Mr. William Thompson    male  28.0
# ...                                                        ...     ...   ...
# ...

# %%
grouped_stats = df.groupby(['Pclass','Sex']).agg(
    {
        'Age': ['min', 'max'],
        'Fare': 'sum'
    }
)

# %%
grouped_stats
# Out:
#                 Age             Fare
#                 min   max        sum
# Pclass Sex
# 1      female  2.00  63.0  9975.8250
#        male    0.92  80.0  8201.5875
# 2      female  2.00  57.0  1669.7292
#        male    0.67  70.0  2132.1125
# 3      female  0.75  63.0  2321.1086
#        male    0.42  74.0  4393.5865

# %%
df.groupby(['Pclass','Sex'])["Name"].count()
# Out:
# Pclass  Sex
# 1       female     94
#         male      122
# 2       female     76
#         male      108
# 3       female    144
#         male      347
# Name: Name, dtype: int64

# %%
df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                        Heikkinen, Miss Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
df.dtypes
# Out:
# Survived       int64
# Pclass         int64
# Name          object
# Sex           object
# Age          float64
# SibSp          int64
# Parch          int64
# Ticket        object
# Fare         float64
# Cabin         object
# Embarked      object
# is age>60      int32
# dtype: object

# %%
df.isnull().sum()
# Out:
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age          177
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin        687
# Embarked       2
# is age>60      0
# dtype: int64

# %%
df[df["Embarked"].isnull()]
# Out:
#              Survived  Pclass                                       Name  \
# PassengerId
# 62                  1       1                         Icard, Miss Amelie
# 830                 1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#                 Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked  \
# PassengerId
# 62           female  38.0      0      0  113572  80.0   B28      NaN
# 830          female  62.0      0      0  113572  80.0   B28      NaN
#
#              is age>60
# PassengerId
# 62                   0
# 830                  1

# %%
df["Embarked"].mode()
# Out:
# 0    S
# Name: Embarked, dtype: object

# %%
df["Embarked"] = df["Embarked"].fillna("S")

# %%
df["Embarked"].isna().sum()
# Out:
# 0

# %%
df.loc[[62,830],:]
# Out:
#              Survived  Pclass                                       Name  \
# PassengerId
# 62                  1       1                         Icard, Miss Amelie
# 830                 1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#                 Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked  \
# PassengerId
# 62           female  38.0      0      0  113572  80.0   B28        S
# 830          female  62.0      0      0  113572  80.0   B28        S
#
#              is age>60
# PassengerId
# 62                   0
# 830                  1

# %%
df["Cabin"]
# Out:
# PassengerId
# 1       NaN
# 2       C85
# 3       NaN
# 4      C123
# 5       NaN
#        ...
# 887     NaN
# 888     B42
# 889     NaN
# 890    C148
# 891     NaN
# Name: Cabin, Length: 891, dtype: object

# %%
df["Cabin"].ffill()
# Out:
# PassengerId
# 1       NaN
# 2       C85
# 3       C85
# 4      C123
# 5      C123
#        ...
# 887     C50
# 888     B42
# 889     B42
# 890    C148
# 891    C148
# Name: Cabin, Length: 891, dtype: object

# %%
df["Cabin"].bfill()
# Out:
# PassengerId
# 1       C85
# 2       C85
# 3      C123
# 4      C123
# 5       E46
#        ...
# 887     B42
# 888     B42
# 889    C148
# 890    C148
# 891     NaN
# Name: Cabin, Length: 891, dtype: object

# %%
df.shape
# Out:
# (891, 12)

# %%
df.size
# Out:
# 10692

# %%
891*12
# Out:
# 10692

# %%
df.ndim
# Out:
# 2

# %%
df["Embarked"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Embarked'>
