# %% [markdown]
# Understanding Lists
# Indexing and slicing in lists
# List methods: append(), extend(), insert(), remove(), pop(), clear(), index(), count(), sort(), reverse()
# Example of adding grocery items

# %% [markdown]
# # List

# %%
lis = []

# %%
type(lis)
# Out:
# list

# %%
len(lis)
# Out:
# 0

# %%
lis1 = list()

# %%
type(lis1)
# Out:
# list

# %%
lis1
# Out:
# []

# %%
lis.append(5) #single object,right side insert

# %%
lis
# Out:
# [5]

# %%
lis.append("sdgs")

# %%
lis
# Out:
# [5, 'sdgs']

# %%
lis.append(56)

# %%
lis
# Out:
# [5, 'sdgs', 56]

# %%
lis[0]
# Out:
# 5

# %%
lis[1]
# Out:
# 'sdgs'

# %%
lis[10]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 lis[10]
#
# IndexError: list index out of range

# %%
lis[0] = 56

# %%
lis # inplace changes
# Out:
# [56, 'sdgs', 56]

# %%
str1 = "asdhd"

# %%
str1[0]
# Out:
# 'a'

# %%
str1[0]="g"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 str1[0]="g"
#
# TypeError: 'str' object does not support item assignment

# %%
lis[0]

# %%
lis.clear() # empty list,all values are removed

# %%
lis
# Out:
# []

# %%
lis.append("Shubham")

# %%
lis
# Out:
# ['Shubham']

# %%
lis.extend("Shubham")# iterable,adds by breaking data into small,unit character

# %%
lis
# Out:
# ['Shubham', 'S', 'h', 'u', 'b', 'h', 'a', 'm']

# %%
lis.append(1564)

# %%
lis
# Out:
# ['Shubham', 'S', 'h', 'u', 'b', 'h', 'a', 'm', 1564]

# %%
lis.extend(1564)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 lis.extend(1564)
#
# TypeError: 'int' object is not iterable

# %%
num = 1234

# %%
num[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 num[0]
#
# TypeError: 'int' object is not subscriptable

# %%
lis.extend('1564')

# %%
lis
# Out:
# ['Shubham', 'S', 'h', 'u', 'b', 'h', 'a', 'm', 1564, '1', '5', '6', '4']

# %%
lis.extend([12,45,78,98,"sfst"])

# %%
lis
# Out:
# ['Shubham',
#  'S',
#  'h',
#  'u',
#  'b',
#  'h',
#  'a',
#  'm',
#  1564,
#  '1',
#  '5',
#  '6',
#  '4',
#  12,
#  45,
#  78,
#  98,
#  'sfst']

# %%
lis.append([12,45,78,98,"sfst"])

# %%
lis
# Out:
# ['Shubham',
#  'S',
#  'h',
#  'u',
#  'b',
#  'h',
#  'a',
#  'm',
#  1564,
#  '1',
#  '5',
#  '6',
#  '4',
#  12,
#  45,
#  78,
#  98,
#  'sfst',
#  [12, 45, 78, 98, 'sfst']]

# %%
lis[2]
# Out:
# 'h'

# %%
lis[2]= 56 #mutate index 2

# %%
lis
# Out:
# ['Shubham',
#  'S',
#  56,
#  'u',
#  'b',
#  'h',
#  'a',
#  'm',
#  1564,
#  '1',
#  '5',
#  '6',
#  '4',
#  12,
#  45,
#  78,
#  98,
#  'sfst',
#  [12, 45, 78, 98, 'sfst']]

# %%
lis[2]
# Out:
# 56

# %%
id(lis[2])
# Out:
# 140725060305048

# %%
lis[2]=5

# %%
id(lis[2])
# Out:
# 140725060303416

# %%
del lis[2]

# %%
lis
# Out:
# ['Shubham',
#  'S',
#  'u',
#  'b',
#  'h',
#  'a',
#  'm',
#  1564,
#  '1',
#  '5',
#  '6',
#  '4',
#  12,
#  45,
#  78,
#  98,
#  'sfst',
#  [12, 45, 78, 98, 'sfst']]

# %%
lis[2]
# Out:
# 'u'

# %%
lis[-1]
# Out:
# [12, 45, 78, 98, 'sfst']

# %%
lis[-2]

# %%
lis[0:5]
# Out:
# ['Shubham', 'S', 'u', 'b', 'h']

# %%
lis[:5]
# Out:
# ['Shubham', 'S', 'u', 'b', 'h']

# %%
lis[5:]
# Out:
# ['a',
#  'm',
#  1564,
#  '1',
#  '5',
#  '6',
#  '4',
#  12,
#  45,
#  78,
#  98,
#  'sfst',
#  [12, 45, 78, 98, 'sfst']]

# %%
lis[:5] + (lis[5:])
# Out:
# ['Shubham',
#  'S',
#  'u',
#  'b',
#  'h',
#  'a',
#  'm',
#  1564,
#  '1',
#  '5',
#  '6',
#  '4',
#  12,
#  45,
#  78,
#  98,
#  'sfst',
#  [12, 45, 78, 98, 'sfst']]

# %%
lis[:] # copy
# Out:
# ['Shubham',
#  'S',
#  'u',
#  'b',
#  'h',
#  'a',
#  'm',
#  1564,
#  '1',
#  '5',
#  '6',
#  '4',
#  12,
#  45,
#  78,
#  98,
#  'sfst',
#  [12, 45, 78, 98, 'sfst']]

# %%
lis[:-1]
# Out:
# ['Shubham',
#  'S',
#  'u',
#  'b',
#  'h',
#  'a',
#  'm',
#  1564,
#  '1',
#  '5',
#  '6',
#  '4',
#  12,
#  45,
#  78,
#  98,
#  'sfst']

# %%
lis[-1:-5] #slicing dont produce error even if out of range

# %%
lis[-2:-5]

# %%
lis[-1:-5:-1]

# %%
lis[-1:-5:-2]

# %%
lis[::-1]

# %%
lis
# Out:
# ['Shubham',
#  'S',
#  'u',
#  'b',
#  'h',
#  'a',
#  'm',
#  1564,
#  '1',
#  '5',
#  '6',
#  '4',
#  12,
#  45,
#  78,
#  98,
#  'sfst',
#  [12, 45, 78, 98, 'sfst']]

# %%
lis.count("h")
# Out:
# 1

# %%
lis.count("sfst")
# Out:
# 1

# %%
id(lis)
# Out:
# 2193676810368

# %%
lis.copy()
# Out:
# ['Shubham',
#  'S',
#  'u',
#  'b',
#  'h',
#  'a',
#  'm',
#  1564,
#  '1',
#  '5',
#  '6',
#  '4',
#  12,
#  45,
#  78,
#  98,
#  'sfst',
#  [12, 45, 78, 98, 'sfst']]

# %%
lis_copy = lis.copy()

# %%
id(lis_copy)
# Out:
# 2193683279616

# %%
lis
# Out:
# ['Shubham',
#  'S',
#  'u',
#  'b',
#  'h',
#  'a',
#  'm',
#  1564,
#  '1',
#  '5',
#  '6',
#  '4',
#  12,
#  45,
#  78,
#  98,
#  'sfst',
#  [12, 45, 78, 98, 'sfst']]

# %%
lis.index("S")
# Out:
# 1

# %%
lis.index("o")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 lis.index("o")
#
# ValueError: 'o' is not in list

# %%
lis.index("g")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 lis.index("g")
#
# ValueError: 'g' is not in list

# %%
lis.insert?
# Out:
# Signature: lis.insert(index, object, /)
# Docstring: Insert object before index.
# Type:      builtin_function_or_method

# %%
lis.insert(0,5)

# %%
lis
# Out:
# [5,
#  'Shubham',
#  'S',
#  'u',
#  'b',
#  'h',
#  'a',
#  'm',
#  1564,
#  '1',
#  '5',
#  '6',
#  '4',
#  12,
#  45,
#  78,
#  98,
#  'sfst',
#  [12, 45, 78, 98, 'sfst']]

# %%
lis[5]
# Out:
# 'h'

# %%
lis.insert(5,2)

# %%
lis[5]
# Out:
# 2

# %%
lis
# Out:
# [5,
#  'Shubham',
#  'S',
#  'u',
#  'b',
#  2,
#  'h',
#  'a',
#  'm',
#  1564,
#  '1',
#  '5',
#  '6',
#  '4',
#  12,
#  45,
#  78,
#  98,
#  'sfst',
#  [12, 45, 78, 98, 'sfst']]

# %%
len(lis)
# Out:
# 20

# %%
lis.insert(100,25)

# %%
lis
# Out:
# [5,
#  'Shubham',
#  'S',
#  'u',
#  'b',
#  2,
#  'h',
#  'a',
#  'm',
#  1564,
#  '1',
#  '5',
#  '6',
#  '4',
#  12,
#  45,
#  78,
#  98,
#  'sfst',
#  [12, 45, 78, 98, 'sfst'],
#  25]

# %%
lis.insert(-100,25)

# %%
lis
# Out:
# [25,
#  5,
#  'Shubham',
#  'S',
#  'u',
#  'b',
#  2,
#  'h',
#  'a',
#  'm',
#  1564,
#  '1',
#  '5',
#  '6',
#  '4',
#  12,
#  45,
#  78,
#  98,
#  'sfst',
#  [12, 45, 78, 98, 'sfst'],
#  25]

# %%
lis[-1]
# Out:
# 25

# %%
lis.pop()
# Out:
# 25

# %%
lis[-1]
# Out:
# [12, 45, 78, 98, 'sfst']

# %%
lis[5]
# Out:
# 'b'

# %%
lis.pop(5)
# Out:
# 'b'

# %%
lis[5]

# %%
lis[10]
# Out:
# '1'

# %%
lis.pop(10)
# Out:
# '1'

# %%
lis[10]
# Out:
# '5'

# %%
lis.pop?
# Out:
# Signature: lis.pop(index=-1, /)
# Docstring:
# Remove and return item at index (default last).
#
# Raises IndexError if list is empty or index is out of range.
# Type:      builtin_function_or_method

# %%
lis.remove?
# Out:
# Signature: lis.remove(value, /)
# Docstring:
# Remove first occurrence of value.
#
# Raises ValueError if the value is not present.
# Type:      builtin_function_or_method

# %%
lis
# Out:
# [25,
#  5,
#  'Shubham',
#  'S',
#  'u',
#  2,
#  'h',
#  'a',
#  'm',
#  1564,
#  '5',
#  '6',
#  '4',
#  12,
#  45,
#  78,
#  98,
#  'sfst',
#  [12, 45, 78, 98, 'sfst']]

# %%
lis.remove(10)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[91], line 1
# ----> 1 lis.remove(10)
#
# ValueError: list.remove(x): x not in list

# %%
lis.remove(5)

# %%
lis.remove(5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[93], line 1
# ----> 1 lis.remove(5)
#
# ValueError: list.remove(x): x not in list

# %%
lis

# %%
lis.remove('5')

# %%
lis
# Out:
# [25,
#  'Shubham',
#  'S',
#  'u',
#  2,
#  'h',
#  'a',
#  'm',
#  1564,
#  '6',
#  '4',
#  12,
#  45,
#  78,
#  98,
#  'sfst',
#  [12, 45, 78, 98, 'sfst']]

# %%
lis.append(2)

# %%
lis
# Out:
# [25,
#  'Shubham',
#  'S',
#  'u',
#  2,
#  'h',
#  'a',
#  'm',
#  1564,
#  '6',
#  '4',
#  12,
#  45,
#  78,
#  98,
#  'sfst',
#  [12, 45, 78, 98, 'sfst'],
#  2]

# %%
lis.remove(2)

# %%
lis
# Out:
# [25,
#  'Shubham',
#  'S',
#  'u',
#  'h',
#  'a',
#  'm',
#  1564,
#  '6',
#  '4',
#  12,
#  45,
#  78,
#  98,
#  'sfst',
#  [12, 45, 78, 98, 'sfst'],
#  2]

# %%
lis.reverse()

# %%
lis
# Out:
# [2,
#  [12, 45, 78, 98, 'sfst'],
#  'sfst',
#  98,
#  78,
#  45,
#  12,
#  '4',
#  '6',
#  1564,
#  'm',
#  'a',
#  'h',
#  'u',
#  'S',
#  'Shubham',
#  25]

# %%
lis.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[102], line 1
# ----> 1 lis.sort()
#
# TypeError: '<' not supported between instances of 'list' and 'int'

# %%
lis2 =[1,52,45,26,3]

# %%
lis2.sort()

# %%
lis2
# Out:
# [1, 3, 26, 45, 52]

# %%
lis2.sort(reverse=True)

# %%
lis2
# Out:
# [52, 45, 26, 3, 1]

# %%
lis3 = ["sd","cdf","ery","cfg","dc"]

# %%
lis3.sort()

# %%
lis3
# Out:
# ['cdf', 'cfg', 'dc', 'ery', 'sd']

# %%
lis3.sort(reverse=True)

# %%
lis3
# Out:
# ['sd', 'ery', 'dc', 'cfg', 'cdf']

# %%
y = lis3.sort()

# %%
lis3
# Out:
# ['cdf', 'cfg', 'dc', 'ery', 'sd']

# %%
print(y)
# Out:
# None

# %% [markdown]
# ## Example of adding Grosary item

# %%
cart =[]

# %%
cart.append("fish")

# %%
cart
# Out:
# ['fish']

# %%
cart.append("egg")

# %%
cart
# Out:
# ['fish', 'egg']

# %%
cart.append("sugar")

# %%
cart
# Out:
# ['fish', 'egg', 'sugar']

# %%
cart.remove("sugar")

# %%
cart
# Out:
# ['fish', 'egg']

# %%
cart.clear()

# %%
cart
# Out:
# []

# %% [markdown]
# ## List comprehansion

# %% [markdown]
# List generation in single line compact code

# %%
list(range(10,20))

# %%
range?

# %%
range(10,20) #generator

# %%
tuple(range(5))

# %%
list(range(1,5,2))

# %%
[num**3 for num in range(10)]

# %%
[i*j for i in range(1,11) for j in range(1,11)]

# %%
range("A","Z")

# %%
lis = [(1,2),45,"ssd"]

# %%
lis[0] = list(lis[0])

# %%
lis

# %%
tup = ([1,2],45,"ssd")

# %%
tup[0][0]= tuple(tup[0])

# %%
tup.
# Out:
# ([1, 2], 45, 'ssd')

# %%
tup[0]
# Out:
# [1, 2]

# %%
tup[0][0] = 25

# %%
tup
# Out:
# ([25, 2], 45, 'ssd')

# %%
tup[0].pop()
# Out:
# 2

# %%
id(tup)
# Out:
# 2193682951104

# %%
tup[0][0] = 36

# %%
id(tup)
# Out:
# 2193682951104

# %%
tup[0] =[]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[139], line 1
# ----> 1 tup[0] =[]
#
# TypeError: 'tuple' object does not support item assignment

# %%
task = []

# %%
task.append("Take Dog for a walk")

# %%
task
# Out:
# ['Take Dog for a walk']

# %%
task.append("Do some Yoga Practice")

# %%
task
# Out:
# ['Take Dog for a walk', 'Do some Yoga Practice']

# %%
task.append("Take a shower")

# %%
task
# Out:
# ['Take Dog for a walk', 'Do some Yoga Practice', 'Take a shower']

# %%
task.append("Do a prayer")

# %%
task.append("Pack lunch box")

# %%
task.append("Not to forget your laptop")

# %%
task.append("Double check that you locked the door well")

# %%
task.append("You have to attend meeting at 2:30 pm with hr on salary increament")

# %%
task
# Out:
# ['Take Dog for a walk',
#  'Do some Yoga Practice',
#  'Take a shower',
#  'Do a prayer',
#  'Pack lunch box',
#  'Not to forget your laptop',
#  'Double check that you locked the door well',
#  'You have to attend meeting at 2:30 pm with hr on salary increament']

# %%
for i,j in enumerate(task):
    print(i,"==>>",j)
# Out:
# 0 ==>> Take Dog for a walk
# 1 ==>> Do some Yoga Practice
# 2 ==>> Take a shower
# 3 ==>> Do a prayer
# 4 ==>> Pack lunch box
# 5 ==>> Not to forget your laptop
# 6 ==>> Double check that you locked the door well
# 7 ==>> You have to attend meeting at 2:30 pm with hr on salary increament

# %%
task.pop(0)
# Out:
# 'Take Dog for a walk'

# %%
task
# Out:
# ['Do some Yoga Practice',
#  'Take a shower',
#  'Do a prayer',
#  'Pack lunch box',
#  'Not to forget your laptop',
#  'Double check that you locked the door well',
#  'You have to attend meeting at 2:30 pm with hr on salary increament']

# %%
for i,j in enumerate(task):
    print(i,"==>>",j)
# Out:
# 0 ==>> Do some Yoga Practice
# 1 ==>> Take a shower
# 2 ==>> Do a prayer
# 3 ==>> Pack lunch box
# 4 ==>> Not to forget your laptop
# 5 ==>> Double check that you locked the door well
# 6 ==>> You have to attend meeting at 2:30 pm with hr on salary increament

# %%
task.pop(3)
# Out:
# 'Pack lunch box'

# %%
task.remove("Not to forget your laptop")

# %%
task
# Out:
# ['Do some Yoga Practice',
#  'Take a shower',
#  'Do a prayer',
#  'Double check that you locked the door well',
#  'You have to attend meeting at 2:30 pm with hr on salary increament']

# %%
task1 = []

# %%
task1.extend(task)

# %%
for i,j in enumerate(task1):
    print(i,"==>>",j)
# Out:
# 0 ==>> Do some Yoga Practice
# 1 ==>> Take a shower
# 2 ==>> Do a prayer
# 3 ==>> Double check that you locked the door well
# 4 ==>> You have to attend meeting at 2:30 pm with hr on salary increament

# %%
task1.insert(0,"Go for a morning walk")

# %%
for i,j in enumerate(task1):
    print(i,"==>>",j)
# Out:
# 0 ==>> Go for a morning walk
# 1 ==>> Do some Yoga Practice
# 2 ==>> Take a shower
# 3 ==>> Do a prayer
# 4 ==>> Double check that you locked the door well
# 5 ==>> You have to attend meeting at 2:30 pm with hr on salary increament

# %%
task1[0] = "Instead go for 3 km speed run and one more thing you need to complete it in 6 mins."

# %%
for i,j in enumerate(task1):
    print(i,"==>>",j)
# Out:
# 0 ==>> Instead go for 3 km speed run and one more thing you need to complete it in 6 mins.
# 1 ==>> Do some Yoga Practice
# 2 ==>> Take a shower
# 3 ==>> Do a prayer
# 4 ==>> Double check that you locked the door well
# 5 ==>> You have to attend meeting at 2:30 pm with hr on salary increament

# %%
def task_viver(task):
    for i,j in enumerate(task1[:task]):
        print(i,"==>>",j)

# %%
task_viver(3)
# Out:
# 0 ==>> Instead go for 3 km speed run and one more thing you need to complete it in 6 mins.
# 1 ==>> Do some Yoga Practice
# 2 ==>> Take a shower

# %%
len(task1)
# Out:
# 6

# %%
task_viver(len(task1))
# Out:
# 0 ==>> Instead go for 3 km speed run and one more thing you need to complete it in 6 mins.
# 1 ==>> Do some Yoga Practice
# 2 ==>> Take a shower
# 3 ==>> Do a prayer
# 4 ==>> Double check that you locked the door well
# 5 ==>> You have to attend meeting at 2:30 pm with hr on salary increament

# %%
task1.remove("Take a shower")

# %%
task_viver(len(task1))
# Out:
# 0 ==>> Instead go for 3 km speed run and one more thing you need to complete it in 6 mins.
# 1 ==>> Do some Yoga Practice
# 2 ==>> Do a prayer
# 3 ==>> Double check that you locked the door well
# 4 ==>> You have to attend meeting at 2:30 pm with hr on salary increament

# %%
task1.pop(2)
# Out:
# 'Do a prayer'

# %%
task_viver(len(task1))
# Out:
# 0 ==>> Instead go for 3 km speed run and one more thing you need to complete it in 6 mins.
# 1 ==>> Do some Yoga Practice
# 2 ==>> Double check that you locked the door well
# 3 ==>> You have to attend meeting at 2:30 pm with hr on salary increament

# %%
task1.sort()

# %%
task_viver(len(task1))
# Out:
# 0 ==>> Do some Yoga Practice
# 1 ==>> Double check that you locked the door well
# 2 ==>> Instead go for 3 km speed run and one more thing you need to complete it in 6 mins.
# 3 ==>> You have to attend meeting at 2:30 pm with hr on salary increament

# %%
task1.sort(reverse=True)

# %%
task_viver(len(task1))
# Out:
# 0 ==>> You have to attend meeting at 2:30 pm with hr on salary increament
# 1 ==>> Instead go for 3 km speed run and one more thing you need to complete it in 6 mins.
# 2 ==>> Double check that you locked the door well
# 3 ==>> Do some Yoga Practice
