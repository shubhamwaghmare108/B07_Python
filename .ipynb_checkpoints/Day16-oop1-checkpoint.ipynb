# %%
print(type(len))
# Out:
# <class 'builtin_function_or_method'>

# %%
print(type(print))
# Out:
# <class 'builtin_function_or_method'>

# %%
print(type(int))
# Out:
# <class 'type'>

# %%
print(type(float))
# Out:
# <class 'type'>

# %%
print(type(str))
# Out:
# <class 'type'>

# %%
class animal:
    pass

# %%
s = animal()

# %%
print(type(s))
# Out:
# <class '__main__.animal'>

# %%
s = int()

# %%
print(type(s))
# Out:
# <class 'int'>

# %%
s = 123

# %%
s = int(123)

# %%
class complexx:
    """
    we want to built an implimentation of python complex class.
    """
    __counter = 0
    def __init__(self,real,imag): # constructur method-- initilizer #__dgfh__ dunder method
        self.__real = float(real) # private
        self.__imag = float(imag)
        self._iscomplex = True
        complexx.__counter += 1
    
    def __repr__(self):
        if '-' in str(self.__imag):
            return  f"({self.__real}{self.__imag}i)"
        return f"({self.__real}+{self.__imag}i)"

    def __add__(self,other):
        real = self.__real + other.__real
        imag = self.__imag + other.__imag
        
        return complexx(real,imag)
    
    def __sub__(self,other):
        real = self.__real - other.__real
        imag = self.__imag - other.__imag
        
        return complexx(real,imag)
    def __mul__(self,other):
        real = self.__real * other.__real
        imag = self.__imag * other.__imag
        
        return complexx(real,imag)
    
    def __eq__(self,other):
        return (self.__real == other.__real) and (self.__imag == other.__imag)

    def __gt__(self,other):
        return (self.__real +self.__imag) > (other.__real + other.__imag)

    # getter method
    @property
    def real(self,passwd):
        if passwd == '123':
            return self.__real
        else:
            print("Bhag yahase")

    # setter method
    @real.setter
    def real(self):
        passwd = input("Enter Passwd:\n")
        if passwd == '123':
            new = input("Enter new value:\n")
            self.__real =float(new)
            print("Value updated sucessfully")
        else:
            print("Invalied Credential,Try Again....")

    @classmethod
    def get_counter(cls):
        return cls.__counter

# %%
s = complexx(10,20) # self=s,real=10,imag =20

# %%
s.real('123')

# %%
'123'._iscomplex
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 '123'._iscomplex
#
# AttributeError: 'str' object has no attribute '_iscomplex'

# %%
s._iscomplex
# Out:
# True

# %%
s._iscomplex

# %%
s.real(123)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 s.real(123)
#
# TypeError: complexx.real() missing 1 required positional argument: 'passwd'

# %%
id(s)

# %%
s.__dict__

# %%
c = complexx(20,56)

# %%
id(c)

# %%
complexx.__counter

# %%
s.counter

# %%
c.counter

# %%
complexx.get_counter()

# %%
s.__dict__

# %%
complexx.__dict__

# %%
print(complexx.__doc__)

# %%
s.real

# %%
s.__real

# %%
s._complexx__real

# %%
s.get_real()

# %%
complexx.real

# %%
complexx.s.real

# %%
s.real=20

# %%
s.real

# %%
com = 10+20j

# %%
com.real # getter

# %%
com

# %%
c.real

# %%
c.__dict__

# %%
s.real=25

# %%
s.real

# %%
s

# %%
c

# %%
c.imag

# %%
d = complexx(5,-5)

# %%
d

# %%
d+s

# %%
com+(20+5j)

# %%
com

# %%
d-s

# %%
d

# %%
s

# %%
"sytrt"+3

# %%
d*s

# %%
d==s

# %%
d!=s

# %%
d>s

# %%
d<s

# %%
d.get_real('123')

# %%
d.set_real()

# %%
d.get_real('123')

# %%
class student:
    pass

# %%
stu1 = student()

# %%
type(stu1)
# Out:
# __main__.student

# %%
stu1.name = "shubham"

# %%
stu1.name
# Out:
# 'shubham'

# %%
stu1.age = 30

# %%
stu1.age
# Out:
# 30

# %%
stu2 = student()

# %%
type(stu2)
# Out:
# __main__.student

# %%
stu2.name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 stu2.name
#
# AttributeError: 'student' object has no attribute 'name'

# %%
stu2.name = "palash"

# %%
stu2.name
# Out:
# 'palash'

# %%
stu1.name
# Out:
# 'shubham'

# %%
class student1:
    classNo = 1 # class attribute

    def __init__(self,name,age):
        print(id(self))
        self.name = name # instance attribute
        self.age = age

# %%
s1 = student1()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 s1 = student1()
#
# TypeError: student1.__init__() missing 2 required positional arguments: 'name' and 'age'

# %%
s1 = student1("shubham",30)
# Out:
# 1912174344576

# %%
s1.name
# Out:
# 'shubham'

# %%
s1.age
# Out:
# 30

# %%
s2 = student1("nikita",28) #(s2,"nikita",28)
# Out:
# 1912174339776

# %%
s2.name
# Out:
# 'nikita'

# %%
s2.age
# Out:
# 28

# %%
id(s1)
# Out:
# 1912174344576

# %%
id(s2)
# Out:
# 1912174339776

# %%
s1.__dict__
# Out:
# {'name': 'shubham', 'age': 30}

# %%
s2.__dict__
# Out:
# {'name': 'nikita', 'age': 28}

# %%
s1.salary
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 s1.salary
#
# AttributeError: 'student1' object has no attribute 'salary'

# %%
s1.salary = 30000

# %%
s1.salary
# Out:
# 30000

# %%
s1.__dict__
# Out:
# {'name': 'shubham', 'age': 30, 'salary': 30000}

# %%
s1.classNo
# Out:
# 1

# %%
s2.classNo
# Out:
# 1

# %%
s2.__dict__
# Out:
# {'name': 'nikita', 'age': 28}

# %%
s1.classNo = 2

# %%
s1.classNo
# Out:
# 2

# %%
s2.classNo
# Out:
# 1

# %%
s1.__dict__
# Out:
# {'name': 'shubham', 'age': 30, 'salary': 30000, 'classNo': 2}

# %%
s2.__dict__
# Out:
# {'name': 'nikita', 'age': 28}

# %%
student1.classNo = 2

# %%
s2.__dict__
# Out:
# {'name': 'nikita', 'age': 28}

# %%
s2.classNo
# Out:
# 2

# %%
student1.fees = 60000

# %%
s1.fees
# Out:
# 60000

# %%
s2.fees
# Out:
# 60000

# %%
student1.fees
# Out:
# 60000

# %%
s1.fees = 58000

# %%
s1.fees
# Out:
# 58000

# %%
s1.update({"x":123})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[96], line 1
# ----> 1 s1.update({"x":123})
#
# AttributeError: 'student1' object has no attribute 'update'

# %%
student1.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               'classNo': 2,
#               '__init__': <function __main__.student1.__init__(self, name, age)>,
#               '__dict__': <attribute '__dict__' of 'student1' objects>,
#               '__weakref__': <attribute '__weakref__' of 'student1' objects>,
#               '__doc__': None,
#               'fees': 60000})

# %%
s1.name
# Out:
# 'shubham'

# %%
s1.name = "mukesh"

# %%
s1.name
# Out:
# 'mukesh'

# %%
student1.name = 123
