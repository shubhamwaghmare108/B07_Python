# %% [markdown]
# ## Lambda function

# %%
(lambda x,y:(x+y))(5,41)

# %%
(lambda x,y:x+y)(5,41)

# %%
y = lambda x,y:x+y

# %%
y(20,30)

# %% [markdown]
# A lambda function is a small, anonymous, single-expression function. They are useful for short-term, throwaway functions.

# %%
# Regular function
def square(x):
    print(x * x)
    return x*x

# Equivalent lambda function
square_lambda = lambda x: x * x
print(square(5))
print(square_lambda(5)) # Output: 25

# %%
s = square(5)

# %%
s

# %%
d = (lambda x,y:x+y)(10,23)

# %%
d

# %%
square(5)

# %%
square = lambda x: x ** 2
print(square(4))  # Output: 16

# %%
double = lambda x: x * 2
print(double(5))  # Output: 10

# %%
lis=[1,2,3]
tuple(map(double,lis))

# %%
map?

# %%
nums = [1, 2, 3, 4, 5]

# Double each element
doubled = list(map(lambda x: x * 2, nums))
print(doubled)  # Output: [2, 4, 6, 8, 10]

# %%
# Filter even numbers
evens = list(filter(lambda x: x % 2 == 1, nums))
print(evens)  # Output: [2, 4]

# %%
filter?

# %%
lis_org=[1,2,3,4,5]
lis_res=[]
for i in lis_org:
    lis_res.append(i*2)

# %%
lis_res

# %%
def dou(lis):
    lis_res=[]
    for i in lis:
        lis_res.append(i*2)
    return lis_res

# %%
dou([1,2,3,4,5])

# %%
dou([4,5,6])

# %%
def double(x):
    return x*2

# %%
list(map(double,[1,2,3]))

# %%
x = 10
y = 20

def add():
    x = 20
    print(x,"local")
    print(y,"global")
    print(x+y)
print(x)
print(y)
add()

# %%
x = "global"

def s1():
    x = "Enclosing"
    print(x)
    def s2():
        x = "Local"
        print(x)
    s2()
print(x)
s1()
print(x)

# %%
x = 10

def add():
    x += 10

add()

# %%
x = 60

def add():
    x = 20
    x += 10
    print(x)

add()
print(x)

# %%
x = 60

def add():
    global x
    x = 40
    print(x)
    
    x += 10
    print(x)

print(x)
add()
print(x)

# %%
x = 60

def add():
    x = 40
    print(x)
    
    def add2():
        nonlocal x
        x += 10
        print(x)
    
    add2()

print(x)
add()
print(x)

# %%
x = 60

def add():
    global x
    x = 40
    print(x)
    
    def add2():
        x = 20
        print(x)

        def add3():
            nonlocal x
            x += 30
            print(x)
        
        add3()
    
    add2()

print(x)
add()
print(x)

# %%
globals()['x']

# %%
globals()['x'] = 30

# %%
globals()['x']

# %%
locals()

# %%
globals()['xyz']

# %%
globals()['xyz'] = 25

# %%
globals()['xyz']

# %%
x = 100

def show():
    print(globals())

show()
# Out:
# {'__name__': '__main__', '__doc__': 'Automatically created module for IPython interactive environment', '__package__': None, '__loader__': None, '__spec__': None, '__builtin__': <module 'builtins' (built-in)>, '__builtins__': <module 'builtins' (built-in)>, '_ih': ['', 'x = 100\n\ndef show():\n    print(globals())\n\nshow()'], '_oh': {}, '_dh': [WindowsPath('C:/Users/hp/Desktop/B07_Python')], 'In': ['', 'x = 100\n\ndef show():\n    print(globals())\n\nshow()'], 'Out': {}, 'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x000001AA6E2D5E80>>, 'exit': <IPython.core.autocall.ZMQExitAutocall object at 0x000001AA6E253740>, 'quit': <IPython.core.autocall.ZMQExitAutocall object at 0x000001AA6E253740>, 'open': <function open at 0x000001AA6D7B5260>, '_': '', '__': '', '___': '', '__session__': 'C:\\Users\\hp\\Desktop\\B07_Python\\Day14 -lambda.ipynb', '_i': '', '_ii': '', '_iii': '', '_i1': 'x = 100\n\ndef show():\n    print(globals())\n\nshow()', 'x': 100, 'show': <function show at 0x000001AA6F693D80>}

# %%
print(globals()['y'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print(globals()['y'])
#
# KeyError: 'y'

# %%
globals()['y'] = 30

# %%
globals()['y']
# Out:
# 30

# %%
y
# Out:
# 30

# %%
def my_func():
    a = 10
    b = 20
    locals()['x'] = 50
    locals()['a'] = 100
    print(locals())

my_func()
# Out:
# {'a': 10, 'b': 20, 'x': 50}

# %%
def fac(x):
    if x == 0:
        return 1
    return x*fac(x-1)

# %%
fac(5)
# Out:
# 120
