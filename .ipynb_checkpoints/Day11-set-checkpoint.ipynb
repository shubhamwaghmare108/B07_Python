# %% [markdown]
# # Set in Python

# %% [markdown]
# ## How to make an empty set

# %%
type({})

# %%
type(set())

# %%
type(str())

# %%
type(list())

# %%
list()

# %%
dict()

# %%
a = set()

# %%
invitation_list = set()

# %%
invitation_list.add("Bhagwan Ji")

# %%
invitation_list

# %%
invitation_list.add("Rohit")

# %%
invitation_list.add("Diksha")

# %%
len(invitation_list)

# %%
invitation_list

# %%
invitation_list.add("Rohit")

# %%
invitation_list

# %%
a.add(56)

# %%
a.add([1,2])

# %% [markdown]
# ## How to add elements in set as it is mutable it can grow or shrink

# %%
se1 = set()

# %%
se1
# Out:
# set()

# %%
se1.add?
# Out:
# Docstring:
# Add an element to a set.
#
# This has no effect if the element is already present.
# Type:      builtin_function_or_method

# %%
se1.add(10)

# %%
se1
# Out:
# {10}

# %%
se1.add(10) # duplicates are not allowed in set

# %%
se1
# Out:
# {10}

# %%
se1.add(20)

# %%
se1
# Out:
# {10, 20}

# %%
se1.add(5)

# %%
se1
# Out:
# {5, 10, 20}

# %%
se1.add(15)

# %%
se1
# Out:
# {5, 10, 15, 20}

# %% [markdown]
# ## indexing

# %%
len(se1)
# Out:
# 4

# %%
se1[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 se1[0]
#
# TypeError: 'set' object is not subscriptable

# %%
se1.add("sdfdj")

# %%
se1
# Out:
# {10, 15, 20, 5, 'sdfdj'}

# %%
se1.add(145)

# %%
se1
# Out:
# {10, 145, 15, 20, 5, 'sdfdj'}

# %%
se1.add(0)

# %%
se1
# Out:
# {0, 10, 145, 15, 20, 5, 'sdfdj'}

# %%
se1.add((1,5))

# %%
se1
# Out:
# {(1, 5), 0, 10, 145, 15, 20, 5, 'sdfdj'}

# %% [markdown]
# ## set are mutable but unordered

# %%
se1[1:3]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 se1[1:3]
#
# TypeError: 'set' object is not subscriptable

# %%
se1
# Out:
# {(1, 5), 0, 10, 145, 15, 20, 5, 'sdfdj'}

# %%
for i in se1:
    print(i)
# Out:
# 0
# 5
# sdfdj
# (1, 5)
# 10
# 15
# 145
# 20

# %% [markdown]
# ## what item/object can be placed inside a set

# %%
se1
# Out:
# {(1, 5), 0, 10, 145, 15, 20, 5, 'sdfdj'}

# %%
se1.add(([1],()))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 se1.add(([1],()))
#
# TypeError: unhashable type: 'list'

# %% [markdown]
# ## only hashable data

# %% [markdown]
# ## hashable means that doen't mutate/change in its entire lifetime

# %%
se1.add({1,5,6})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 se1.add({1,5,6})
#
# TypeError: unhashable type: 'set'

# %%
se1.clear()

# %%
se1
# Out:
# set()

# %%
se1.add(1,3,5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 se1.add(1,3,5)
#
# TypeError: set.add() takes exactly one argument (3 given)

# %%
se1.add(1)

# %%
se1.add(10)

# %%
se1.add("adfa")

# %%
se1.add(12.36)

# %%
se1
# Out:
# {1, 10, 12.36, 'adfa'}

# %% [markdown]
# ### set are fast for serching

# %%
se2 = se1.copy()

# %%
se2
# Out:
# {1, 10, 12.36, 'adfa'}

# %%
se1.pop?
# Out:
# Docstring:
# Remove and return an arbitrary set element.
# Raises KeyError if the set is empty.
# Type:      builtin_function_or_method

# %%
se1.pop()
# Out:
# 1

# %%
se1.pop()
# Out:
# 10

# %%
se1.pop()
# Out:
# 'adfa'

# %%
se1.pop(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 se1.pop(10)
#
# TypeError: set.pop() takes no arguments (1 given)

# %%
se1.pop()

# %%
se1

# %%
se2

# %%
se2.remove?
# Out:
# Docstring:
# Remove an element from a set; it must be a member.
#
# If the element is not a member, raise a KeyError.
# Type:      builtin_function_or_method

# %%
se2.remove(50)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 se2.remove(50)
#
# KeyError: 50

# %% [markdown]
# ### set does indexing for faster search

# %%
se2.remove(10)

# %%
se2

# %%
se2.update({1,5,6,7})

# %%
se2
# Out:
# {1, 12.36, 5, 6, 7, 'adfa'}

# %%
se2.update(())

# %%
se2.update([1,2,3])

# %%
se2.update([1,2,3,[1,2,3]])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 se2.update([1,2,3,[1,2,3]])
#
# TypeError: unhashable type: 'list'

# %%
se2.update("sdfg")

# %%
se2
# Out:
# {1, 12.36, 2, 3, 5, 6, 7, 'adfa', 'd', 'f', 'g', 's'}

# %%
se2.update([20,30,50,[]])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 se2.update([20,30,50,[]])
#
# TypeError: unhashable type: 'list'

# %%
se2
# Out:
# {1, 12.36, 2, 20, 3, 30, 5, 50, 6, 7, 'adfa', 'd', 'f', 'g', 's'}

# %%
len(se2)
# Out:
# 15

# %%
se2.update([101,[],56])

# %%
len(se2)

# %%
se2

# %%
se2.discard?
# Out:
# Docstring:
# Remove an element from a set if it is a member.
#
# Unlike set.remove(), the discard() method does not raise
# an exception when an element is missing from the set.
# Type:      builtin_function_or_method

# %%
se2.discard(1000)

# %%
set1 = {1,2,5,6}

# %%
set2 = {3,4,5}

# %%
set1.union(set2)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
set1
# Out:
# {1, 2, 5, 6}

# %%
set2.union(set1)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
set1.intersection(set2)
# Out:
# {5}

# %%
set2.intersection(set1)
# Out:
# {5}

# %%
set1.difference(set2)
# Out:
# {1, 2, 6}

# %%
set2.difference(set1)
# Out:
# {3, 4}

# %%
set1.symmetric_difference(set2)
# Out:
# {1, 2, 3, 4, 6}

# %%
set1.issubset(set2)
# Out:
# False

# %%
set1.issuperset(set2)
# Out:
# False

# %%
set3 = {2,4,5,6}
set4 = {2,6}

# %%
set3.issubset(set4)
# Out:
# False

# %%
set3.issuperset(set4)
# Out:
# True

# %%
set1.isdisjoint?

# %%
set1.isdisjoint(set2)
# Out:
# False

# %%
set1
# Out:
# {1, 2, 5, 6}

# %%
set2
# Out:
# {3, 4, 5}

# %%
set3
# Out:
# {2, 4, 5, 6}

# %%
set4
# Out:
# {2, 6}

# %%
set2.isdisjoint(set4)
# Out:
# True

# %%
set2.difference_update?

# %%
set1

# %%
set2

# %%
set1.difference_update(set2)

# %%
set1
# Out:
# {1, 2, 6}

# %%
set2

# %%
li = [1,5,5,6]
dep_li= []
for i in li:
    if dep_li.count(i) == 0:
        dep_li.append(i)

# %%
dep_li

# %%
list(set(li))

# %%
lis = [5,9,5,6,3,4,1,52,4,59,85,2,93,1,3,2,63,55,62,4,85,52]

# %%
set(lis)
# Out:
# {1, 2, 3, 4, 5, 6, 9, 52, 55, 59, 62, 63, 85, 93}

# %%
print(1)
# Out:
# 1

# %%
print("sdfgd")
# Out:
# sdfgd

# %%
print("adsds","asjfgash",123)
# Out:
# adsds asjfgash 123

# %%
print("adsds","asjfgash",123,sep = ">>")
# Out:
# adsds>>asjfgash>>123

# %%
print("adsds","asjfgash",123,sep = ">>")
print("adsds","asjfgash",123,sep = ">>")
# Out:
# adsds>>asjfgash>>123
# adsds>>asjfgash>>123

# %%
print("adsds","asjfgash",123,sep = ">>",end="***")
print("adsds","asjfgash",123,sep = ">>")
# Out:
# adsds>>asjfgash>>123***adsds>>asjfgash>>123

# %%
file = open("demo.txt","w")

# %%
print("Hello, My name is shubham")
# Out:
# Hello, My name is shubham

# %%
print("Hello, My name is shubham",file=file)

# %%
file.close()

# %%
print?
# Out:
# Signature: print(*args, sep=' ', end='\n', file=None, flush=False)
# Docstring:
# Prints the values to a stream, or to sys.stdout by default.
#
# sep
#   string inserted between values, default a space.
# end
#   string appended after the last value, default a newline.
# file
#   a file-like object (stream); defaults to the current sys.stdout.
# flush
#   whether to forcibly flush the stream.
# Type:      builtin_function_or_method

# %%
file = open("demo.txt","a")

# %%
print("I am a Data Science Trainer",file=file,flush=True)

# %%
file.close()

# %%
file = open("demo.txt","r")

# %%
file.read()
# Out:
# ''

# %%
file.seek(0)
# Out:
# 0

# %%
print(file.read())
# Out:
# Hello, My name is shubham
# I am a Data Science Trainer

# %%
se1
# Out:
# {12.36}

# %%
kl = frozenset(se1)

# %%
kl.
