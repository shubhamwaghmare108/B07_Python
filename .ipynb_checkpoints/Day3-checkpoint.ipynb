# %% [markdown]
# # Variables in python

# %%
age = 29

# %%
print(age)
# Out:
# 29

# %%
del age

# %%
age = 32

# %%
age

# %%
type(age) # data type

# %% [markdown]
# ## Naming rule

# %% [markdown]
# [a-z,A-Z,0-9,_]  # allowed charcater set for name

# %%
"a"=="A"

# %% [markdown]
# 1.Do not use number at start

# %%
9fdshfh=123

# %% [markdown]
# 2.Space not allowed.

# %%
first name="Shubham"

# %%
first_name="Shubham"

# %%
first_name

# %%
f9dshfh=123

# %%
a=123

# %%
a

# %%
_=123

# %%
_

# %% [markdown]
# 3.Keywards not allowed as variable name.

# %%
if=123

# %%
a=123

# %%
A=456

# %%
a

# %%
A

# %%
a=123

# %%
a=456

# %%
a

# %%
4567996

# %%
id(4567996)

# %%
4567996

# %% [markdown]
# # Build in data types

# %%
number---> int,float,complex

# %%
int --> 10,52,46,56

# %%
a=123

# %%
type(a)

# %%
float --> 12.0,13.25,16.45

# %%
a=12.0

# %%
type(a)

# %%
complex ---> real+imag
imag -->j,J

# %%
a=12+13j

# %%
type(a)

# %%
a.real

# %%
a.imag

# %%
0b101010

# %%
bin(42)

# %%
oct(42)

# %%
hex(42)

# %%
type(0b1010)

# %%
text--->str

# %%
name = 'Shubham'

# %%
type(name)

# %%
name="dsdg"

# %%
type(name)

# %%
a="1213"

# %%
type(a)

# %%
"hfhfhj13232sgdh24#%$^%^&"

# %%
Collection Type---> list,tuple,set

# %%
type([123,"sgfg",1223])

# %%
a=[123,"sgfg",1223]

# %%
a[2]=1564

# %%
a[2]

# %%
a

# %%
(123,456,"sfgh")

# %%
a=(123,[123,456],"sdgh")

# %%
a[1].append(56)

# %%
a

# %%
a=(1)

# %%
type(a)

# %%
a=(1,)

# %%
type(a)

# %%
set -->{1,2,3} #no duplicate

# %%
se={1,2,3}

# %%
se

# %%
type(se)

# %%
se={1,2,3,3,3,3,3,3,3,3,3,3,3,3,3,3}

# %%
se

# %%
se.add(156)

# %%
se

# %%
se.add("sshg")

# %%
se # immutabble --change not allowed

# %%
se.add([123])

# %%
mapping type ---> dict{"Key":"Value"}

# %%
dict1 ={1:456,2:789}

# %%
dict1[1] # mutable

# %%
dict1.update({"S":123})

# %%
dict1

# %%
# dict not allowed duplicate keys

# %%
dict1.update({"S":89})

# %%
dict1

# %%
# dict keys are immutable type

# %%
num,tuple,

# %%
dict1.update({[1,2]:123})

# %%
dict1.update({(1,2):123})

# %%
dict1.update({(1,2,[123]):123})

# %%
dict1

# %%
None

# %%
a=None

# %%
a

# %%
print(a)

# %%
type(a)

# %%
dict1

# %%
dict1["S"]

# %%
for i in dict1.keys():
    print(i,type(i))

# %%
dict1.update({"1":123})

# %%
dict1

# %%
for i in dict1.keys():
    print(i,type(i))

# %%
1+1

# %%
int("1")+1

# %%
a=[123,466,789]

# %%
a[5]
