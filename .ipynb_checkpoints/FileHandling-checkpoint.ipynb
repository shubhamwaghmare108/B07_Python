# %%
file = open("B12.txt","r")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 file = open("B12.txt","r")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'B12.txt'

# %%
file = open("B12.txt","w")

# %%
file.write("Hello Student")
# Out:
# 13

# %%
file.close()

# %%
file = open("B12.txt","r")

# %%
file.read()
# Out:
# 'Hello Student'

# %%
file.read()
# Out:
# ''

# %%
file.seek?
# Out:
# Signature: file.seek(cookie, whence=0, /)
# Docstring:
# Set the stream position, and return the new stream position.
#
#   cookie
#     Zero or an opaque number returned by tell().
#   whence
#     The relative position to seek from.
#
# Four operations are supported, given by the following argument
# combinations:
#
# - seek(0, SEEK_SET): Rewind to the start of the stream.
# - seek(cookie, SEEK_SET): Restore a previous position;
#   'cookie' must be a number returned by tell().
# - seek(0, SEEK_END): Fast-forward to the end of the stream.
# - seek(0, SEEK_CUR): Leave the current stream position unchanged.
#
# Any other argument combinations are invalid,
# and may raise exceptions.
# Type:      builtin_function_or_method

# %%
file.seek(1,-5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 file.seek(1,-5)
#
# ValueError: invalid whence (-5, should be 0, 1 or 2)

# %%
file.read()
# Out:
# 'Hello Student'

# %%
file.seek(1,0)
# Out:
# 1

# %%
file.read()
# Out:
# 'ello Student'

# %%
file.seek(0,0)
# Out:
# 0

# %%
file.read()
# Out:
# 'Hello Student'

# %%
file.tail()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 file.tail()
#
# AttributeError: '_io.TextIOWrapper' object has no attribute 'tail'

# %%
file.seek(-1,2)
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 file.seek(-1,2)
#
# UnsupportedOperation: can't do nonzero end-relative seeks

# %%
file.seek(2,1)
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 file.seek(2,1)
#
# UnsupportedOperation: can't do nonzero cur-relative seeks

# %%
file.close()

# %%
file = open("B12.txt","w")

# %%
file.read()
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 file.read()
#
# UnsupportedOperation: not readable

# %%
file.write("Hello Class")
# Out:
# 11

# %%
file.close()

# %%
file = open("B12.txt","r")

# %%
file.read()
# Out:
# 'Hello Class'

# %%
file.write("123")
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 file.write("123")
#
# UnsupportedOperation: not writable

# %%
file.close()

# %%
file = open("B12.txt","a")

# %%
file.read()
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 file.read()
#
# UnsupportedOperation: not readable

# %%
file.write("Hello student")
# Out:
# 13

# %%
file.close()

# %%
file = open("B12.txt","r")

# %%
file.read()
# Out:
# 'Hello ClassHello student'

# %%
file.close()

# %%
file = open("B12.txt","x")
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 file = open("B12.txt","x")
#
# FileExistsError: [Errno 17] File exists: 'B12.txt'

# %%
file = open("B13.txt","x")

# %%
file.close()

# %%
file = open("B13.txt","wb")

# %%
file.write("I love Python")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 file.write("I love Python")
#
# TypeError: a bytes-like object is required, not 'str'

# %%
file.write(b"I love Python")
# Out:
# 13

# %%
file.close()

# %%
file = open("B13.txt","rb")

# %%
file.read()
# Out:
# b'I love Python'

# %%
file.tell()
# Out:
# 13

# %%
file.seek(5,0)
# Out:
# 5

# %%
file.read()
# Out:
# b'e Python'

# %%
file.seek(-3,2)
# Out:
# 10

# %%
file.read()
# Out:
# b'hon'

# %%
file.tell()
# Out:
# 13

# %%
file.seek(0,0)
# Out:
# 0

# %%
file.seek(5,0)
# Out:
# 5

# %%
file.seek(2,1)
# Out:
# 7

# %%
file.seek(2,0)
# Out:
# 2

# %%
file.seek(-2,1)
# Out:
# 0

# %%
file.read(5)
# Out:
# b'I lov'

# %%
file.tell()
# Out:
# 5

# %%
file.read(2)
# Out:
# b'e '

# %%
file.close()

# %%
file = open("B13.txt","rb+")

# %%
file.readline()
# Out:
# b'I love Python\n'

# %%
file.readline()
# Out:
# b'I Hate Coding\n'

# %%
file.readline()
# Out:
# b'I Love Data Analysis'

# %%
file.readline()
# Out:
# b''

# %%
file.readline?
# Out:
# Signature: file.readline(size=-1, /)
# Docstring:
# Read and return a line from the stream.
#
# If size is specified, at most size bytes will be read.
#
# The line terminator is always b'\n' for binary files; for text
# files, the newlines argument to open can be used to select the line
# terminator(s) recognized.
# Type:      builtin_function_or_method

# %%
file.tell()
# Out:
# 48

# %%
file.seek(0,0)
# Out:
# 0

# %%
file.readlines()
# Out:
# [b'I love Python\n', b'I Hate Coding\n', b'I Love Data Analysis']

# %%
file.readlines()
# Out:
# []

# %%
file.write(b"\nI Love Machine Learning")
# Out:
# 23

# %%
file.tell()
# Out:
# 71

# %%
file.seek(0,0)
# Out:
# 0

# %%
file.readlines()
# Out:
# [b'I love Python\n',
#  b'I Hate Coding\n',
#  b'I Love Data AnalysisI Love Machine Learning']

# %%
file.write(b"\nI Love Machine Learning")
# Out:
# 24

# %%
file.seek(0)
# Out:
# 0

# %%
inputlines = file.readlines()

# %%
file.writelines(inputlines)

# %%
file.tell()
# Out:
# 190

# %%
file.seek(0)
# Out:
# 0

# %%
file.readlines()
# Out:
# [b'I love Python\n',
#  b'I Hate Coding\n',
#  b'I Love Data AnalysisI Love Machine Learning\n',
#  b'I Love Machine LearningI love Python\n',
#  b'I Hate Coding\n',
#  b'I Love Data AnalysisI Love Machine Learning\n',
#  b'I Love Machine Learning']

# %%
file.close()
