# %% [markdown]
# # Tuple

# %% [markdown]
# tuple - - > ()

# %%
tup1 = ()

# %%
type(tup1)
# Out:
# tuple

# %% [markdown]
# ## Tuple is immutable -- size can not grow or shrink,

# %%
tup2 = (1,2,5,6,4)

# %%
type(tup2)
# Out:
# tuple

# %%
tup2[0]
# Out:
# 1

# %%
tup2[-1]
# Out:
# 4

# %%
tup2[-4:-1]
# Out:
# (2, 5, 6)

# %% [markdown]
# ## indexiing and slicing supported

# %%
tup3 = (1,2,5,"adfh",[25,56],(56,"sdfs"))

# %%
len(tup3)
# Out:
# 6

# %%
del tup3[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 del tup3[0]
#
# TypeError: 'tuple' object doesn't support item deletion

# %%
tup3
# Out:
# (1, 2, 5, 'adfh', [25, 56], (56, 'sdfs'))

# %%
tup3[0] = 25
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 tup3[0] = 25
#
# TypeError: 'tuple' object does not support item assignment

# %%
tup3[4][1]
# Out:
# 56

# %%
tup3[4][1] = 57

# %%
tup3
# Out:
# (1, 2, 5, 'adfh', [25, 57], (56, 'sdfs'))

# %%
tup3[-1][0]=45
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 tup3[-1][0]=45
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ## Tuple Methods

# %%
tup3
# Out:
# (1, 2, 5, 'adfh', [25, 57], (56, 'sdfs'))

# %%
tup3.count?
# Out:
# Signature: tup3.count(value, /)
# Docstring: Return number of occurrences of value.
# Type:      builtin_function_or_method

# %%
tup3.count(1)
# Out:
# 1

# %%
tup3.count("f")
# Out:
# 0

# %%
tup3.count(5)
# Out:
# 1

# %%
tup3.count(57)
# Out:
# 0

# %%
tup3[4].count(57)
# Out:
# 1

# %%
tup3.index(5)
# Out:
# 2

# %%
tup3.index("g")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 tup3.index("g")
#
# ValueError: tuple.index(x): x not in tuple

# %% [markdown]
# ### List Vs Tuple

# %%
lis=[1,2,3,4]

# %%
tup=(1,2,3,4)

# %%
import sys

# %%
sys.getsizeof(lis)
# Out:
# 88

# %%
sys.getsizeof(tup)
# Out:
# 72

# %%
sys.getsizeof?
# Out:
# Docstring:
# getsizeof(object [, default]) -> int
#
# Return the size of object in bytes.
# Type:      builtin_function_or_method

# %%
16/72
# Out:
# 0.2222222222222222

# %%
# memory wise tuple is more efficient

# %%
#tuple is faster than list because  of operation overhead

# %%
# flexibility is inbuilt in list

# %% [markdown]
# ## Tuple can be hashable or vice versa
