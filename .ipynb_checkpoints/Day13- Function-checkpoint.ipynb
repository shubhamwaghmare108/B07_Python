# %%
print("Hello,Everyone")

# %% [markdown]
# # Standard Function in python

# %% [raw]
# def functionname(parameter):
#     main body
#     optional return

# %%
def addition(x,y):
    print("Hello,User.\nThis is the result of your calculation:")
    print(x),print(y)
    print(x+y)
    return 1

# %%
z = addition(10,20)
# Out:
# Hello,User.
# This is the result of your calculation:
# 10
# 20
# 30

# %%
z
# Out:
# 1

# %%
addition("Shubham ","Waghmare")
# Out:
# Hello,User.
# This is the result of your calculation:
# Shubham
# Waghmare
# Shubham Waghmare
# 'Shubham Waghmare'

# %%
addition("Shubham",7)
# Out:
# Hello,User.
# This is the result of your calculation:
# Shubham
# 7
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 addition("Shubham",7)
#
# Cell In[3], line 4, in addition(x, y)
#       2 print("Hello,User.\nThis is the result of your calculation:")
#       3 print(x),print(y)
# ----> 4 print(x+y)
#       5 return x+y
#
# TypeError: can only concatenate str (not "int") to str

# %%
def addition(x,y):
    print(x+y)

# %%
addition(10,51)
# Out:
# 61

# %%
y = addition(10,51)

# %%
y

# %%
print(y)

# %%
var

# %%
def greet():
    print("Hello,User!")

# %%
greet()
# Out:
# Hello,User!

# %%
greet("Shubham")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 greet("Shubham")
#
# TypeError: greet() takes 0 positional arguments but 1 was given

# %%
addition(10,20,30)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 addition(10,20,30)
#
# TypeError: addition() takes 2 positional arguments but 3 were given

# %% [markdown]
# ## default argument

# %%
def greet(name = "User"):
    print(f"Hello,{name}!")

# %%
greet("Shubham")
# Out:
# Hello,Shubham!

# %%
greet()
# Out:
# Hello,User!

# %%
positional,keyward

# %%
greet(name = "Shubham")

# %%
def sub(x:int = 1,y:int = 1)->int:
    """
    takes two arguments x and y and return there subtraction
    """
    return x - y

# %%
sub(x = 5,y = 10)
# Out:
# -5

# %%
sub(y = 5,x = 10)
# Out:
# 5

# %%
sub(5,10)
# Out:
# -5

# %%
sub(10,5)
# Out:
# 5

# %% [markdown]
# ## order of arguments

# %%
sub(y = 10,5)
# Out:
#   Cell In[35], line 1
#     sub(y = 10,5)
#                 ^
# SyntaxError: positional argument follows keyword argument

# %% [markdown]
# ## first -positional,second -keyward

# %%
sub(x=10,5)
# Out:
#   Cell In[36], line 1
#     sub(x=10,5)
#               ^
# SyntaxError: positional argument follows keyword argument

# %%
sub(5,y = 5)
# Out:
# 0

# %%
sub(5,x = 5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 sub(5,x = 5)
#
# TypeError: sub() got multiple values for argument 'x'

# %%
sub?
# Out:
# Signature: sub(x: int = 1, y: int = 1) -> int
# Docstring: takes two arguments x and y and return there subtraction
# File:      c:\users\hp\appdata\local\temp\ipykernel_12908\88617922.py
# Type:      function

# %%
sub()
# Out:
# 0

# %%
print?
# Out:
# Signature: print(*args, sep=' ', end='\n', file=None, flush=False)
# Docstring:
# Prints the values to a stream, or to sys.stdout by default.
#
# sep
#   string inserted between values, default a space.
# end
#   string appended after the last value, default a newline.
# file
#   a file-like object (stream); defaults to the current sys.stdout.
# flush
#   whether to forcibly flush the stream.
# Type:      builtin_function_or_method

# %% [markdown]
# ### variable length argument

# %%
*args,**kwargs

# %%
def minus(x,y,/,z):
    return x-y-z

# %%
minus(10,5,2)

# %%
minus(x=10,y=5,z=2)

# %%
minus(10,5,z=2)

# %%
def minus(x,y,/,z,c,*,d,f):
    return x-y-z-c-d-f

# %%
minus(10,20,3,54,64,58)

# %%
parameter :
    1.positional only before /
    2.keyword only after *
    3.standard -(p+k)

# %%
minus(10,20,3,54,d=64,f=58)

# %%
minus(10,20,3,54,f=58,d=64)

# %%
minus(10,20,z=3,c=54,f=58,d=64)

# %%
minus(10,20,3,c=54,f=58,d=64)

# %%
def add(*nums):
    
    return type(nums)

# %%
add(10,20,3)

# %%
nums

# %%
def minus(**nums):
    print(nums)
    return type(nums)

# %%
minus(12,35,56)

# %%
minus(x=12,y=35,z=56)

# %%
def minus(z,x,c,*args):
    return args,z,x,c

# %%
minus(1,2,0,5,2,2,0,5,0,5,0,4,0,5,0,4,0,4,0,4)

# %%
def minus(*args,z,x,c):
    return args,z,x,c

# %%
minus(1,2,0,5,2,2,0,5,0,5,0,4,0,5,0,4,0,4,0,4)

# %%
minus(1,2,0,5,2,2,0,5,0,5,0,4,0,5,0,4,0,z=4,x=0,c=4)

# %%
def fd(c,v):
    return c*v
    print("ok")

# %%
fd(5,3)
# Out:
# 15

# %%
fd(c=5,v=3)
# Out:
# 15

# %%
fd(5,v=3)
# Out:
# 15

# %%
fd(v=5,3)
# Out:
#   Cell In[5], line 1
#     fd(v=5,3)
#             ^
# SyntaxError: positional argument follows keyword argument

# %%
fd(5,c=3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 fd(5,c=3)
#
# TypeError: fd() got multiple values for argument 'c'

# %%
def addition(x,y):
    return x + y

# %%
addition(5,3)
# Out:
# 8

# %%
def addition(*nums):
    print(type(nums))
    print(nums)
    return sum(nums)

# %%
addition(5,3)
# Out:
# <class 'tuple'>
# (5, 3)
# 8

# %%
addition(5,3,8)
# Out:
# <class 'tuple'>
# (5, 3, 8)
# 16

# %%
addition()
# Out:
# <class 'tuple'>
# ()
# 0

# %%
(3,5,8)
# Out:
# (3, 5, 8)

# %%
(12,3)+(3,)
# Out:
# (12, 3, 3)

# %%
def addition(name,**nums):
    print(type(nums))
    print(nums)
    print(name)

# %%
addition("Shubham")
# Out:
# <class 'dict'>
# {}
# Shubham

# %%
addition("Shubham",age = 30,edu = "Graduate",age = 31)
# Out:
#   Cell In[33], line 1
#     addition("Shubham",age = 30,edu = "Graduate",age = 31)
#                                                  ^
# SyntaxError: keyword argument repeated: age

# %%
def info(name,*marks,**result):
    print(name)
    print(sum(marks))
    print(result)

# %%
info("shubham",80,90,99,100,75,grade = "distinction",final_result = "pass")
# Out:
# shubham
# 444
# {'grade': 'distinction', 'final_result': 'pass'}

# %%
info(name = "shubham",80,90,99,100,75,grade = "distinction",final_result = "pass")
# Out:
#   Cell In[36], line 1
#     info(name = "shubham",80,90,99,100,75,grade = "distinction",final_result = "pass")
#                                                                                      ^
# SyntaxError: positional argument follows keyword argument

# %%
info(80,90,99,100,75,grade = "distinction",final_result = "pass",name = "shubham")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 info(80,90,99,100,75,grade = "distinction",final_result = "pass",name = "shubham")
#
# TypeError: info() got multiple values for argument 'name'

# %%
def sd(science,maths,*marks):
    print(science)
    print(maths)
    print(marks)

# %%
sd(20,30,50,"shubham",70)
# Out:
# 20
# 30
# (50, 'shubham', 70)

# %%
sd(20,30)
# Out:
# 20
# 30
# ()

# %%
def sd(science,/,maths,**subjects):
    print(science)
    print(maths)
    print(subjects)

# %%
sd(45,65,history = 75,literature = 80)
# Out:
# 45
# 65
# {'history': 75, 'literature': 80}

# %%
sd(science = 45,maths = 65,history = 75,literature = 80)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 sd(science = 45,maths = 65,history = 75,literature = 80)
#
# TypeError: sd() missing 1 required positional argument: 'science'

# %%
def sd(science,*,maths,**subjects):
    print(science)
    print(maths)
    print(subjects)

# %%
sd(45,65,history = 75,literature = 80)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 sd(45,65,history = 75,literature = 80)
#
# TypeError: sd() takes 1 positional argument but 2 were given

# %%
sd(science = 45,maths = 65,history = 75,literature = 80)
# Out:
# 45
# 65
# {'history': 75, 'literature': 80}

# %%
j
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 j
#
# NameError: name 'j' is not defined

# %%
x = 10

def dfg():
    x = 25
    print(x)

# %%
x
# Out:
# 10

# %%
dfg()
# Out:
# 25

# %%
x
# Out:
# 10

# %%
x=20

# %%
x
# Out:
# 20
