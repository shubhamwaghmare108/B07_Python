# %% [markdown]
# # Complete Pandas Tutorial
#
# Pandas is the most popular Python library for data manipulation and analysis. It provides two primary data structures:
# - **Series**: 1D labeled array
# - **DataFrame**: 2D labeled data structure (like a spreadsheet)
#
# This tutorial covers everything from basics to advanced operations like merging, grouping, handling missing data, and visualization.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Set display options
pd.set_option('display.max_columns', None)
np.random.seed(42)

# %% [markdown]
# ## 1. Series – One-Dimensional Labeled Array

# %%
s1 = pd.Series([1, 2, 3, 4, 5])
print("Default index:")
print(s1)

# %%
s1[0]

# %%
s2 = pd.Series([1, 2, 3, 4], index=['A', 'B', 'C', 'D'])
print("\nCustom index:")
print(s2)

# %%
s2.at['A']

# %%
s2.iat[0]

# %%
s3 = pd.Series({'a': 10, 'b': 20, 'c': 30})
print("\nFrom dict:")
print(s3)

# %%
# From list
s1 = pd.Series([1, 2, 3, 4, 5])
print("Default index:")
print(s1)

# With custom index
s2 = pd.Series([1, 2, 3, 4], index=['A', 'B', 'C', 'D'])
print("\nCustom index:")
print(s2)

# From dictionary (keys become index)
s3 = pd.Series({'a': 10, 'b': 20, 'c': 30})
print("\nFrom dict:")
print(s3)

# %%
s2.iloc[1:3]

# %%
s2.loc['B':'C']

# %%
s2

# %%
s2[1:3]

# %%
s2['B':'C']

# %%
s2

# %%
s2+10

# %%
s2.mean()

# %%
s2.max()

# %%
s2.min()

# %%
s2.sum()

# %%
len(s2)

# %%
type(s2)

# %%
s2>3

# %%
s2[s2>3]

# %%
s2.where(s2%2==0,'Odd')

# %%
# Accessing elements
print("By integer position:", s2.iat[0])        # 1
print("By label:", s2['B'])                # 2
print("Slicing by label (includes end):", s2['B':'D'])  # B 2, C 3, D 4
print("Slicing by position (excludes end):", s2[1:3])   # B 2, C 3

# Vectorized operations
print("s2 + 10:\n", s2 + 10)
print("s2.mean():", s2.mean())
print("s2 > 2:\n", s2 > 2)

# %% [markdown]
# ## 2. DataFrame – Two-Dimensional Table

# %% [markdown]
# ### Creating DataFrames

# %%
df = pd.DataFrame({
    'Name': ['Alice', 'Bob', 'Charlie', 'Diana'],
    'Age': [25, 30, 35, 28],
    'City': ['New York', 'London', 'Paris', 'Tokyo']
},index = ['A','B','C','D'])
print("DataFrame from dict:\n", df)

# %%
df = pd.DataFrame({
    'Name': ('Alice', 'Bob', 'Charlie', 'Diana','Shubham'),
    'Age': (25, 30, 35, 28,np.nan),
    'City': ('New York', 'London', 'Paris', 'Tokyo',np.nan)
},index = ['A','B','C','D','E'])
print("DataFrame from dict:\n", df)

# %%
data = [
    {'Name': 'Alice', 'Age': 25, 'City': 'New York'},
    {'Name': 'Bob', 'Age': 30, 'City': 'London'}
]
df2 = pd.DataFrame(data)
print("\nFrom list of dicts:\n", df2)

# %%
arr = np.array([[1, 2, 3], [4, 5, 6]])
df3 = pd.DataFrame(arr, index = ['Row1','Row2'],columns=['A', 'B', 'C'])
print("\nFrom NumPy array:\n", df3)

# %%
type(df3)

# %%
# From dictionary of lists
df = pd.DataFrame({
    'Name': ['Alice', 'Bob', 'Charlie', 'Diana'],
    'Age': [25, 30, 35, 28],
    'City': ['New York', 'London', 'Paris', 'Tokyo']
},index = ['A','B','C','D'])
print("DataFrame from dict:\n", df)

# From list of dictionaries
data = [
    {'Name': 'Alice', 'Age': 25, 'City': 'New York'},
    {'Name': 'Bob', 'Age': 30, 'City': 'London'}
]
df2 = pd.DataFrame(data)
print("\nFrom list of dicts:\n", df2)

# From NumPy array
arr = np.array([[1, 2, 3], [4, 5, 6]])
df3 = pd.DataFrame(arr, index = ['Row1','Row2'],columns=['A', 'B', 'C'])
print("\nFrom NumPy array:\n", df3)

# %% [markdown]
# ### DataFrame Attributes

# %%
print("Shape:", df.shape)
print("Columns:", df.columns.tolist())
print("Index:", df.index.tolist())
print("Data types:\n", df.dtypes)
print("\nInfo:")
df.info()

# %%
type(df)

# %% [markdown]
# ### Previewing Data

# %%
titanic = pd.read_excel('Titanic.xlsx')

# %%
titanic

# %%
titanic.to_json('Titanic_demo.json',index = False)

# %%
titanic.to_csv('Titanic_demo.csv',index = False)

# %%
score = pd.read_json(r"C:\Users\SHUBHAM\Desktop\RockPaperScissor\score.json")

# %%
score

# %%
record = pd.read_csv(r"C:\Users\SHUBHAM\Desktop\B07_Python\demo.txt")

# %%
record

# %%
record['age'] = 20

# %%
record

# %%
record.to_csv(r"C:\Users\SHUBHAM\Desktop\RockPaperScissor\demo.csv",index = 0)

# %%
demo = pd.read_csv(r"C:\Users\SHUBHAM\Desktop\RockPaperScissor\demo.csv")

# %%
demo

# %%
demo.to_excel(r"C:\Users\SHUBHAM\Desktop\RockPaperScissor\demo.xlsx",index=False) # xlrd,openpyxl

# %%
titanic = pd.read_excel("Titanic.xlsx")

# %%
titanic

# %%
titanic.info()

# %%
titanic.nunique()

# %%
titanic['Survived'].nunique()

# %%
titanic['Survived'].unique()

# %%
titanic.columns.to_list()

# %%
titanic.index.to_list()

# %%
titanic['Pclass'].unique()

# %%
titanic['Sex'].unique()

# %%
titanic['Embarked'].unique()

# %%
titanic.unique()

# %%
titanic.head(10)

# %%
titanic.tail(10)

# %%
titanic.sample(10)

# %%
titanic.describe()

# %%
titanic.columns

# %%
titanic['Name']

# %%
titanic[['Name']]

# %%
titanic[[ 'Pclass','Survived', 'Name', 'Sex', 'Age']]

# %%
titanic.loc[0,'Name']

# %%
titanic.at[0,'Name']

# %%
titanic.info()

# %%
titanic.iat[0,3]

# %%
titanic.iloc[0,3]

# %%
titanic.iloc[:25,3:5]

# %%
titanic.iloc[:,3]

# %%
titanic.iloc[:,[3,1,2,5]]

# %%
titanic.iloc[:,3:]

# %%
type(titanic['Name'])

# %%
type(titanic[['Name']])

# %%
titanic['Name']

# %%
titanic[['Name']]

# %%
# Using sample dataset (Titanic from seaborn or built-in)
titanic = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')
print("Head (first 5 rows):")
print(titanic.head())
print("\nTail (last 5 rows):")
print(titanic.tail())
print("\nRandom sample (3 rows):")
print(titanic.sample(3))
print("\nShape:", titanic.shape)

# %%
titanic.isnull().sum()

# %%
titanic.isnull().mean()*100

# %%
titanic.isnull().sum()

# %%
titanic.dropna()

# %%
titanic[titanic.isna().any(axis=1)]

# %%
titanic.head()

# %%
titanic.tail()

# %%
titanic.head(10)

# %%
titanic.tail(10)

# %%
titanic.sample()

# %%
titanic.sample(5)

# %% [markdown]
# ## 3. Indexing and Selection
#
# - `df[column]` – select a column (returns Series)
# - `df[[col1, col2]]` – select multiple columns (returns DataFrame)
# - `df.loc[row_label, column_label]` – label-based indexing
# - `df.iloc[row_position, column_position]` – integer position-based
# - `df.at[row_label, col_label]` – fast scalar access
# - `df.iat[row_pos, col_pos]` – fast integer scalar access

# %%
titanic.columns.to_list()

# %%
titanic['Name']

# %%
titanic[['Name']]

# %%
titanic[['Name','Age']]

# %%
titanic.info()

# %%
titanic[['Age',"Name"]]

# %%
titanic[[0,1]]

# %%
titanic.head()

# %%
titanic.at[0,'Name']

# %%
titanic.at[0,"Age"]

# %%
titanic.iat[0,1]

# %%
titanic.loc[0,:]

# %%
titanic.loc[0:4,:]

# %%
titanic.iloc[0:5,:]

# %%
titanic.loc[[1,0,3,4,2],:]

# %%
# Column selection
print("Single column (Series):\n", titanic['Name'].head(2))
print("\nMultiple columns (DataFrame):\n", titanic[['Name', 'Age']].head(2))

# Row selection with .loc
print("\nRow 0 with .loc:")
print(titanic.loc[0])
print("\nRows 0-2, columns 'Name' and 'Age' with .loc:")
print(titanic.loc[0:2, ['Name', 'Age']])   # label slice includes end

# Row selection with .iloc
print("\nFirst row with .iloc:")
print(titanic.iloc[0])
print("\nRows 0-2 (excludes 3), columns 2-4 with .iloc:")
print(titanic.iloc[0:3, 2:5])

# Fast scalar access
print("\n.at[0, 'Name']:", titanic.at[0, 'Name'])
print(".iat[0, 2]:", titanic.iat[0, 2])

# %% [markdown]
# ## 4. Boolean Indexing (Filtering)

# %%
titanic['Age'] > 30

# %%
titanic[titanic['Age'] > 30]

# %%
titanic['Embarked'] == 'S'

# %%
titanic[(titanic['Age'] > 30) & (titanic['Embarked'] == 'S') & (titanic['Sex'] == 'female') & (titanic['Pclass'] >1)].shape[0]

# %%
adults = titanic[titanic['Age'] > 30]
print(f"Number of passengers older than 30: {len(adults),adults.shape[0]}")

# %%
titanic.shape[1]

# %%
(titanic['Age']>70).sum()

# %%
data = np.where(titanic['Age']<10,'Child','Not Child')

# %%
data

# %%
titanic.insert(6,"IsChild",data)

# %%
titanic.query("IsChild=='Child'")

# %%
titanic

# %%
titanic.query("Age>70 and Survived == 1")

# %%
titanic[titanic['Age']>70]

# %%
titanic[(titanic['Pclass'] == 1) & ~(titanic['Sex'] == 'female')]

# %%
titanic[(titanic['Pclass'] == 1) | ~(titanic['Sex'] == 'female')]

# %%
titanic[(titanic['Pclass'] == 1) | (titanic['Sex'] == 'female')]

# %%
titanic[(titanic['Pclass'] == 1) & (titanic['Sex'] == 'female')]

# %%
titanic[titanic['Pclass'] == 1]

# %%
# Single condition
adults = titanic[titanic['Age'] > 30]
print(f"Number of passengers older than 30: {len(adults)}")

# Multiple conditions (& for AND, | for OR, ~ for NOT)
rich_females = titanic[(titanic['Sex'] == 'female') & (titanic['Pclass'] == 1)]
print(f"\nFirst class females: {len(rich_females)}")
print(rich_females[['Name', 'Age', 'Fare']].head())

# Using .isin()
southampton = titanic[titanic['Embarked'].isin(['S', 'C'])]
print(f"\nPassengers from Southampton or Cherbourg: {len(southampton)}")

# Using .query() (alternative syntax)
young_males = titanic.query('Age < 18 and Sex == "male"')
print(f"\nYoung males: {len(young_males)}")

# %% [markdown]
# ## 5. Sorting

# %%
titanic.sort_values('Age', ascending=True)

# %%
titanic.sort_values?

# %%
x = titanic.sort_values(by = ['Age','Name'],ascending=[True,True])

# %%
X = x.sort_index(axis=1,ascending =False)

# %%
x

# %%
X.sort_index(axis = 0,ascending = False)

# %%
# Sort by single column
by_age = titanic.sort_values('Age', ascending=False)
print("Oldest passengers:")
print(by_age[['Name', 'Age']].head())

# Sort by multiple columns
by_class_age = titanic.sort_values(['Pclass', 'Age'], ascending=[True, False])
print("\nSort by Pclass (ascending), then Age (descending):")
print(by_class_age[['Pclass', 'Name', 'Age']].head())

# Sort by index
titanic_sorted_index = titanic.sort_index(ascending=False)
print("\nIndex sorted descending:", titanic_sorted_index.index[:5].tolist())

# %% [markdown]
# ## 6. Handling Missing Data

# %%
titanic[titanic['Embarked'].isnull()]

# %%
titanic.isnull().mean()*100

# %%
titanic.isnull().sum()

# %%
titanic['Embarked'].isnull()

# %%
titanic['Age'].mean()

# %%
titanic['Age'].median()

# %%
titanic

# %%
fill_df  = titanic.fillna({'Age':titanic['Age'].mean()})

# %%
fill_df.fillna?

# %%
fill_df = fill_df.fillna({'Embarked':'S'})

# %%
fill_df.isnull().sum()

# %%
fill_df.drop('Cabin',axis=1)

# %%
fill_df.drop(columns = ['Cabin'],inplace=True)

# %%
fill_df.isna().sum()

# %%
titanic['Embarked'].mode()

# %%
titanic.fillna({'Embarked':}

# %%
titanic['Age'].fillna(titanic['Age'].mean()).isna().sum()

# %%
titanic[titanic['Embarked'].isnull()]

# %%
titanic['Embarked'].unique()

# %%
titanic['Embarked'].value_counts()

# %%
titanic.isna()

# %%
titanic[titanic.isnull().any(axis=1)]

# %%
x = np.arange(891)

# %%
titanic.insert(0,'X',x)

# %%
titanic

# %%
titanic.insert?

# %%
titanic.insert(0,"Demo",np.nan)

# %%
titanic.dropna(how ='all',axis = 1,inplace = True)

# %%
titanic.rename({'X':'Ser'},axis =1)

# %%
titanic.dropna(how = 'any',axis=1)

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
print("Missing values per column:")
print(titanic.isnull().sum())
print("\nPercentage missing:")
print(titanic.isnull().mean() * 100)
# Out:
# Missing values per column:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64
#
# Percentage missing:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            19.865320
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# Cabin          77.104377
# Embarked        0.224467
# dtype: float64

# %%
titanic.dropna?
# Out:
# Signature:
# titanic.dropna(
#     *,
#     axis: 'Axis' = 0,
#     how: 'AnyAll | lib.NoDefault' = <no_default>,
#     thresh: 'int | lib.NoDefault' = <no_default>,
#     subset: 'IndexLabel | AnyArrayLike | None' = None,
#     inplace: 'bool' = False,
#     ignore_index: 'bool' = False,
# ) -> 'DataFrame | None'
# Docstring:
# Remove missing values.
#
# See the :ref:`User Guide <missing_data>` for more on which values are
# considered missing, and how to work with missing data.
#
# Parameters
# ----------
# axis : {0 or 'index', 1 or 'columns'}, default 0
#     Determine if rows or columns which contain missing values are
#     removed.
#
#     * 0, or 'index' : Drop rows which contain missing values.
#     * 1, or 'columns' : Drop columns which contain missing value.
#
#     Only a single axis is allowed.
#
# how : {'any', 'all'}, default 'any'
#     Determine if row or column is removed from DataFrame, when we have
#     at least one NA or all NA.
#
# ...

# %%
titanic.dropna(how = 'all',axis = 0)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
sample_row = [[nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],[nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]]
for i in range(12):
    sample_row.append(np.nan)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 sample_row = [[nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],[nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]]
#       2 """for i in range(12):
#       3     sample_row.append(np.nan)"""
#
# NameError: name 'nan' is not defined

# %%
sample_row
# Out:
# [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]

# %%
df = pd.concat((titanic,pd.DataFrame(sample_row)),axis=1)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1 = df.iloc[:,:8]

# %%
df2 = df.iloc[:,8:]

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df2
# Out:
#                Ticket     Fare Cabin Embarked   0
# 0           A/5 21171   7.2500   NaN        S NaN
# 1            PC 17599  71.2833   C85        C NaN
# 2    STON/O2. 3101282   7.9250   NaN        S NaN
# 3              113803  53.1000  C123        S NaN
# 4              373450   8.0500   NaN        S NaN
# ..                ...      ...   ...      ...  ..
# 886            211536  13.0000   NaN        S NaN
# 887            112053  30.0000   B42        S NaN
# 888        W./C. 6607  23.4500   NaN        S NaN
# 889            111369  30.0000  C148        C NaN
# 890            370376   7.7500   NaN        Q NaN
#
# [891 rows x 5 columns]

# %%
pd.concat((df1,df2),axis = 1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.dropna(how = "all",axis = 1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df3 = df.iloc[:500,:]

# %%
df4 = df.iloc[500:,:]

# %%
df3
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 495          496         0       3
# 496          497         1       1
# 497          498         0       3
# 498          499         0       1
# 499          500         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df4
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 500          501         0       3                         Calic, Mr. Petar
# 501          502         0       3                       Canavan, Miss Mary
# 502          503         0       3            O'Sullivan, Miss Bridget Mary
# 503          504         0       3            Laitinen, Miss Kristina Sofia
# 504          505         1       1                     Maioni, Miss Roberta
# ..           ...       ...     ...                                      ...
# 886          887         0       2                    Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss Margaret Edith
# 888          889         0       3  Johnston, Miss Catherine Helen "Carrie"
# 889          890         1       1                    Behr, Mr. Karl Howell
# 890          891         0       3                      Dooley, Mr. Patrick
#
# ...

# %%
pd.concat((df3,df4))
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.bfill().isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          1
# Embarked       0
# dtype: int64

# %%
titanic.duplicated?
# Out:
# Signature:
# titanic.duplicated(
#     subset: 'Hashable | Iterable[Hashable] | None' = None,
#     keep: 'DropKeep' = 'first',
# ) -> 'Series'
# Docstring:
# Return boolean Series denoting duplicate rows.
#
# Considering certain columns is optional.
#
# Parameters
# ----------
# subset : column label or iterable of labels, optional
#     Only consider certain columns for identifying duplicates, by
#     default use all of the columns.
# keep : {'first', 'last', False}, default 'first'
#     Determines which duplicates (if any) to mark.
#
#     - ``first`` : Mark duplicates as ``True`` except for the first occurrence.
#     - ``last`` : Mark duplicates as ``True`` except for the last occurrence.
#     - False : Mark all duplicates as ``True``.
#
# Returns
# -------
# Series
#     Boolean series for each duplicated rows.
#
# See Also
# --------
# Index.duplicated : Equivalent method on index.
# Series.duplicated : Equivalent method on Series.
# ...

# %%
duplicate = pd.concat((titanic,titanic))

# %%
duplicate.duplicated().sum()
# Out:
# 891

# %%
duplicate = duplicate.set_index('PassengerId')

# %%
duplicate = duplicate.drop(columns = ['index'])

# %%
duplicate = duplicate.drop_duplicates()

# %%
duplicate
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                        Heikkinen, Miss Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
duplicate.rename?
# Out:
# Signature:
# duplicate.rename(
#     mapper: 'Renamer | None' = None,
#     *,
#     index: 'Renamer | None' = None,
#     columns: 'Renamer | None' = None,
#     axis: 'Axis | None' = None,
#     copy: 'bool | lib.NoDefault' = <no_default>,
#     inplace: 'bool' = False,
#     level: 'Level | None' = None,
#     errors: 'IgnoreRaise' = 'ignore',
# ) -> 'DataFrame | None'
# Docstring:
# Rename columns or index labels.
#
# Function / dict values must be unique (1-to-1). Labels not contained in
# a dict / Series will be left as-is. Extra labels listed don't throw an
# error.
#
# See the :ref:`user guide <basics.rename>` for more.
#
# Parameters
# ----------
# mapper : dict-like or function
#     Dict-like or function transformations to apply to
#     that axis' values. Use either ``mapper`` and ``axis`` to
#     specify the axis to target with ``mapper``, or ``index`` and
#     ``columns``.
# index : dict-like or function
#     Alternative to specifying axis (``mapper, axis=0``
# ...

# %%
duplicate.rename({'Sex':'Gender'},axis =1)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name  Gender   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                        Heikkinen, Miss Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
duplicate[duplicate.duplicated(subset=['Sex','Age'])]
# Out:
#              Survived  Pclass  \
# PassengerId
# 15                  0       3
# 17                  0       3
# 18                  1       2
# 21                  0       2
# 26                  1       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 15                         Vestrom, Miss Hulda Amanda Adolfina  female  14.0
# 17                                         Rice, Master Eugene    male   2.0
# 18                                Williams, Mr. Charles Eugene    male   NaN
# 21                                        Fynney, Mr. Joseph J    male  35.0
# 26           Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0
# ...                                                        ...     ...   ...
# ...

# %%
duplicate.drop_duplicates(keep = 'first')
# Out:
#      index  PassengerId  Survived  Pclass  \
# 0        0            1         0       3
# 1        1            2         1       1
# 2        2            3         1       3
# 3        3            4         1       1
# 4        4            5         0       3
# ..     ...          ...       ...     ...
# 886    886          887         0       2
# 887    887          888         1       1
# 888    888          889         0       3
# 889    889          890         1       1
# 890    890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
titanic.duplicated?
# Out:
# Signature:
# titanic.duplicated(
#     subset: 'Hashable | Iterable[Hashable] | None' = None,
#     keep: 'DropKeep' = 'first',
# ) -> 'Series'
# Docstring:
# Return boolean Series denoting duplicate rows.
#
# Considering certain columns is optional.
#
# Parameters
# ----------
# subset : column label or iterable of labels, optional
#     Only consider certain columns for identifying duplicates, by
#     default use all of the columns.
# keep : {'first', 'last', False}, default 'first'
#     Determines which duplicates (if any) to mark.
#
#     - ``first`` : Mark duplicates as ``True`` except for the first occurrence.
#     - ``last`` : Mark duplicates as ``True`` except for the last occurrence.
#     - False : Mark all duplicates as ``True``.
#
# Returns
# -------
# Series
#     Boolean series for each duplicated rows.
#
# See Also
# --------
# Index.duplicated : Equivalent method on index.
# Series.duplicated : Equivalent method on Series.
# ...

# %%
titanic.insert?
# Out:
# Signature:
# titanic.insert(
#     loc: 'int',
#     column: 'Hashable',
#     value: 'object',
#     allow_duplicates: 'bool | lib.NoDefault' = <no_default>,
# ) -> 'None'
# Docstring:
# Insert column into DataFrame at specified location.
#
# Raises a ValueError if `column` is already contained in the DataFrame,
# unless `allow_duplicates` is set to True.
#
# Parameters
# ----------
# loc : int
#     Insertion index. Must verify 0 <= loc <= len(columns).
# column : str, number, or hashable object
#     Label of the inserted column.
# value : Scalar, Series, or array-like
#     Content of the inserted column.
# allow_duplicates : bool, optional, default lib.no_default
#     Allow duplicate column labels to be created.
#
# See Also
# --------
# Index.insert : Insert new item by index.
#
# Examples
# --------
# >>> df = pd.DataFrame({"col1": [1, 2], "col2": [3, 4]})
# >>> df
#    col1  col2
# 0     1     3
# 1     2     4
# >>> df.insert(1, "newcol", [99, 99])
# >>> df
# ...

# %%
# Detect missing values
print("Missing values per column:")
print(titanic.isnull().sum())
print("\nPercentage missing:")
print(titanic.isnull().mean() * 100)

# Drop rows with any missing values
titanic_dropped_rows = titanic.dropna()
print(f"\nShape after dropna(): {titanic_dropped_rows.shape}")

# Drop columns with any missing values
titanic_dropped_cols = titanic.dropna(axis=1)
print(f"Shape after dropna(axis=1): {titanic_dropped_cols.shape}")
age_fill = titanic_filled['Age'].median()
print(age_fill)
embarked_fill = titanic_filled['Embarked'].mode()[0]
# Fill missing values
titanic_filled = titanic.copy()
titanic_filled.fillna({'Age':age_fill,'Embarked':embarked_fill},inplace = True)
#titanic_filled['Embarked'].fillna(titanic_filled['Embarked'].mode()[0], inplace=True)
print(f"\nMissing Age after median fill: {titanic_filled['Age'].isnull().sum()}")

# Forward fill and backward fill
sample_series = pd.Series([1, 2, None, 4, None, 6])
print("\nOriginal:", sample_series.tolist())
print("Forward fill:", sample_series.fillna(method='ffill').tolist())
#print("Backward fill:", sample_series.fillna(method='bfill').tolist())
titanic_filled.isna().sum()

# %%
titanic.ffill?

# %%
titanic_filled.drop('Cabin',axis=1)

# %% [markdown]
# ## 7. Data Type Conversion

# %%
titanic.isna().sum()

# %%
titanic.dtypes

# %%
pd.to_numeric?

# %%
# Check dtypes
print("Original dtypes:\n", titanic.dtypes)

# Convert to string
titanic['Survived_str'] = titanic['Survived'].astype(str)

# Convert to category (memory efficient)
titanic['Sex_cat'] = titanic['Sex'].astype('category')

# Convert to numeric (coerce errors)
titanic['Fare_numeric'] = pd.to_numeric(titanic['Fare'], errors='coerce')

# Convert to datetime
date_df = pd.DataFrame({'date_str': ['2024-01-15', '2024-02-20']})
date_df['date'] = pd.to_datetime(date_df['date_str'])
print("\nDatetime conversion:\n", date_df.dtypes)

# %%
date_df = pd.DataFrame({'date_str': ['2024-15-january', '2024-20-february','123a']})

# %%
date_df.dtypes

# %%
pd.to_datetime?

# %%
date_df['date'] = pd.to_datetime(date_df['date_str'],errors ='coerce',format='%Y-%d-%B')
print("\nDatetime conversion:\n", date_df.dtypes)

# %%
date_df

# %%
date_df['date'].dt.strftime('%y-%b-%a')

# %% [markdown]
# ## 8. Aggregations (Summary Statistics)

# %%
titanic.describe()

# %%
titanic.query('Fare > 31').groupby('Sex')['Fare'].mean()

# %%
titanic.query('Fare>512')

# %%
titanic.query('Fare > 31').groupby('Sex')['Fare'].min()

# %%
titanic['Sex'].unique()

# %%
titanic['Pclass'].unique()

# %%
titanic['Pclass'].nunique()

# %%
titanic.nunique()

# %%
titanic['Embarked'].unique()

# %%
titanic.unique()

# %%
# Basic statistics for numeric columns
print("describe():")
print(titanic.describe())

# Specific aggregates
print(f"\nMean Age: {titanic['Age'].mean():.2f}")
print(f"Median Fare: {titanic['Fare'].median():.2f}")
print(f"Max Age: {titanic['Age'].max():.2f}")
print(f"Min Age: {titanic['Age'].min()}")
print(f"Std Age: {titanic['Age'].std():.2f}")

# For categorical columns
print("\nValue counts for Embarked:")
print(titanic['Embarked'].value_counts())
print("\nUnique values in Sex:", titanic['Sex'].unique())
print("Number of unique tickets:", titanic['Ticket'].nunique())

# %% [markdown]
# ## 9. GroupBy Operations
#
# Split-Apply-Combine: split data into groups, apply a function, combine results.

# %%
titanic.sort_index?

# %%
titanic.groupby('Sex')['Survived'].value_counts().sort_index()

# %%
titanic.groupby('Sex')['Survived'].mean()

# %%
titanic.groupby(['Pclass'])['Sex'].value_counts()

# %%
titanic.groupby(['Pclass', 'Sex'])['Survived'].value_counts()

# %%
titanic.groupby(['Pclass', 'Sex'])['Survived'].mean()

# %%
agg_result = titanic.groupby('Pclass').agg({
    'Age': ['mean', 'min', 'max'],
    'Fare': ['sum', 'mean']
})

# %%
agg_result

# %%
titanic.groupby('Sex').size()

# %%
titanic.groupby('Embarked').size()

# %%
titanic.groupby('Survived').size()

# %%
titanic.groupby('Pclass').size()

# %%
# Single column group
survival_by_sex = titanic.groupby('Sex')['Survived'].mean()
print("Survival rate by sex:")
print(survival_by_sex)

# Multiple columns group
survival_by_class_sex = titanic.groupby(['Pclass', 'Sex'])['Survived'].mean()
print("\nSurvival rate by class and sex:")
print(survival_by_class_sex)

# Multiple aggregations
agg_result = titanic.groupby('Pclass').agg({
    'Age': ['mean', 'min', 'max'],
    'Fare': ['sum', 'mean']
})
print("\nAggregations by Pclass:")
print(agg_result)

# Count per group
print("\nCount by Embarked:")
print(titanic.groupby('Embarked').size())

# Custom aggregation with .apply
def range_func(x):
    return x.max() - x.min()

age_range_by_class = titanic.groupby('Pclass')['Age'].apply(range_func)
print("\nAge range by class:")
print(age_range_by_class)

# %% [markdown]
# ## 10. Merging and Concatenating DataFrames
#
# - `pd.concat()` – stack DataFrames vertically (rows) or horizontally (columns)
# - `pd.merge()` – join DataFrames on keys (like SQL joins)

# %%
# Create sample data
df_left = pd.DataFrame({'key': ['A', 'B', 'C'], 'value_left': [1, 2, 3]})
df_right = pd.DataFrame({'key': ['B', 'C', 'D'], 'value_right': [4, 5, 6]})
print("Left DataFrame:\n", df_left)
print("\nRight DataFrame:\n", df_right)

# %%
# Concatenate vertically (rows)
df_concat_rows = pd.concat([df_left, df_right], ignore_index=True)
print("\nConcatenated rows:\n", df_concat_rows)

# %%
# Concatenate horizontally (columns)
df_concat_cols = pd.concat([df_left, df_right], axis=1)
print("\nConcatenated columns:\n", df_concat_cols)

# %%
# Create sample data
df_left = pd.DataFrame({'key': ['A', 'B', 'C'], 'value_left': [1, 2, 3]})
df_right = pd.DataFrame({'key': ['B', 'C', 'D'], 'value_right': [4, 5, 6]})
print("Left DataFrame:\n", df_left)
print("\nRight DataFrame:\n", df_right)

# Concatenate vertically (rows)
df_concat_rows = pd.concat([df_left, df_right], ignore_index=True)
print("\nConcatenated rows:\n", df_concat_rows)

# Concatenate horizontally (columns)
df_concat_cols = pd.concat([df_left, df_right], axis=1)
print("\nConcatenated columns:\n", df_concat_cols)

# %%
# Inner join (only keys present in both)
inner = pd.merge(df_left, df_right, on='key', how='inner')
print("Inner join:\n", inner)

# %%
# Left join (all keys from left)
left = pd.merge(df_left, df_right, on='key', how='left')
print("\nLeft join:\n", left)

# %%
# Right join (all keys from right)
right = pd.merge(df_left, df_right, on='key', how='right')
print("\nRight join:\n", right)

# %%
# Outer join (union of keys)
outer = pd.merge(df_left, df_right, on='key', how='outer')
print("\nOuter join:\n", outer)

# %%
# Cross join (Cartesian product)
cross = pd.merge(df_left, df_right, how='cross')
print("\nCross join:\n", cross)

# %%
# Inner join (only keys present in both)
inner = pd.merge(df_left, df_right, on='key', how='inner')
print("Inner join:\n", inner)

# Left join (all keys from left)
left = pd.merge(df_left, df_right, on='key', how='left')
print("\nLeft join:\n", left)

# Right join (all keys from right)
right = pd.merge(df_left, df_right, on='key', how='right')
print("\nRight join:\n", right)

# Outer join (union of keys)
outer = pd.merge(df_left, df_right, on='key', how='outer')
print("\nOuter join:\n", outer)

# Cross join (Cartesian product)
cross = pd.merge(df_left, df_right, how='cross')
print("\nCross join:\n", cross)

# %% [markdown]
# ## 11. Apply Functions (`apply`, `map`, `applymap`)
#
# - `apply()` – apply function to rows or columns of DataFrame
# - `map()` – apply function element-wise to Series
# - `applymap()` – element-wise to DataFrame

# %%
titanic.head()

# %%
type(titanic['Age'].apply(lambda x:x+5))

# %%
# Series.map (element-wise)
titanic['Sex_code'] = titanic['Sex'].map({'male': 0, 'female': 1})
print("Sex mapped to 0/1:")
print(titanic[['Sex', 'Sex_code']].head())
type(titanic['Sex_code'])

# %%
def age_class(age):
    if age < 10:
        return 'Child'
    elif age >=10 and age <= 16:
        return 'Teenager'
    elif age >=17 and age <=25:
        return 'Young'
    elif age>= 26 and age <=40:
        return 'Adult'
    elif age>= 41 and age <=60:
        return 'Mid Adult'
    elif age>= 61 and age <=120:
        return 'Senior Citizen'
    elif pd.isna(age):
        return 'Unknown'

# %%
titanic.drop('Age Code',axis=1,inplace =True)

# %%
titanic.insert(6,'Age Code',titanic['Age'].map(age_class))

# %%
titanic.rename({'Sex':'Gender'},axis = 1,inplace =True)

# %%
titanic.groupby(['Age Code','Gender'])['Survived'].value_counts()

# %%
titanic.query('Gender == "male" and Age >=17 and Age <= 25 and Survived == 1')

# %%
titanic.columns

# %%
titanic.query('Age>60 and Gender == "female"')

# %%
titanic.head()

# %%
# Series.map (element-wise)
titanic['Sex_code'] = titanic['Gender'].map({'male': 0, 'female': 1})
print("Sex mapped to 0/1:")
print(titanic[['Gender', 'Sex_code']].head())

# DataFrame.apply (row-wise or column-wise)
# Calculate age group
def age_group(age):
    if pd.isna(age):
        return 'Unknown'
    elif age < 18:
        return 'Child'
    elif age < 60:
        return 'Adult'
    else:
        return 'Senior'

titanic['AgeGroup'] = titanic['Age'].apply(age_group)
print("\nAge groups:")
print(titanic['AgeGroup'].value_counts())

# Apply to entire DataFrame (element-wise)
df_small = pd.DataFrame([[1, 2], [3, 4]], columns=['A', 'B'])
df_squared = df_small.applymap(lambda x: x**2)
print("\nElement-wise square with applymap:\n", df_squared)

# %% [markdown]
# ## 12. Working with Dates and Times

# %%
# Create datetime data
dates = pd.date_range('2024-01-01', periods=10, freq='D')
df_dates = pd.DataFrame({'date': dates, 'value': np.random.randn(10)})
print("DataFrame with dates:\n", df_dates.head())

# Extract date components
df_dates['year'] = df_dates['date'].dt.year
df_dates['month'] = df_dates['date'].dt.month
df_dates['day'] = df_dates['date'].dt.day
df_dates['weekday'] = df_dates['date'].dt.day_name()
print("\nExtracted components:\n", df_dates.head())

# Filter by date
jan_data = df_dates[df_dates['date'].dt.month == 1]
print(f"\nJanuary data: {len(jan_data)} rows")

# Set date as index and resample
df_dates.set_index('date', inplace=True)
weekly_mean = df_dates['value'].resample('W').mean()
print("\nWeekly average values:")
print(weekly_mean)

# %% [markdown]
# ## 13. Handling Duplicates

# %%
titanic.duplicated().sum()

# %%
titanic[~titanic.duplicated(subset=['Gender','Pclass'],keep ='last')]

# %%
# Create duplicate data
df_dup = pd.DataFrame({
    'id': [1, 2, 2, 3, 3, 3],
    'value': ['a', 'b', 'b', 'c', 'c', 'c']
})
print("Data with duplicates:\n", df_dup)

# Check duplicates
print("\nDuplicated rows:")
print(df_dup.duplicated())

# Count duplicates
print(f"\nNumber of duplicate rows: {df_dup.duplicated().sum()}")

# Drop duplicates (keep first by default)
df_no_dup = df_dup.drop_duplicates()
print("\nAfter drop_duplicates():\n", df_no_dup)

# Drop duplicates based on subset of columns
df_dup_subset = df_dup.drop_duplicates(subset=['value'])
print("\nDrop duplicates based on 'value' column:\n", df_dup_subset)

# %% [markdown]
# ## 14. Pivot Tables and Cross Tabulation

# %%
# Pivot table: survival rate by class and sex
pivot = pd.pivot_table(titanic, values='Survived', index='Pclass', columns='Sex', aggfunc='mean')
print("Pivot table (survival rate):")
print(pivot)

# Cross tabulation (frequency counts)
crosstab = pd.crosstab(titanic['Pclass'], titanic['Survived'], margins=True)
print("\nCross tabulation:")
print(crosstab)

# With normalization
crosstab_norm = pd.crosstab(titanic['Pclass'], titanic['Survived'], normalize='index')
print("\nNormalized by class:")
print(crosstab_norm)

# %% [markdown]
# ## 15. Reading and Writing Data

# %%
# Write to CSV
titanic_sample = titanic.head(100)
titanic_sample.to_csv('titanic_sample.csv', index=False)
print("Saved to CSV")

# Read from CSV
df_csv = pd.read_csv('titanic_sample.csv')
print("Read from CSV, shape:", df_csv.shape)

# Write to Excel (requires openpyxl)
# titanic_sample.to_excel('titanic_sample.xlsx', index=False)
# df_excel = pd.read_excel('titanic_sample.xlsx')

# Write to JSON
titanic_sample.to_json('titanic_sample.json', orient='records')
print("Saved to JSON")

# Write to Parquet (efficient binary format)
# titanic_sample.to_parquet('titanic_sample.parquet')
# df_parquet = pd.read_parquet('titanic_sample.parquet')

# %% [markdown]
# ## 16. Basic Plotting with Pandas

# %%
# Line plot
ts = pd.Series(np.random.randn(100), index=pd.date_range('2024-01-01', periods=100))
ts.plot(title='Random Time Series', figsize=(10, 4))
plt.show()

# Bar plot
titanic['Pclass'].value_counts().sort_index().plot(kind='bar', title='Passenger Count by Class', color='skyblue')
plt.ylabel('Count')
plt.show()

# Histogram
titanic['Age'].dropna().plot(kind='hist', bins=30, title='Age Distribution', alpha=0.7)
plt.xlabel('Age')
plt.show()

# Scatter plot
titanic.plot.scatter(x='Age', y='Fare', alpha=0.5, title='Age vs Fare')
plt.show()

# %% [markdown]
# ## 17. Advanced Tips and Tricks
#
# - **Memory optimization**: Use `pd.read_csv(..., dtype={'col': 'category'})` for low-cardinality columns.
# - **Chunking large files**: `pd.read_csv('large.csv', chunksize=10000)`.
# - **Efficient conditionals**: `np.where` for vectorized if-else.
# - **String methods**: `df['col'].str.contains()`, `str.startswith()`, `str.extract()`.
# - **Working with large data**: Use `pd.read_csv(..., usecols=[...])` to load only needed columns.

# %%
titanic['Gender'].str.title()

# %%
titanic.columns

# %%
titanic.insert(2,'Title1',titanic['Name'].str.extract('([A-Za-z]+)\.'))

# %%
titanic['Name']  = titanic['Name'].str.replace('Miss','Miss.')

# %%
titanic

# %%
# Using np.where for new column
titanic['Child'] = np.where(titanic['Age'] < 18, 1, 0)
print("Children count:", titanic['Child'].sum())

# String methods
titanic['Title'] = titanic['Name'].str.extract('([A-Za-z]+)\.')
print("\nTitle counts:")
print(titanic['Title'].value_counts())

# Chaining operations
result = (titanic
          .query('Age > 18')
          .groupby('Sex')['Fare']
          .mean())
print("\nAverage fare for adults by sex:")
print(result)

# %% [markdown]
# ## Summary
#
# Congratulations! You've covered:
# - **Series and DataFrame** creation and attributes
# - **Indexing** with `loc`, `iloc`, boolean filtering
# - **Handling missing data** (detect, drop, fill)
# - **Data type conversion** (to numeric, datetime, category)
# - **Aggregations and descriptive statistics**
# - **GroupBy** for split-apply-combine
# - **Merging and concatenating** DataFrames (all join types)
# - **Apply family** (`map`, `apply`, `applymap`)
# - **Datetime** manipulation and resampling
# - **Duplicates** handling
# - **Pivot tables and crosstab**
# - **Reading/writing** common file formats
# - **Basic plotting**
# - **Advanced tips** for efficiency
#
# Pandas is an essential tool for any data professional. Practice with real datasets to solidify these concepts.
