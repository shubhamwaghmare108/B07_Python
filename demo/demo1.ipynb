# %% [markdown]
# # demo

# %% [markdown]
# _demo_

# %% [markdown]
# __demo__

# %% [markdown]
# ___demo___

# %% [markdown]
# 1. day1
# 2. day2
# 3. day3

# %% [markdown]
# 1. day1
#     1. variable
#     2. naming rule
# 2. fghj

# %% [markdown]
# - sdfg
# - sdfg

# %% [markdown]
# - day1
#     - naming rule
# - day2
#     - variables

# %% [markdown]
# |name|age|
# |----|----|
# |shubham|30|
# |nikita|28|
