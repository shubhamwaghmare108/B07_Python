# %%
# A class called 'Dog'
class Dog:
    # A class attribute
    species = "Canis familiaris"

    # The __init__ method is a special constructor method,autocalled when you try to create class object
    def __init__(self, name, age):
        # Instance attributes
        print("welcome to Dog Classs")
        self.name = name
        self.age = age
        print(f"Dog with name {self.name} is created sucessfully")

    # An instance method or function
    def bark(self):
        return f"{self.name} woof!"

    def walk(self):
        return f"{self.name} walk"

    def sit(self):
        return f"{self.name} sit down"

    def attack(self):
        return f"{self.name} attack"

# %%
# A class called 'Dog'
class MotherDog:
    # A class attribute
    species = "Canis familiaris"

    # The __init__ method is a special constructor method,autocalled when you try to create class object
    def __init__(self, name, age):
        # Instance attributes
        print("welcome to Dog Classs")
        self.name = name
        self.age = age
        print(f"Dog with name {self.name} is created sucessfully")

    # An instance method or function
    def bark(self):
        print("Work from Home")
        return f"{self.name} woof!"

    def walk(self):
        return f"{self.name} walk"

    def sit(self):
        return f"{self.name} sit down"
    def attack(self,is_familier = 0):
        print(123)
        if is_familier == 1:
            return "bark and wag tail"
        return f"{self.name} attack"

# %%
# A class called 'Dog'
class FatherDog:
    # A class attribute
    species = "Canis familiaris"

    # The __init__ method is a special constructor method,autocalled when you try to create class object
    def __init__(self, name, age):
        # Instance attributes
        print("welcome to Dog Classs")
        self.name = name
        self.age = age
        print(f"Dog with name {self.name} is created sucessfully")

    # An instance method or function

    def walk(self):
        return f"{self.name} walk"

    def sit(self):
        print("Father's sit method is called")
        return f"{self.name} sit down"

    def attack(self,is_familier = 0):
        print(2)
        return super().attack(is_familier)

# %%
class Puppy(FatherDog,MotherDog):

    def __init__(self,name,age,cuteness_level):
        super().__init__(name,age)
        self.cuteness_level = cuteness_level
        
    def attack(self,is_familier):
        print(1)
        return super().attack(is_familier)

# %%
d1 = Puppy("tommy",2,"very cute")
# Out:
# welcome to Dog Classs
# Dog with name tommy is created sucessfully

# %%
d1.name
# Out:
# 'tommy'

# %%
d1.age
# Out:
# 2

# %%
d1.cuteness_level
# Out:
# 'very cute'

# %%
d1.sit()
# Out:
# Father's sit method is called
# 'tommy sit down'

# %%
d1.bark()
# Out:
# Work from Home
# 'tommy woof!'

# %%
d1.walk()
# Out:
# 'tommy walk'

# %%
d1.sit()
# Out:
# Father's sit method is called
# 'tommy sit down'

# %%
d1.attack()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 d1.attack()
#
# TypeError: Puppy.attack() missing 1 required positional argument: 'is_familier'

# %%
d1.attack(1)
# Out:
# 1
# 2
# 123
# 'bark and wag tail'

# %%
x

# %%
d1.attack(0)
# Out:
# 1
# 2
# 123
# 'tommy attack'

# %%
Puppy.mro()
# Out:
# [__main__.Puppy, __main__.FatherDog, __main__.MotherDog, object]

# %%
FatherDog.mro()
# Out:
# [__main__.FatherDog, object]

# %%
f1 = FatherDog('Tiger',5)
# Out:
# welcome to Dog Classs
# Dog with name Tiger is created sucessfully

# %%
f1.attack()
# Out:
# 2
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 f1.attack()
#
# Cell In[29], line 25, in FatherDog.attack(self, is_familier)
#      23     def attack(self,is_familier = 0):
#      24         print(2)
# ---> 25         return super().attack(is_familier)
#
# AttributeError: 'super' object has no attribute 'attack'

# %%
d1.fly()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 d1.fly()
#
# AttributeError: 'Puppy' object has no attribute 'fly'

# %%
# A class called 'Dog'
class Dog:
    # A class attribute
    __species = "Canis familiaris"
    @classmethod
    def species(cls):
        return cls.__species
    # The __init__ method is a special constructor method
    def __init__(self, name, age):
        # Instance attributes
        print("welcome to Dog Classs")
        self._name = name
        self.__age = age

    # An instance method
    
    def bark(self):
        return f"{self._name} says woof!"

    @property # getter
    def age(self):
        return self.__age

    @age.setter # setter
    def age(self,new):
        self.__age = new
    @age.deleter # getter
    def age(self):
        del self.__age
    
    @staticmethod
    def gretings():
        print("Hello Everyone")
    #@age.setter
    #def age(self,new):
        #self.__age = new

# %%
d1 = Dog("Tiger",5)

# %%
d1.gretings()

# %%
Dog._Dog__species

# %%
d1.species()

# %%
Dog.species()

# %%
d1.age

# %%
d1.age = 10

# %%
d1.age

# %%
del d1.age

# %%
d1.age

# %%
dog1.__dict__

# %%
# Creating objects (instances) of the Dog class
dog1 = Dog("Buddy", 3)
dog2 = Dog("Lucy", 5)

# Accessing attributes and calling methods
print(f"Dog 1 is {dog1.name} and is {dog1._Dog__age} years old.")
print(f"Dog 2 is {dog2.name} and is {dog2.__age} years old.")

# %%
dog2.__dict__

# %%
dog1.getAge()

# %%
dog1.getAge(123) # getter method

# %%
dog1.getAge("asdff")

# %%
dog1.setAge(1,5)

# %%
dog1.name

# %%
dog1._name

# %%
dog1._name = "fruty"

# %%
dog1._name

# %%
dog1.__age

# %%
dog1._Dog__age

# %%
dog1.bark

# %%
dog1.species

# %%
type(dog1)

# %%
dog1._Dog__age

# %%
dog1.getAge("asdf")

# %%
dog1.setAge("asdff",10)

# %%
dog1.getAge("asdff")

# %%
# Parent class
class Animal:
    def __init__(self, name):
        self.name = name

    def speak(self):
        raise NotImplementedError("Subclass must implement abstract method")

# Child class inheriting from Animal
class Cat(Animal):
    def __init__(self, name, breed):
        # Call the parent's constructor
        super().__init__(name)
        self.breed = breed

    # Override the speak method
    def speak(self):
        return f"{self.name} says meow!"

cat1 = Cat("Whiskers", "Siamese")
print(cat1.speak())

# %%
# Parent class
class Animal:
    def __init__(self, name):
        self.name = name

    def speak(self):
        raise NotImplementedError("Subclass must implement abstract method")

# Child class inheriting from Animal
class Cat(Animal):
    def __init__(self, name, breed):
        # Call the parent's constructor
        super().__init__(name)
        self.breed = breed

    # Override the speak method
    def speak(self):
        return f"{self.name} says meow!"

cat1 = Cat("Whiskers", "Siamese")
print(cat1.speak())

# %%
class Parent1:
    def method1(self):
        print("Method from Parent1")
    def method2(self):
        print("Method from Parent1")

class Parent2:
    def method1(self):
        print("Method from Parent2")
    def method2(self):
        print("Method from Parent2")

class Child( Parent2,Parent1):
    def method3(self):
        print("Method from Child")

# Create an instance of the Child class
c = Child()
c.method1()
c.method2()
c.method3()

# %%
Child.mro()

# %%
class A:
    #pass
    def hi(self):
        print("In A")

class B(A):
    #def hi(self):
        #print("In B")
    pass
class C(A):
    #def hi(self):
        #print("In C")
    pass
class D(B, C):
    pass

# Check the MRO
print(D.mro())
# Out:
# [<class '__main__.D'>, <class '__main__.B'>, <class '__main__.C'>, <class '__main__.A'>, <class 'object'>]

# %%
d=D()

# %%
d.hi()

# %%
# Parent class 1
class Vehicle:
    def __init__(self, brand, year):
        self.brand = brand
        self.year = year
        print("Vehicle initialized.")

    def display_info(self):
        print(f"Brand: {self.brand}, Year: {self.year}")

# Mixin class 1
class Motorized:
    def __init__(self, motor_type):
        self.motor_type = motor_type
        print("Motorized component added.")

    def run_motor(self):
        print(f"The {self.motor_type} motor is running.")

# Mixin class 2
class Amphibious:
    def __init__(self, propulsion_type):
        self.propulsion_type = propulsion_type
        print("Amphibious component added.")

    def float(self):
        print(f"The vehicle is floating using {self.propulsion_type}.")

# Child class using multiple inheritance
class AmphibiousCar(Vehicle, Motorized, Amphibious):
    def __init__(self, brand, year, motor_type, propulsion_type):
        # Call constructors of parent classes using super()
        super().__init__(brand, year)
        # We must explicitly call the __init__ of other mixins
        Motorized.__init__(self, motor_type)
        Amphibious.__init__(self, propulsion_type)
        print("AmphibiousCar created.")

    def drive(self):
        print("The vehicle is driving on land.")

# Create an object of the AmphibiousCar class
my_amphibious_car = AmphibiousCar("WaterCar", 2023, "Gasoline", "Jet Propulsion")

# Accessing methods from all parent and child classes
print("\n--- Displaying Info ---")
my_amphibious_car.display_info()
my_amphibious_car.run_motor()
my_amphibious_car.float()
my_amphibious_car.drive()

# %%
class stranger:
    def hello(self):
        print("Hello from stranger")
        return 1
class p1(stranger):
    def hello(self):
        print("Hello from p1")
        super().hello()
class p2(stranger):
    def hello(self):
        print("Hello from p2")
        return super().hello()
class child(p1,p2):
    def hello(self):
        return super().hello()

# %%
c1 = child()

# %%
child.__mro__
# Out:
# (__main__.child, __main__.p1, __main__.p2, __main__.stranger, object)

# %%
p1.mro()
# Out:
# [__main__.p1, __main__.stranger, object]

# %%
p2.mro()
# Out:
# [__main__.p2, __main__.stranger, object]

# %%
x = c1.hello()
# Out:
# Hello from p1
# Hello from p2
# Hello from stranger

# %%
x
