# %% [raw]
# \d----digit
# \D-----except digit
# \w-----[a-zA-Z0-9_]
# \W-----except \w charactor
# \s----- space,tab,newline
# \S---except \s charactor
# ()---group
# |---or

# %%
import re

# %%
re.search('p.g', 'pig')
# Out:
# <re.Match object; span=(0, 3), match='pig'>

# %%
re.search('p.g', 'peg')
# Out:
# <re.Match object; span=(0, 3), match='peg'>

# %%
re.search('[aeiou]', 'regular')
# Out:
# <re.Match object; span=(1, 2), match='e'>

# %%
re.search('[123]', '456789')

# %%
re.search('[^0-9]', '33&123')
# Out:
# <re.Match object; span=(2, 3), match='&'>

# %%
re.search('[^xyz]', 'yzw')
# Out:
# <re.Match object; span=(2, 3), match='w'>

# %%
re.search('[a-c]', 'dog')

# %%
re.search('[1-5]', '67890')

# %%
re.search('\d', 'test123')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\hp\AppData\Local\Temp\ipykernel_17100\3933172009.py:1: SyntaxWarning: invalid escape sequence '\d'
#   re.search('\d', 'test123')
# <re.Match object; span=(4, 5), match='1'>

# %%
re.search('\d+', 'price 100')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\hp\AppData\Local\Temp\ipykernel_17100\1532121953.py:1: SyntaxWarning: invalid escape sequence '\d'
#   re.search('\d+', 'price 100')
# <re.Match object; span=(6, 9), match='100'>

# %%
re.search('\d+', 'price 1')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\hp\AppData\Local\Temp\ipykernel_17100\2045720021.py:1: SyntaxWarning: invalid escape sequence '\d'
#   re.search('\d+', 'price 1')
# <re.Match object; span=(6, 7), match='1'>

# %%
re.search('\D', '123go')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\hp\AppData\Local\Temp\ipykernel_17100\812455061.py:1: SyntaxWarning: invalid escape sequence '\D'
#   re.search('\D', '123go')
# <re.Match object; span=(3, 4), match='g'>

# %%
re.search(r'\D', '456')

# %%
re.search(r'\w', '!')

# %%
r=re.search(r'\w+', 'hello_%world')

# %%
re.search('\W', 'test!')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\W'
# <>:1: SyntaxWarning: invalid escape sequence '\W'
# C:\Users\hp\AppData\Local\Temp\ipykernel_17100\2331549065.py:1: SyntaxWarning: invalid escape sequence '\W'
#   re.search('\W', 'test!')
# <re.Match object; span=(4, 5), match='!'>

# %%
re.search('\W', 'alphanum')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\W'
# <>:1: SyntaxWarning: invalid escape sequence '\W'
# C:\Users\hp\AppData\Local\Temp\ipykernel_17100\4080166559.py:1: SyntaxWarning: invalid escape sequence '\W'
#   re.search('\W', 'alphanum')

# %%
re.search('\s', 'hello world')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\hp\AppData\Local\Temp\ipykernel_17100\2326557015.py:1: SyntaxWarning: invalid escape sequence '\s'
#   re.search('\s', 'hello world')
# <re.Match object; span=(5, 6), match=' '>

# %%
re.search('\s+', 'two   spaces')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\hp\AppData\Local\Temp\ipykernel_17100\340098835.py:1: SyntaxWarning: invalid escape sequence '\s'
#   re.search('\s+', 'two   spaces')
# <re.Match object; span=(3, 6), match='   '>

# %%
re.search(r'\S', '  space')
# Out:
# <re.Match object; span=(2, 3), match='s'>

# %%
re.search(r'\S', '\t')

# %%
re.search(r'\s', '\t')
# Out:
# <re.Match object; span=(0, 1), match='\t'>

# %%
re.search(r'\bcat\b', 'The cat sat.')
# Out:
# <re.Match object; span=(4, 7), match='cat'>

# %%
re.search(r'\bcat\b', 'The catsat.')

# %%
re.search(r'\bcat\b', 'The acatasat.')

# %%
re.search(r'\Bcat\B', 'The acatasat.')
# Out:
# <re.Match object; span=(5, 8), match='cat'>

# %%
#meta charactor,re method,regex in python
